# %% [markdown]
# # Assurance of Learning (Number 1)

# %% [markdown]
# ## Linear Approach
# ##### Just additional
# I want to show why linear approach is bad and even if the linear approach is easy to code it's prohibited to use to solve this question

# %%
# Library Import

import numpy as np
from matplotlib import pyplot as plt

# Bag production data

data = [
    1863, 1614, 2570, 1685, 2101, 1811, 2457, 2171, 2134, 2502, 2358, 2399, 2048, 2523, 2086, 2391,
    2150, 2340, 3129, 2277, 2964, 2997, 2747, 2862, 3405, 2677, 2749, 2755, 2963, 3161, 3623, 2768,
    3141, 3439, 3601, 3531, 3477, 3376, 4027, 3175, 3274, 3334, 3964, 3649, 3502, 3688, 3657, 4422,
    4197, 4441, 4736, 4521, 4485, 4644, 5036, 4876, 4789, 4544, 4975, 5211, 4880, 4933, 5079, 5339,
    5232, 5520, 5714, 5260, 6110, 5334, 5988, 6235, 6365, 6266, 6345, 6118, 6497, 6278, 6638, 6590,
    6271, 7246, 6584, 6594, 7092, 7326, 7409, 7976, 7959, 8012, 8195, 8008, 8313, 7791, 8368, 8933,
    8756, 8613, 8705, 9098, 8769, 9544, 9050, 9186, 10012, 9685, 9966, 10048, 10244, 10740, 10318,
    10393, 10986, 10635, 10731, 11749, 11849, 12123, 12274, 11666, 11960, 12629, 12915, 13051,
    13387, 13309, 13732, 13162, 13644, 13808, 14101, 13992, 15191, 15018, 14917, 15046, 15556,
    15893, 16388, 16782, 16716, 17033, 16896, 17689
]

# From Month 1 to Month 144
months = np.arange(1, 145)

x = np.array(months)
y = np.array(data)

# Step 1

# np.stack --> creating vertical stack
# np.ones --> creating an array with value = 1
# .T --> Transpose

A = np.vstack([x, np.ones(len(x))]).T

# print (A)

# Step 2

# np.newaxis --> reating new axis

y = y[:,np.newaxis]

# print (y)

# Step 3

# np.dot --> do the product rule matrix
# np.linalg.inv --> to invers a matrix

beta = np.dot(np.dot(np.linalg.inv(np.dot(A.T, A)), A.T), y)

# index 0 --> m, index 1 --> b

m = beta[0]
b = beta[1]

# Step 4

print (f'Graph using Linear Approach')

plt.plot (x, y, "bo")

plt.plot (x, m*x + b, "r")

plt.show()

print(f'Mathematical Model (Linear Equation Model): y = {m[0]:.2f} * x {b[0]:.2f}\n')

# Print each month with the production bag predicted by linear model

print (f'Predicted value using Linear Equation Model:')

for i in range(len(x)):
    month = x[i]
    production = m[0] * month + b[0]
    print(f'Month {month}: {production:.2f}')
# Out:
# Graph using Linear Approach
# Mathematical Model (Linear Equation Model): y = 100.68 * x -141.04
#
# Predicted value using Linear Equation Model:
# Month 1: -40.36
# Month 2: 60.32
# Month 3: 160.99
# Month 4: 261.67
# Month 5: 362.34
# Month 6: 463.02
# Month 7: 563.69
# Month 8: 664.37
# Month 9: 765.05
# Month 10: 865.72
# Month 11: 966.40
# Month 12: 1067.07
# Month 13: 1167.75
# Month 14: 1268.42
# Month 15: 1369.10
# Month 16: 1469.78
# Month 17: 1570.45
# Month 18: 1671.13
# Month 19: 1771.80
# Month 20: 1872.48
# Month 21: 1973.15
# Month 22: 2073.83
# Month 23: 2174.51
# Month 24: 2275.18
# Month 25: 2375.86
# Month 26: 2476.53
# Month 27: 2577.21
# Month 28: 2677.88
# Month 29: 2778.56
# Month 30: 2879.23
# Month 31: 2979.91
# Month 32: 3080.59
# Month 33: 3181.26
# Month 34: 3281.94
# Month 35: 3382.61
# Month 36: 3483.29
# Month 37: 3583.96
# Month 38: 3684.64
# Month 39: 3785.32
# Month 40: 3885.99
# Month 41: 3986.67
# Month 42: 4087.34
# Month 43: 4188.02
# Month 44: 4288.69
# Month 45: 4389.37
# Month 46: 4490.05
# Month 47: 4590.72
# Month 48: 4691.40
# Month 49: 4792.07
# Month 50: 4892.75
# Month 51: 4993.42
# Month 52: 5094.10
# Month 53: 5194.78
# Month 54: 5295.45
# Month 55: 5396.13
# Month 56: 5496.80
# Month 57: 5597.48
# Month 58: 5698.15
# Month 59: 5798.83
# Month 60: 5899.51
# Month 61: 6000.18
# Month 62: 6100.86
# Month 63: 6201.53
# Month 64: 6302.21
# Month 65: 6402.88
# Month 66: 6503.56
# Month 67: 6604.24
# Month 68: 6704.91
# Month 69: 6805.59
# Month 70: 6906.26
# Month 71: 7006.94
# Month 72: 7107.61
# Month 73: 7208.29
# Month 74: 7308.96
# Month 75: 7409.64
# Month 76: 7510.32
# Month 77: 7610.99
# Month 78: 7711.67
# Month 79: 7812.34
# Month 80: 7913.02
# Month 81: 8013.69
# Month 82: 8114.37
# Month 83: 8215.05
# Month 84: 8315.72
# Month 85: 8416.40
# Month 86: 8517.07
# Month 87: 8617.75
# Month 88: 8718.42
# Month 89: 8819.10
# Month 90: 8919.78
# Month 91: 9020.45
# Month 92: 9121.13
# Month 93: 9221.80
# Month 94: 9322.48
# Month 95: 9423.15
# Month 96: 9523.83
# Month 97: 9624.51
# Month 98: 9725.18
# Month 99: 9825.86
# Month 100: 9926.53
# Month 101: 10027.21
# Month 102: 10127.88
# Month 103: 10228.56
# Month 104: 10329.24
# Month 105: 10429.91
# Month 106: 10530.59
# Month 107: 10631.26
# Month 108: 10731.94
# Month 109: 10832.61
# Month 110: 10933.29
# Month 111: 11033.97
# Month 112: 11134.64
# Month 113: 11235.32
# Month 114: 11335.99
# Month 115: 11436.67
# Month 116: 11537.34
# Month 117: 11638.02
# Month 118: 11738.69
# Month 119: 11839.37
# Month 120: 11940.05
# Month 121: 12040.72
# Month 122: 12141.40
# Month 123: 12242.07
# Month 124: 12342.75
# Month 125: 12443.42
# Month 126: 12544.10
# Month 127: 12644.78
# Month 128: 12745.45
# Month 129: 12846.13
# Month 130: 12946.80
# Month 131: 13047.48
# Month 132: 13148.15
# Month 133: 13248.83
# Month 134: 13349.51
# Month 135: 13450.18
# Month 136: 13550.86
# Month 137: 13651.53
# Month 138: 13752.21
# Month 139: 13852.88
# Month 140: 13953.56
# Month 141: 14054.24
# Month 142: 14154.91
# Month 143: 14255.59
# Month 144: 14356.26

# %% [markdown]
# ### Linear Model Conclusion
#
# It has been proven that a linear approach will produce poor approximation values ​​and even negative data.

# %% [markdown]
# ## Polynomial Equation Model

# %%
# Library Import

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# Bag Production Data

data = [
    1863, 1614, 2570, 1685, 2101, 1811, 2457, 2171, 2134, 2502, 2358, 2399, 2048, 2523, 2086, 2391,
    2150, 2340, 3129, 2277, 2964, 2997, 2747, 2862, 3405, 2677, 2749, 2755, 2963, 3161, 3623, 2768,
    3141, 3439, 3601, 3531, 3477, 3376, 4027, 3175, 3274, 3334, 3964, 3649, 3502, 3688, 3657, 4422,
    4197, 4441, 4736, 4521, 4485, 4644, 5036, 4876, 4789, 4544, 4975, 5211, 4880, 4933, 5079, 5339,
    5232, 5520, 5714, 5260, 6110, 5334, 5988, 6235, 6365, 6266, 6345, 6118, 6497, 6278, 6638, 6590,
    6271, 7246, 6584, 6594, 7092, 7326, 7409, 7976, 7959, 8012, 8195, 8008, 8313, 7791, 8368, 8933,
    8756, 8613, 8705, 9098, 8769, 9544, 9050, 9186, 10012, 9685, 9966, 10048, 10244, 10740, 10318,
    10393, 10986, 10635, 10731, 11749, 11849, 12123, 12274, 11666, 11960, 12629, 12915, 13051,
    13387, 13309, 13732, 13162, 13644, 13808, 14101, 13992, 15191, 15018, 14917, 15046, 15556,
    15893, 16388, 16782, 16716, 17033, 16896, 17689
]

# Month 1 to Month 144

months = np.arange(1, 145)

# Plot the original data

print (f'Graph for the original data given based on the question\n')

plt.figure(figsize=(12, 6))
plt.plot(months, data, label='Real Production Data', color='blue')
plt.xlabel('Month')
plt.ylabel('Production')
plt.title('Bag Production Data for Each Month')
plt.legend()
plt.grid(True)
plt.show()

# Fit the polynomial equation using 5 Degree

degree = 5
poly_coeffs = np.polyfit(months, data, degree)
poly_model = np.poly1d(poly_coeffs)

fitted_data = poly_model(months)

# Plot the result of the polynomial equation model

print (f'Graph using Polynomial Equation Degree {degree}\n')

plt.figure(figsize=(12, 6))
plt.plot(months, data, label='Real Production Data', color='blue')
plt.plot(months, fitted_data, label=f'Polynomial Model Degree {degree}', color='red')
plt.xlabel('Month')
plt.ylabel('Production')
plt.title('Polynomial Model Fitting with Data Production')
plt.legend()
plt.grid(True)
plt.show()

# Print the polynomial coefficient model

print('Polynomial Model Coefficient:\n')
print (poly_model)

for i, coeff in enumerate(poly_coeffs):
    print(f'Coefficient of x^{degree-i}: {coeff:.10f}')

# Print the Polynomial Model Equation as a String
poly_equation = " + ".join([f"{coeff:.10f}x^{degree-i}" for i, coeff in enumerate(poly_coeffs)])
print(f"\nPolynomial Equation: {poly_equation}")
# Out:
# Graph for the original data given based on the question
# Graph using Polynomial Equation Degree 5
# Polynomial Model Coefficient:
#
#            5             4            3            2
# 2.515e-07 x - 6.251e-05 x + 0.007325 x - 0.001457 x + 35.52 x + 1869
# Coefficient of x^5: 0.0000002515
# Coefficient of x^4: -0.0000625150
# Coefficient of x^3: 0.0073252801
# Coefficient of x^2: -0.0014574290
# Coefficient of x^1: 35.5201677705
# Coefficient of x^0: 1868.5382788214
#
# Polynomial Equation: 0.0000002515x^5 + -0.0000625150x^4 + 0.0073252801x^3 + -0.0014574290x^2 + 35.5201677705x^1 + 1868.5382788214x^0

# %% [markdown]
# ### Difference checking between the True vs Predicted Value using Polynomial Degree 5

# %%
def check_polynomial_accuracy(poly_model, x_values, y_actual):
    y_predicted = poly_model(x_values)
    total_diff = 0
    for x, y_pred, y_act in zip(x_values, y_predicted, y_actual):
        total_diff += abs(y_pred - y_act)
        print(f'x = {x}, y_predicted = {y_pred:.2f}, y_true = {y_act}, difference = {abs(y_pred - y_act):.2f}')
    return total_diff

# Checking the accuracy model from the difference and total difference of True vs Predicted Value

total_diff = check_polynomial_accuracy(poly_model, months, data)
print(f'Total difference: {total_diff:.2f}')
# Out:
# x = 1, y_predicted = 1904.06, y_true = 1863, difference = 41.06
# x = 2, y_predicted = 1939.63, y_true = 1614, difference = 325.63
# x = 3, y_predicted = 1975.28, y_true = 2570, difference = 594.72
# x = 4, y_predicted = 2011.05, y_true = 1685, difference = 326.05
# x = 5, y_predicted = 2046.98, y_true = 2101, difference = 54.02
# x = 6, y_predicted = 2083.11, y_true = 1811, difference = 272.11
# x = 7, y_predicted = 2119.47, y_true = 2457, difference = 337.53
# x = 8, y_predicted = 2156.11, y_true = 2171, difference = 14.89
# x = 9, y_predicted = 2193.05, y_true = 2134, difference = 59.05
# x = 10, y_predicted = 2230.32, y_true = 2502, difference = 271.68
# x = 11, y_predicted = 2267.96, y_true = 2358, difference = 90.04
# x = 12, y_predicted = 2305.99, y_true = 2399, difference = 93.01
# x = 13, y_predicted = 2344.46, y_true = 2048, difference = 296.46
# x = 14, y_predicted = 2383.37, y_true = 2523, difference = 139.63
# x = 15, y_predicted = 2422.76, y_true = 2086, difference = 336.76
# x = 16, y_predicted = 2462.66, y_true = 2391, difference = 71.66
# x = 17, y_predicted = 2503.08, y_true = 2150, difference = 353.08
# x = 18, y_predicted = 2544.06, y_true = 2340, difference = 204.06
# x = 19, y_predicted = 2585.62, y_true = 3129, difference = 543.38
# x = 20, y_predicted = 2627.76, y_true = 2277, difference = 350.76
# x = 21, y_predicted = 2670.53, y_true = 2964, difference = 293.47
# x = 22, y_predicted = 2713.93, y_true = 2997, difference = 283.07
# x = 23, y_predicted = 2757.98, y_true = 2747, difference = 10.98
# x = 24, y_predicted = 2802.71, y_true = 2862, difference = 59.29
# x = 25, y_predicted = 2848.13, y_true = 3405, difference = 556.87
# x = 26, y_predicted = 2894.25, y_true = 2677, difference = 217.25
# x = 27, y_predicted = 2941.09, y_true = 2749, difference = 192.09
# x = 28, y_predicted = 2988.67, y_true = 2755, difference = 233.67
# x = 29, y_predicted = 3037.00, y_true = 2963, difference = 74.00
# x = 30, y_predicted = 3086.09, y_true = 3161, difference = 74.91
# x = 31, y_predicted = 3135.96, y_true = 3623, difference = 487.04
# x = 32, y_predicted = 3186.61, y_true = 2768, difference = 418.61
# x = 33, y_predicted = 3238.07, y_true = 3141, difference = 97.07
# x = 34, y_predicted = 3290.34, y_true = 3439, difference = 148.66
# x = 35, y_predicted = 3343.43, y_true = 3601, difference = 257.57
# x = 36, y_predicted = 3397.35, y_true = 3531, difference = 133.65
# x = 37, y_predicted = 3452.11, y_true = 3477, difference = 24.89
# x = 38, y_predicted = 3507.73, y_true = 3376, difference = 131.73
# x = 39, y_predicted = 3564.20, y_true = 4027, difference = 462.80
# x = 40, y_predicted = 3621.55, y_true = 3175, difference = 446.55
# x = 41, y_predicted = 3679.77, y_true = 3274, difference = 405.77
# x = 42, y_predicted = 3738.87, y_true = 3334, difference = 404.87
# x = 43, y_predicted = 3798.87, y_true = 3964, difference = 165.13
# x = 44, y_predicted = 3859.76, y_true = 3649, difference = 210.76
# x = 45, y_predicted = 3921.57, y_true = 3502, difference = 419.57
# x = 46, y_predicted = 3984.29, y_true = 3688, difference = 296.29
# x = 47, y_predicted = 4047.93, y_true = 3657, difference = 390.93
# x = 48, y_predicted = 4112.49, y_true = 4422, difference = 309.51
# x = 49, y_predicted = 4177.99, y_true = 4197, difference = 19.01
# x = 50, y_predicted = 4244.44, y_true = 4441, difference = 196.56
# x = 51, y_predicted = 4311.83, y_true = 4736, difference = 424.17
# x = 52, y_predicted = 4380.17, y_true = 4521, difference = 140.83
# x = 53, y_predicted = 4449.48, y_true = 4485, difference = 35.52
# x = 54, y_predicted = 4519.75, y_true = 4644, difference = 124.25
# x = 55, y_predicted = 4591.00, y_true = 5036, difference = 445.00
# x = 56, y_predicted = 4663.24, y_true = 4876, difference = 212.76
# x = 57, y_predicted = 4736.46, y_true = 4789, difference = 52.54
# x = 58, y_predicted = 4810.68, y_true = 4544, difference = 266.68
# x = 59, y_predicted = 4885.90, y_true = 4975, difference = 89.10
# x = 60, y_predicted = 4962.13, y_true = 5211, difference = 248.87
# x = 61, y_predicted = 5039.38, y_true = 4880, difference = 159.38
# x = 62, y_predicted = 5117.67, y_true = 4933, difference = 184.67
# x = 63, y_predicted = 5196.99, y_true = 5079, difference = 117.99
# x = 64, y_predicted = 5277.35, y_true = 5339, difference = 61.65
# x = 65, y_predicted = 5358.77, y_true = 5232, difference = 126.77
# x = 66, y_predicted = 5441.26, y_true = 5520, difference = 78.74
# x = 67, y_predicted = 5524.82, y_true = 5714, difference = 189.18
# x = 68, y_predicted = 5609.47, y_true = 5260, difference = 349.47
# x = 69, y_predicted = 5695.22, y_true = 6110, difference = 414.78
# x = 70, y_predicted = 5782.08, y_true = 5334, difference = 448.08
# x = 71, y_predicted = 5870.07, y_true = 5988, difference = 117.93
# x = 72, y_predicted = 5959.19, y_true = 6235, difference = 275.81
# x = 73, y_predicted = 6049.45, y_true = 6365, difference = 315.55
# x = 74, y_predicted = 6140.89, y_true = 6266, difference = 125.11
# x = 75, y_predicted = 6233.50, y_true = 6345, difference = 111.50
# x = 76, y_predicted = 6327.31, y_true = 6118, difference = 209.31
# x = 77, y_predicted = 6422.33, y_true = 6497, difference = 74.67
# x = 78, y_predicted = 6518.59, y_true = 6278, difference = 240.59
# x = 79, y_predicted = 6616.09, y_true = 6638, difference = 21.91
# x = 80, y_predicted = 6714.85, y_true = 6590, difference = 124.85
# x = 81, y_predicted = 6814.91, y_true = 6271, difference = 543.91
# x = 82, y_predicted = 6916.27, y_true = 7246, difference = 329.73
# x = 83, y_predicted = 7018.97, y_true = 6584, difference = 434.97
# x = 84, y_predicted = 7123.01, y_true = 6594, difference = 529.01
# x = 85, y_predicted = 7228.44, y_true = 7092, difference = 136.44
# x = 86, y_predicted = 7335.26, y_true = 7326, difference = 9.26
# x = 87, y_predicted = 7443.52, y_true = 7409, difference = 34.52
# x = 88, y_predicted = 7553.23, y_true = 7976, difference = 422.77
# x = 89, y_predicted = 7664.42, y_true = 7959, difference = 294.58
# x = 90, y_predicted = 7777.12, y_true = 8012, difference = 234.88
# x = 91, y_predicted = 7891.37, y_true = 8195, difference = 303.63
# x = 92, y_predicted = 8007.19, y_true = 8008, difference = 0.81
# x = 93, y_predicted = 8124.63, y_true = 8313, difference = 188.37
# x = 94, y_predicted = 8243.70, y_true = 7791, difference = 452.70
# x = 95, y_predicted = 8364.45, y_true = 8368, difference = 3.55
# x = 96, y_predicted = 8486.92, y_true = 8933, difference = 446.08
# x = 97, y_predicted = 8611.14, y_true = 8756, difference = 144.86
# x = 98, y_predicted = 8737.15, y_true = 8613, difference = 124.15
# x = 99, y_predicted = 8864.99, y_true = 8705, difference = 159.99
# x = 100, y_predicted = 8994.71, y_true = 9098, difference = 103.29
# x = 101, y_predicted = 9126.36, y_true = 8769, difference = 357.36
# x = 102, y_predicted = 9259.97, y_true = 9544, difference = 284.03
# x = 103, y_predicted = 9395.59, y_true = 9050, difference = 345.59
# x = 104, y_predicted = 9533.27, y_true = 9186, difference = 347.27
# x = 105, y_predicted = 9673.07, y_true = 10012, difference = 338.93
# x = 106, y_predicted = 9815.03, y_true = 9685, difference = 130.03
# x = 107, y_predicted = 9959.20, y_true = 9966, difference = 6.80
# x = 108, y_predicted = 10105.65, y_true = 10048, difference = 57.65
# x = 109, y_predicted = 10254.44, y_true = 10244, difference = 10.44
# x = 110, y_predicted = 10405.61, y_true = 10740, difference = 334.39
# x = 111, y_predicted = 10559.23, y_true = 10318, difference = 241.23
# x = 112, y_predicted = 10715.36, y_true = 10393, difference = 322.36
# x = 113, y_predicted = 10874.06, y_true = 10986, difference = 111.94
# x = 114, y_predicted = 11035.41, y_true = 10635, difference = 400.41
# x = 115, y_predicted = 11199.47, y_true = 10731, difference = 468.47
# x = 116, y_predicted = 11366.32, y_true = 11749, difference = 382.68
# x = 117, y_predicted = 11536.01, y_true = 11849, difference = 312.99
# x = 118, y_predicted = 11708.63, y_true = 12123, difference = 414.37
# x = 119, y_predicted = 11884.25, y_true = 12274, difference = 389.75
# x = 120, y_predicted = 12062.95, y_true = 11666, difference = 396.95
# x = 121, y_predicted = 12244.82, y_true = 11960, difference = 284.82
# x = 122, y_predicted = 12429.92, y_true = 12629, difference = 199.08
# x = 123, y_predicted = 12618.35, y_true = 12915, difference = 296.65
# x = 124, y_predicted = 12810.20, y_true = 13051, difference = 240.80
# x = 125, y_predicted = 13005.55, y_true = 13387, difference = 381.45
# x = 126, y_predicted = 13204.49, y_true = 13309, difference = 104.51
# x = 127, y_predicted = 13407.12, y_true = 13732, difference = 324.88
# x = 128, y_predicted = 13613.54, y_true = 13162, difference = 451.54
# x = 129, y_predicted = 13823.83, y_true = 13644, difference = 179.83
# x = 130, y_predicted = 14038.10, y_true = 13808, difference = 230.10
# x = 131, y_predicted = 14256.46, y_true = 14101, difference = 155.46
# x = 132, y_predicted = 14479.01, y_true = 13992, difference = 487.01
# x = 133, y_predicted = 14705.85, y_true = 15191, difference = 485.15
# x = 134, y_predicted = 14937.10, y_true = 15018, difference = 80.90
# x = 135, y_predicted = 15172.87, y_true = 14917, difference = 255.87
# x = 136, y_predicted = 15413.27, y_true = 15046, difference = 367.27
# x = 137, y_predicted = 15658.43, y_true = 15556, difference = 102.43
# x = 138, y_predicted = 15908.46, y_true = 15893, difference = 15.46
# x = 139, y_predicted = 16163.48, y_true = 16388, difference = 224.52
# x = 140, y_predicted = 16423.62, y_true = 16782, difference = 358.38
# x = 141, y_predicted = 16689.01, y_true = 16716, difference = 26.99
# x = 142, y_predicted = 16959.79, y_true = 17033, difference = 73.21
# x = 143, y_predicted = 17236.07, y_true = 16896, difference = 340.07
# x = 144, y_predicted = 17518.01, y_true = 17689, difference = 170.99
# Total difference: 34374.30

# %% [markdown]
# ### Evaluate the Polynomial Degree 5 Model

# %%
# Evaluate the model

print (f'Using the Polynomial Model\n')

fitted_data = poly_model(months)
mse = mean_squared_error(data, fitted_data)
print(f'Polynomial Degree: {degree}')
print(f'Mean Squared Error: {mse}')
# Out:
# Using the Polynomial Model
#
# Polynomial Degree: 5
# Mean Squared Error: 79412.21257840593

# %% [markdown]
# ## Spline Model (Cubic Spline)

# %%
# Library Import

import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline

# Bag Production Data

data = [
    1863, 1614, 2570, 1685, 2101, 1811, 2457, 2171, 2134, 2502, 2358, 2399, 2048, 2523, 2086, 2391,
    2150, 2340, 3129, 2277, 2964, 2997, 2747, 2862, 3405, 2677, 2749, 2755, 2963, 3161, 3623, 2768,
    3141, 3439, 3601, 3531, 3477, 3376, 4027, 3175, 3274, 3334, 3964, 3649, 3502, 3688, 3657, 4422,
    4197, 4441, 4736, 4521, 4485, 4644, 5036, 4876, 4789, 4544, 4975, 5211, 4880, 4933, 5079, 5339,
    5232, 5520, 5714, 5260, 6110, 5334, 5988, 6235, 6365, 6266, 6345, 6118, 6497, 6278, 6638, 6590,
    6271, 7246, 6584, 6594, 7092, 7326, 7409, 7976, 7959, 8012, 8195, 8008, 8313, 7791, 8368, 8933,
    8756, 8613, 8705, 9098, 8769, 9544, 9050, 9186, 10012, 9685, 9966, 10048, 10244, 10740, 10318,
    10393, 10986, 10635, 10731, 11749, 11849, 12123, 12274, 11666, 11960, 12629, 12915, 13051,
    13387, 13309, 13732, 13162, 13644, 13808, 14101, 13992, 15191, 15018, 14917, 15046, 15556,
    15893, 16388, 16782, 16716, 17033, 16896, 17689
]

# Month 1 to Month 144

months = np.arange(1, 145)

# Fitting Spline  Model

spline_model = make_interp_spline(months, data, k=2)  # Cubic spline

# Prediction using Spline Model

months_new = np.linspace(1, len(data), 300)
spline_predictions = spline_model(months_new)

# Plot the True Value and Predicted Value

plt.figure(figsize=(10, 6))
plt.plot(months, data, label='Monthly Production', color='blue')
plt.plot(months_new, spline_predictions, label='Spline Model', color='green')
plt.xlabel('Month')
plt.ylabel('Production')
plt.title('Spline Model of Bag Production')
plt.legend()
plt.grid(True)
plt.show()

# Print the Spline Coefficients

spline_coeffs = spline_model.c
print('Spline Coefficients:')
print(spline_coeffs)
# Out:
# Spline Coefficients:
# [ 1863.           989.26173866  2967.9726098   1367.16042833
#   2309.06482024  1586.45065023  2660.23127839  2108.16167945
#   2058.79864491  2611.04645107  2290.92264867  2507.41765692
#   1856.57140982  2737.15388415  1904.50528529  2523.81440412
#   2080.60828997  2192.53585608  3484.17657353  1934.40470274
#   3125.39521     3025.22403724  2699.26056657  2755.21256335
#   3665.46405335  2492.00311657  2798.51724726  2708.89339988
#   2988.12235347  3066.3724793   3901.64277071  2507.77089641
#   3195.73185083  3445.8379986   3641.24015756  3514.72105606
#   3518.4335061   3190.67790735  4345.49904978  2952.32779394
#   3340.53418659  3196.46708653  4152.66329422  3599.55314814
#   3442.01781692  3764.33995036  3475.94248091  4636.00516418
#   4084.02653399  4435.83563185  4828.95967488  4478.40631886
#   4468.60241195  4589.97920944  5143.52233139  4836.88680221
#   4843.15685535  4416.17206572  5011.81075036  5312.96343211
#   4798.40865699  4936.58462594  5046.08358734  5418.91385002
#   5152.43331257  5522.48627458  5872.64903993  4953.61948586
#   6485.63404491  5012.57624467  6110.90848709  6225.97283282
#   6413.25451601  6214.50007111  6427.74505732  5979.02958498
#   6642.07743278  6144.50581833  6714.88765721  6670.16823838
#   5984.10291251  7593.21428658  6424.611368    6531.11750543
#   7140.68359944  7360.78089796  7302.63101282  8095.43302515
#   7932.77083629  7979.94195709  8283.57742118  7878.5935158
#   8508.86148399  7572.23758027  8385.71303436  9057.48421354
#   8733.38168438  8590.2256802   8629.26423443  9274.18891319
#   8509.60228641  9820.19736837  8921.2135034   9052.52161126
#  10251.65682905  9533.53741446 10027.11868418 10031.75048045
#  10166.37843314 10921.9789207  10221.74804267 10291.53282326
#  11173.05501777 10558.13707013 10558.12256148 11941.12756102
#  11787.11207241 12128.20000453 12427.68790041 11497.67259301
#  11914.27654154 12696.66815773 12937.71451206 12997.04476991
#  13488.01686846 13170.85401931 13958.85901566 12931.9918867
#  13745.18966412 13748.87012859 14225.58956436 13705.59248526
#  15476.85552406 14961.27437039 14899.49825359 14977.73610806
#  15602.08509802 15857.7533038  16395.39507917 16873.87622116
#  16617.34759386 17150.03821568 16645.51933614 17689.        ]

# %% [markdown]
# ### Difference checking between the True vs Predicted Value using Cubic Spline

# %%
def check_spline_accuracy(spline_model, x_values, y_actual):
    y_predicted = spline_model(x_values)
    total_diff = 0
    for x, y_pred, y_act in zip(x_values, y_predicted, y_actual):
        total_diff += abs(y_pred - y_act)
        print(f'Month {x:.0f}: y_predicted = {y_pred:.2f}, y_true = {y_act}, difference = {abs(y_pred - y_act):.2f}')
    return total_diff

# Checking the accuracy model from the difference and total difference of True vs Predicted Value

total_diff = check_spline_accuracy(spline_model, months, data)
print(f'Total difference: {total_diff:.2f}')
# Out:
# Month 1: y_predicted = 1863.00, y_true = 1863, difference = 0.00
# Month 2: y_predicted = 1614.00, y_true = 1614, difference = 0.00
# Month 3: y_predicted = 2570.00, y_true = 2570, difference = 0.00
# Month 4: y_predicted = 1685.00, y_true = 1685, difference = 0.00
# Month 5: y_predicted = 2101.00, y_true = 2101, difference = 0.00
# Month 6: y_predicted = 1811.00, y_true = 1811, difference = 0.00
# Month 7: y_predicted = 2457.00, y_true = 2457, difference = 0.00
# Month 8: y_predicted = 2171.00, y_true = 2171, difference = 0.00
# Month 9: y_predicted = 2134.00, y_true = 2134, difference = 0.00
# Month 10: y_predicted = 2502.00, y_true = 2502, difference = 0.00
# Month 11: y_predicted = 2358.00, y_true = 2358, difference = 0.00
# Month 12: y_predicted = 2399.00, y_true = 2399, difference = 0.00
# Month 13: y_predicted = 2048.00, y_true = 2048, difference = 0.00
# Month 14: y_predicted = 2523.00, y_true = 2523, difference = 0.00
# Month 15: y_predicted = 2086.00, y_true = 2086, difference = 0.00
# Month 16: y_predicted = 2391.00, y_true = 2391, difference = 0.00
# Month 17: y_predicted = 2150.00, y_true = 2150, difference = 0.00
# Month 18: y_predicted = 2340.00, y_true = 2340, difference = 0.00
# Month 19: y_predicted = 3129.00, y_true = 3129, difference = 0.00
# Month 20: y_predicted = 2277.00, y_true = 2277, difference = 0.00
# Month 21: y_predicted = 2964.00, y_true = 2964, difference = 0.00
# Month 22: y_predicted = 2997.00, y_true = 2997, difference = 0.00
# Month 23: y_predicted = 2747.00, y_true = 2747, difference = 0.00
# Month 24: y_predicted = 2862.00, y_true = 2862, difference = 0.00
# Month 25: y_predicted = 3405.00, y_true = 3405, difference = 0.00
# Month 26: y_predicted = 2677.00, y_true = 2677, difference = 0.00
# Month 27: y_predicted = 2749.00, y_true = 2749, difference = 0.00
# Month 28: y_predicted = 2755.00, y_true = 2755, difference = 0.00
# Month 29: y_predicted = 2963.00, y_true = 2963, difference = 0.00
# Month 30: y_predicted = 3161.00, y_true = 3161, difference = 0.00
# Month 31: y_predicted = 3623.00, y_true = 3623, difference = 0.00
# Month 32: y_predicted = 2768.00, y_true = 2768, difference = 0.00
# Month 33: y_predicted = 3141.00, y_true = 3141, difference = 0.00
# Month 34: y_predicted = 3439.00, y_true = 3439, difference = 0.00
# Month 35: y_predicted = 3601.00, y_true = 3601, difference = 0.00
# Month 36: y_predicted = 3531.00, y_true = 3531, difference = 0.00
# Month 37: y_predicted = 3477.00, y_true = 3477, difference = 0.00
# Month 38: y_predicted = 3376.00, y_true = 3376, difference = 0.00
# Month 39: y_predicted = 4027.00, y_true = 4027, difference = 0.00
# Month 40: y_predicted = 3175.00, y_true = 3175, difference = 0.00
# Month 41: y_predicted = 3274.00, y_true = 3274, difference = 0.00
# Month 42: y_predicted = 3334.00, y_true = 3334, difference = 0.00
# Month 43: y_predicted = 3964.00, y_true = 3964, difference = 0.00
# Month 44: y_predicted = 3649.00, y_true = 3649, difference = 0.00
# Month 45: y_predicted = 3502.00, y_true = 3502, difference = 0.00
# Month 46: y_predicted = 3688.00, y_true = 3688, difference = 0.00
# Month 47: y_predicted = 3657.00, y_true = 3657, difference = 0.00
# Month 48: y_predicted = 4422.00, y_true = 4422, difference = 0.00
# Month 49: y_predicted = 4197.00, y_true = 4197, difference = 0.00
# Month 50: y_predicted = 4441.00, y_true = 4441, difference = 0.00
# Month 51: y_predicted = 4736.00, y_true = 4736, difference = 0.00
# Month 52: y_predicted = 4521.00, y_true = 4521, difference = 0.00
# Month 53: y_predicted = 4485.00, y_true = 4485, difference = 0.00
# Month 54: y_predicted = 4644.00, y_true = 4644, difference = 0.00
# Month 55: y_predicted = 5036.00, y_true = 5036, difference = 0.00
# Month 56: y_predicted = 4876.00, y_true = 4876, difference = 0.00
# Month 57: y_predicted = 4789.00, y_true = 4789, difference = 0.00
# Month 58: y_predicted = 4544.00, y_true = 4544, difference = 0.00
# Month 59: y_predicted = 4975.00, y_true = 4975, difference = 0.00
# Month 60: y_predicted = 5211.00, y_true = 5211, difference = 0.00
# Month 61: y_predicted = 4880.00, y_true = 4880, difference = 0.00
# Month 62: y_predicted = 4933.00, y_true = 4933, difference = 0.00
# Month 63: y_predicted = 5079.00, y_true = 5079, difference = 0.00
# Month 64: y_predicted = 5339.00, y_true = 5339, difference = 0.00
# Month 65: y_predicted = 5232.00, y_true = 5232, difference = 0.00
# Month 66: y_predicted = 5520.00, y_true = 5520, difference = 0.00
# Month 67: y_predicted = 5714.00, y_true = 5714, difference = 0.00
# Month 68: y_predicted = 5260.00, y_true = 5260, difference = 0.00
# Month 69: y_predicted = 6110.00, y_true = 6110, difference = 0.00
# Month 70: y_predicted = 5334.00, y_true = 5334, difference = 0.00
# Month 71: y_predicted = 5988.00, y_true = 5988, difference = 0.00
# Month 72: y_predicted = 6235.00, y_true = 6235, difference = 0.00
# Month 73: y_predicted = 6365.00, y_true = 6365, difference = 0.00
# Month 74: y_predicted = 6266.00, y_true = 6266, difference = 0.00
# Month 75: y_predicted = 6345.00, y_true = 6345, difference = 0.00
# Month 76: y_predicted = 6118.00, y_true = 6118, difference = 0.00
# Month 77: y_predicted = 6497.00, y_true = 6497, difference = 0.00
# Month 78: y_predicted = 6278.00, y_true = 6278, difference = 0.00
# Month 79: y_predicted = 6638.00, y_true = 6638, difference = 0.00
# Month 80: y_predicted = 6590.00, y_true = 6590, difference = 0.00
# Month 81: y_predicted = 6271.00, y_true = 6271, difference = 0.00
# Month 82: y_predicted = 7246.00, y_true = 7246, difference = 0.00
# Month 83: y_predicted = 6584.00, y_true = 6584, difference = 0.00
# Month 84: y_predicted = 6594.00, y_true = 6594, difference = 0.00
# Month 85: y_predicted = 7092.00, y_true = 7092, difference = 0.00
# Month 86: y_predicted = 7326.00, y_true = 7326, difference = 0.00
# Month 87: y_predicted = 7409.00, y_true = 7409, difference = 0.00
# Month 88: y_predicted = 7976.00, y_true = 7976, difference = 0.00
# Month 89: y_predicted = 7959.00, y_true = 7959, difference = 0.00
# Month 90: y_predicted = 8012.00, y_true = 8012, difference = 0.00
# Month 91: y_predicted = 8195.00, y_true = 8195, difference = 0.00
# Month 92: y_predicted = 8008.00, y_true = 8008, difference = 0.00
# Month 93: y_predicted = 8313.00, y_true = 8313, difference = 0.00
# Month 94: y_predicted = 7791.00, y_true = 7791, difference = 0.00
# Month 95: y_predicted = 8368.00, y_true = 8368, difference = 0.00
# Month 96: y_predicted = 8933.00, y_true = 8933, difference = 0.00
# Month 97: y_predicted = 8756.00, y_true = 8756, difference = 0.00
# Month 98: y_predicted = 8613.00, y_true = 8613, difference = 0.00
# Month 99: y_predicted = 8705.00, y_true = 8705, difference = 0.00
# Month 100: y_predicted = 9098.00, y_true = 9098, difference = 0.00
# Month 101: y_predicted = 8769.00, y_true = 8769, difference = 0.00
# Month 102: y_predicted = 9544.00, y_true = 9544, difference = 0.00
# Month 103: y_predicted = 9050.00, y_true = 9050, difference = 0.00
# Month 104: y_predicted = 9186.00, y_true = 9186, difference = 0.00
# Month 105: y_predicted = 10012.00, y_true = 10012, difference = 0.00
# Month 106: y_predicted = 9685.00, y_true = 9685, difference = 0.00
# Month 107: y_predicted = 9966.00, y_true = 9966, difference = 0.00
# Month 108: y_predicted = 10048.00, y_true = 10048, difference = 0.00
# Month 109: y_predicted = 10244.00, y_true = 10244, difference = 0.00
# Month 110: y_predicted = 10740.00, y_true = 10740, difference = 0.00
# Month 111: y_predicted = 10318.00, y_true = 10318, difference = 0.00
# Month 112: y_predicted = 10393.00, y_true = 10393, difference = 0.00
# Month 113: y_predicted = 10986.00, y_true = 10986, difference = 0.00
# Month 114: y_predicted = 10635.00, y_true = 10635, difference = 0.00
# Month 115: y_predicted = 10731.00, y_true = 10731, difference = 0.00
# Month 116: y_predicted = 11749.00, y_true = 11749, difference = 0.00
# Month 117: y_predicted = 11849.00, y_true = 11849, difference = 0.00
# Month 118: y_predicted = 12123.00, y_true = 12123, difference = 0.00
# Month 119: y_predicted = 12274.00, y_true = 12274, difference = 0.00
# Month 120: y_predicted = 11666.00, y_true = 11666, difference = 0.00
# Month 121: y_predicted = 11960.00, y_true = 11960, difference = 0.00
# Month 122: y_predicted = 12629.00, y_true = 12629, difference = 0.00
# Month 123: y_predicted = 12915.00, y_true = 12915, difference = 0.00
# Month 124: y_predicted = 13051.00, y_true = 13051, difference = 0.00
# Month 125: y_predicted = 13387.00, y_true = 13387, difference = 0.00
# Month 126: y_predicted = 13309.00, y_true = 13309, difference = 0.00
# Month 127: y_predicted = 13732.00, y_true = 13732, difference = 0.00
# Month 128: y_predicted = 13162.00, y_true = 13162, difference = 0.00
# Month 129: y_predicted = 13644.00, y_true = 13644, difference = 0.00
# Month 130: y_predicted = 13808.00, y_true = 13808, difference = 0.00
# Month 131: y_predicted = 14101.00, y_true = 14101, difference = 0.00
# Month 132: y_predicted = 13992.00, y_true = 13992, difference = 0.00
# Month 133: y_predicted = 15191.00, y_true = 15191, difference = 0.00
# Month 134: y_predicted = 15018.00, y_true = 15018, difference = 0.00
# Month 135: y_predicted = 14917.00, y_true = 14917, difference = 0.00
# Month 136: y_predicted = 15046.00, y_true = 15046, difference = 0.00
# Month 137: y_predicted = 15556.00, y_true = 15556, difference = 0.00
# Month 138: y_predicted = 15893.00, y_true = 15893, difference = 0.00
# Month 139: y_predicted = 16388.00, y_true = 16388, difference = 0.00
# Month 140: y_predicted = 16782.00, y_true = 16782, difference = 0.00
# Month 141: y_predicted = 16716.00, y_true = 16716, difference = 0.00
# Month 142: y_predicted = 17033.00, y_true = 17033, difference = 0.00
# Month 143: y_predicted = 16896.00, y_true = 16896, difference = 0.00
# Month 144: y_predicted = 17689.00, y_true = 17689, difference = 0.00
# Total difference: 0.00

# %% [markdown]
# ### Evaluate the Spline Model (MSE)

# %%
# Spline Model Evaluation

spline_predictions_full = spline_model(months)
mse_spline = mean_squared_error(data, spline_predictions_full)
print(f'Mean Squared Error (Spline): {mse_spline}')
# Out:
# Mean Squared Error (Spline): 6.02075471897321e-25

# %% [markdown]
# ### Comparison Between Polynomial and Spline Model
#
# I'm testing between the two models to predict another value (variable x) if there is any fluctuation

# %%
# Predict Y Value when X Value is >= 145 using Polynomial and Spline Model

x_new = np.arange(145, 195)
poly_predictions_new = poly_model(x_new)
spline_predictions_new = spline_model(x_new)

# Print the prediction

print("Prediksi Menggunakan Model Polinomial:")
for i in range(len(x_new)):
    print(f"Month {x_new[i]}: {poly_predictions_new[i]:.2f}")

print("\nPrediksi Menggunakan Model Spline:")
for i in range(len(x_new)):
    print(f"Month {x_new[i]}: {spline_predictions_new[i]:.2f}")
# Out:
# Prediksi Menggunakan Model Polinomial:
# Month 145: 17805.73
# Month 146: 18099.39
# Month 147: 18399.13
# Month 148: 18705.09
# Month 149: 19017.43
# Month 150: 19336.29
# Month 151: 19661.85
# Month 152: 19994.25
# Month 153: 20333.66
# Month 154: 20680.25
# Month 155: 21034.18
# Month 156: 21395.63
# Month 157: 21764.77
# Month 158: 22141.78
# Month 159: 22526.85
# Month 160: 22920.16
# Month 161: 23321.89
# Month 162: 23732.25
# Month 163: 24151.42
# Month 164: 24579.60
# Month 165: 25016.99
# Month 166: 25463.81
# Month 167: 25920.26
# Month 168: 26386.55
# Month 169: 26862.90
# Month 170: 27349.52
# Month 171: 27846.65
# Month 172: 28354.50
# Month 173: 28873.31
# Month 174: 29403.32
# Month 175: 29944.75
# Month 176: 30497.86
# Month 177: 31062.88
# Month 178: 31640.07
# Month 179: 32229.68
# Month 180: 32831.97
# Month 181: 33447.19
# Month 182: 34075.61
# Month 183: 34717.51
# Month 184: 35373.15
# Month 185: 36042.81
# Month 186: 36726.77
# Month 187: 37425.32
# Month 188: 38138.74
# Month 189: 38867.33
# Month 190: 39611.38
# Month 191: 40371.21
# Month 192: 41147.10
# Month 193: 41939.38
# Month 194: 42748.35
#
# Prediksi Menggunakan Model Spline:
# Month 145: 19678.62
# Month 146: 22864.85
# Month 147: 27247.69
# Month 148: 32827.15
# Month 149: 39603.23
# Month 150: 47575.92
# Month 151: 56745.22
# Month 152: 67111.14
# Month 153: 78673.68
# Month 154: 91432.83
# Month 155: 105388.60
# Month 156: 120540.98
# Month 157: 136889.97
# Month 158: 154435.59
# Month 159: 173177.81
# Month 160: 193116.65
# Month 161: 214252.11
# Month 162: 236584.18
# Month 163: 260112.87
# Month 164: 284838.17
# Month 165: 310760.09
# Month 166: 337878.62
# Month 167: 366193.77
# Month 168: 395705.53
# Month 169: 426413.91
# Month 170: 458318.90
# Month 171: 491420.51
# Month 172: 525718.73
# Month 173: 561213.57
# Month 174: 597905.02
# Month 175: 635793.09
# Month 176: 674877.77
# Month 177: 715159.07
# Month 178: 756636.99
# Month 179: 799311.52
# Month 180: 843182.66
# Month 181: 888250.42
# Month 182: 934514.79
# Month 183: 981975.78
# Month 184: 1030633.38
# Month 185: 1080487.60
# Month 186: 1131538.44
# Month 187: 1183785.89
# Month 188: 1237229.95
# Month 189: 1291870.63
# Month 190: 1347707.93
# Month 191: 1404741.84
# Month 192: 1462972.36
# Month 193: 1522399.50
# Month 194: 1583023.26

# %% [markdown]
# ### Testing Result
#
# As you can see, there is a significant fluctuation if we are predict other X-value using Spline Model, so we ignore the Spline Model and we will using the Polynomial Equation Model

# %% [markdown]
# ### Conclusion
#
# We will use Polynomial Model Degree 5 with this details
# <br><br>
# Using the Polynomial Model
# <br><br>
# Polynomial Degree: 5
# <br><br>
# Mean Squared Error: 79412.21257840596
# <br><br>
# Polynomial Model Coefficient:
# <br><br>
# Coefficient of x^5: 0.0000002515
# <br><br>
# Coefficient of x^4: -0.0000625150
# <br><br>
# Coefficient of x^3: 0.0073252801
# <br><br>
# Coefficient of x^2: -0.0014574290
# <br><br>
# Coefficient of x^1: 35.5201677705
# <br><br>
# Coefficient of x^0: 1868.5382788214
# <br><br><br>
# Polynomial Equation: 0.0000002515x^5 + -0.0000625150x^4 + 0.0073252801x^3 + -0.0014574290x^2 + 35.5201677705x^1 + 1868.5382788214x^0

# %% [markdown]
# # Assurance of Learning (Number 2)

# %% [markdown]
# ## Taylor Series

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from sklearn.metrics import mean_squared_error

# Data

months = np.arange(1, 145)
data = [
    1863, 1614, 2570, 1685, 2101, 1811, 2457, 2171, 2134, 2502, 2358, 2399, 2048, 2523, 2086, 2391,
    2150, 2340, 3129, 2277, 2964, 2997, 2747, 2862, 3405, 2677, 2749, 2755, 2963, 3161, 3623, 2768,
    3141, 3439, 3601, 3531, 3477, 3376, 4027, 3175, 3274, 3334, 3964, 3649, 3502, 3688, 3657, 4422,
    4197, 4441, 4736, 4521, 4485, 4644, 5036, 4876, 4789, 4544, 4975, 5211, 4880, 4933, 5079, 5339,
    5232, 5520, 5714, 5260, 6110, 5334, 5988, 6235, 6365, 6266, 6345, 6118, 6497, 6278, 6638, 6590,
    6271, 7246, 6584, 6594, 7092, 7326, 7409, 7976, 7959, 8012, 8195, 8008, 8313, 7791, 8368, 8933,
    8756, 8613, 8705, 9098, 8769, 9544, 9050, 9186, 10012, 9685, 9966, 10048, 10244, 10740, 10318,
    10393, 10986, 10635, 10731, 11749, 11849, 12123, 12274, 11666, 11960, 12629, 12915, 13051,
    13387, 13309, 13732, 13162, 13644, 13808, 14101, 13992, 15191, 15018, 14917, 15046, 15556,
    15893, 16388, 16782, 16716, 17033, 16896, 17689
]

# Polynomial Model Equation Degree 5

poly_coeffs = np.polyfit(months, data, 5)
poly_model = np.poly1d(poly_coeffs)

# Find the derivative of Polynomial

poly_derivatives = [np.polyder(poly_model, m) for m in range(6)]

# Function to Print the polynomial equation and its derivative

def print_polynomial_function(poly):
    coeffs = poly.coefficients
    degree = len(coeffs) - 1
    func_str = " + ".join([f"{coeff:.10f}x^{degree - i}" if degree - i != 0 else f"{coeff:.10f}" for i, coeff in enumerate(coeffs)])
    return func_str

# Print the polynomial equation and its derivative

print("Polynomial Function and its Derivatives:")
for i, derivative in enumerate(poly_derivatives):
    if i == 0:
        print(f"F(x) = {print_polynomial_function(derivative)}")
    else:
        print(f"F^({i})(x) = {print_polynomial_function(derivative)}")

# Function to make a Taylor Series

def taylor_series_approximation(x, a, derivatives):
    approximation = 0
    terms = []
    print(f'\nEvaluating Taylor Series around a = {a} for x = {x}')
    for n, derivative in enumerate(derivatives):
        term_value = derivative(a) * ((x - a) ** n) / math.factorial(n)
        approximation += term_value
        term_str = f"{derivative(a):.10f} * (({x} - {a}) ** {n}) / {math.factorial(n)}"
        terms.append(term_str)
        print(f'Term {n}: {term_str} = {term_value}')
    return approximation, terms

a = len(months) // 2  # Point of a (Middle Value = 144/2 = 72)

# Taylor Series Value Printing

taylor_approximations = []
for x in months:
    approx, terms = taylor_series_approximation(x, a, poly_derivatives)
    taylor_approximations.append(approx)
    print(f'Taylor Series: {" + ".join(terms)}\nBag Production at x={x}: {approx}\n')

# Plotting the Original Data, Polynomial Model, and Taylor Series Model

plt.figure(figsize=(10, 6))
plt.plot(months, data, label='Monthly Production', color='blue')
plt.plot(months, poly_model(months), label='Polynomial Model (Degree 5)', color='red')
plt.plot(months, taylor_approximations, label='Taylor Series Approximation', color='green', linestyle='dashed')
plt.xlabel('Month')
plt.ylabel('Production')
plt.title('Taylor Series Approximation of Polynomial Model')
plt.legend()
plt.grid(True)
plt.show()

# Evaluate the Taylor Series Approximation

mse_taylor = mean_squared_error(data, taylor_approximations)
print(f'Mean Squared Error (Taylor Series Approximation): {mse_taylor}\n')

# Code to evaluate another Y value based on X-value given

# x_manual = 165  # Change any x-value
# approx_manual, terms_manual = taylor_series_approximation(x_manual, a, poly_derivatives)
# print(f'Taylor Series at x={x_manual}: {approx_manual}\nTerms: {" + ".join(terms_manual)}\n')
# Out:
# Polynomial Function and its Derivatives:
# F(x) = 0.0000002515x^5 + -0.0000625150x^4 + 0.0073252801x^3 + -0.0014574290x^2 + 35.5201677705x^1 + 1868.5382788214
# F^(1)(x) = 0.0000012575x^4 + -0.0002500599x^3 + 0.0219758402x^2 + -0.0029148581x^1 + 35.5201677705
# F^(2)(x) = 0.0000050299x^3 + -0.0007501797x^2 + 0.0439516805x^1 + -0.0029148581
# F^(3)(x) = 0.0000150897x^2 + -0.0015003593x^1 + 0.0439516805
# F^(4)(x) = 0.0000301794x^1 + -0.0015003593
# F^(5)(x) = 0.0000301794
#
# Evaluating Taylor Series around a = 72 for x = 1
# Term 0: 5959.1850514140 * ((1 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((1 - 72) ** 1) / 1 = -6368.125659583136
# Term 2: 1.1500753222 * ((1 - 72) ** 2) / 2 = 2898.764849704331
# Term 3: 0.0141508328 * ((1 - 72) ** 3) / 6 = -844.1231171484341
# Term 4: 0.0006725580 * ((1 - 72) ** 4) / 24 = 712.1179038131282
# Term 5: 0.0000301794 * ((1 - 72) ** 5) / 120 = -453.75477602040297
# Taylor Series: 5959.1850514140 * ((1 - 72) ** 0) / 1 + 89.6919106984 * ((1 - 72) ** 1) / 1 + 1.1500753222 * ((1 - 72) ** 2) / 2 + 0.0141508328 * ((1 - 72) ** 3) / 6 + 0.0006725580 * ((1 - 72) ** 4) / 24 + 0.0000301794 * ((1 - 72) ** 5) / 120
# Bag Production at x=1: 1904.0642521794525
#
#
# Evaluating Taylor Series around a = 72 for x = 2
# Term 0: 5959.1850514140 * ((2 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((2 - 72) ** 1) / 1 = -6278.433748884782
# Term 2: 1.1500753222 * ((2 - 72) ** 2) / 2 = 2817.6845394864554
# Term 3: 0.0141508328 * ((2 - 72) ** 3) / 6 = -808.955939275163
# Term 4: 0.0006725580 * ((2 - 72) ** 4) / 24 = 672.8382459449734
# Term 5: 0.0000301794 * ((2 - 72) ** 5) / 120 = -422.6877539902582
# Taylor Series: 5959.1850514140 * ((2 - 72) ** 0) / 1 + 89.6919106984 * ((2 - 72) ** 1) / 1 + 1.1500753222 * ((2 - 72) ** 2) / 2 + 0.0141508328 * ((2 - 72) ** 3) / 6 + 0.0006725580 * ((2 - 72) ** 4) / 24 + 0.0000301794 * ((2 - 72) ** 5) / 120
# Bag Production at x=2: 1939.6303946951923
#
#
# Evaluating Taylor Series around a = 72 for x = 3
# Term 0: 5959.1850514140 * ((3 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((3 - 72) ** 1) / 1 = -6188.741838186428
# Term 2: 1.1500753222 * ((3 - 72) ** 2) / 2 = 2737.754304590819
# Term 3: 0.0141508328 * ((3 - 72) ** 3) / 6 = -774.779319694882
# Term 4: 0.0006725580 * ((3 - 72) ** 4) / 24 = 635.2064112562463
# Term 5: 0.0000301794 * ((3 - 72) ** 5) / 120 = -393.346164145394
# Taylor Series: 5959.1850514140 * ((3 - 72) ** 0) / 1 + 89.6919106984 * ((3 - 72) ** 1) / 1 + 1.1500753222 * ((3 - 72) ** 2) / 2 + 0.0141508328 * ((3 - 72) ** 3) / 6 + 0.0006725580 * ((3 - 72) ** 4) / 24 + 0.0000301794 * ((3 - 72) ** 5) / 120
# Bag Production at x=3: 1975.278445234328
#
#
# Evaluating Taylor Series around a = 72 for x = 4
# Term 0: 5959.1850514140 * ((4 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((4 - 72) ** 1) / 1 = -6099.049927488075
# Term 2: 1.1500753222 * ((4 - 72) ** 2) / 2 = 2658.9741450174224
# Term 3: 0.0141508328 * ((4 - 72) ** 3) / 6 = -741.579107574834
# Term 4: 0.0006725580 * ((4 - 72) ** 4) / 24 = 599.1756569650125
# Term 5: 0.0000301794 * ((4 - 72) ** 5) / 120 = -365.6571156714241
# Taylor Series: 5959.1850514140 * ((4 - 72) ** 0) / 1 + 89.6919106984 * ((4 - 72) ** 1) / 1 + 1.1500753222 * ((4 - 72) ** 2) / 2 + 0.0141508328 * ((4 - 72) ** 3) / 6 + 0.0006725580 * ((4 - 72) ** 4) / 24 + 0.0000301794 * ((4 - 72) ** 5) / 120
# Bag Production at x=4: 2011.048702662069
#
#
# Evaluating Taylor Series around a = 72 for x = 5
# Term 0: 5959.1850514140 * ((5 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((5 - 72) ** 1) / 1 = -6009.358016789721
# Term 2: 1.1500753222 * ((5 - 72) ** 2) / 2 = 2581.344060766265
# Term 3: 0.0141508328 * ((5 - 72) ** 3) / 6 = -709.3411520822619
# Term 4: 0.0006725580 * ((5 - 72) ** 4) / 24 = 564.6999128473519
# Term 5: 0.0000301794 * ((5 - 72) ** 5) / 120 = -339.5498001330916
# Taylor Series: 5959.1850514140 * ((5 - 72) ** 0) / 1 + 89.6919106984 * ((5 - 72) ** 1) / 1 + 1.1500753222 * ((5 - 72) ** 2) / 2 + 0.0141508328 * ((5 - 72) ** 3) / 6 + 0.0006725580 * ((5 - 72) ** 4) / 24 + 0.0000301794 * ((5 - 72) ** 5) / 120
# Bag Production at x=5: 2046.9800560225094
#
#
# Evaluating Taylor Series around a = 72 for x = 6
# Term 0: 5959.1850514140 * ((6 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((6 - 72) ** 1) / 1 = -5919.666106091367
# Term 2: 1.1500753222 * ((6 - 72) ** 2) / 2 = 2504.864051837347
# Term 3: 0.0141508328 * ((6 - 72) ** 3) / 6 = -678.051302384409
# Term 4: 0.0006725580 * ((6 - 72) ** 4) / 24 = 531.733781237357
# Term 5: 0.0000301794 * ((6 - 72) ** 5) / 120 = -314.9554612948619
# Taylor Series: 5959.1850514140 * ((6 - 72) ** 0) / 1 + 89.6919106984 * ((6 - 72) ** 1) / 1 + 1.1500753222 * ((6 - 72) ** 2) / 2 + 0.0141508328 * ((6 - 72) ** 3) / 6 + 0.0006725580 * ((6 - 72) ** 4) / 24 + 0.0000301794 * ((6 - 72) ** 5) / 120
# Bag Production at x=6: 2083.110014718033
#
#
# Evaluating Taylor Series around a = 72 for x = 7
# Term 0: 5959.1850514140 * ((7 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((7 - 72) ** 1) / 1 = -5829.974195393012
# Term 2: 1.1500753222 * ((7 - 72) ** 2) / 2 = 2429.5341182306684
# Term 3: 0.0141508328 * ((7 - 72) ** 3) / 6 = -647.695407648518
# Term 4: 0.0006725580 * ((7 - 72) ** 4) / 24 = 500.2325370271342
# Term 5: 0.0000301794 * ((7 - 72) ** 5) / 120 = -291.80736494151427
# Taylor Series: 5959.1850514140 * ((7 - 72) ** 0) / 1 + 89.6919106984 * ((7 - 72) ** 1) / 1 + 1.1500753222 * ((7 - 72) ** 2) / 2 + 0.0141508328 * ((7 - 72) ** 3) / 6 + 0.0006725580 * ((7 - 72) ** 4) / 24 + 0.0000301794 * ((7 - 72) ** 5) / 120
# Bag Production at x=7: 2119.4747386887248
#
#
# Evaluating Taylor Series around a = 72 for x = 8
# Term 0: 5959.1850514140 * ((8 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((8 - 72) ** 1) / 1 = -5740.282284694658
# Term 2: 1.1500753222 * ((8 - 72) ** 2) / 2 = 2355.354259946229
# Term 3: 0.0141508328 * ((8 - 72) ** 3) / 6 = -618.2593170418319
# Term 4: 0.0006725580 * ((8 - 72) ** 4) / 24 = 470.15212766680315
# Term 5: 0.0000301794 * ((8 - 72) ** 5) / 120 = -270.04076869873455
# Taylor Series: 5959.1850514140 * ((8 - 72) ** 0) / 1 + 89.6919106984 * ((8 - 72) ** 1) / 1 + 1.1500753222 * ((8 - 72) ** 2) / 2 + 0.0141508328 * ((8 - 72) ** 3) / 6 + 0.0006725580 * ((8 - 72) ** 4) / 24 + 0.0000301794 * ((8 - 72) ** 5) / 120
# Bag Production at x=8: 2156.1090685917743
#
#
# Evaluating Taylor Series around a = 72 for x = 9
# Term 0: 5959.1850514140 * ((9 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((9 - 72) ** 1) / 1 = -5650.590373996304
# Term 2: 1.1500753222 * ((9 - 72) ** 2) / 2 = 2282.324476984029
# Term 3: 0.0141508328 * ((9 - 72) ** 3) / 6 = -589.7288797315939
# Term 4: 0.0006725580 * ((9 - 72) ** 4) / 24 = 441.4491731644971
# Term 5: 0.0000301794 * ((9 - 72) ** 5) / 120 = -249.59289185370758
# Taylor Series: 5959.1850514140 * ((9 - 72) ** 0) / 1 + 89.6919106984 * ((9 - 72) ** 1) / 1 + 1.1500753222 * ((9 - 72) ** 2) / 2 + 0.0141508328 * ((9 - 72) ** 3) / 6 + 0.0006725580 * ((9 - 72) ** 4) / 24 + 0.0000301794 * ((9 - 72) ** 5) / 120
# Bag Production at x=9: 2193.046555980887
#
#
# Evaluating Taylor Series around a = 72 for x = 10
# Term 0: 5959.1850514140 * ((10 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((10 - 72) ** 1) / 1 = -5560.89846329795
# Term 2: 1.1500753222 * ((10 - 72) ** 2) / 2 = 2210.4447693440684
# Term 3: 0.0141508328 * ((10 - 72) ** 3) / 6 = -562.0899448850469
# Term 4: 0.0006725580 * ((10 - 72) ** 4) / 24 = 414.0809660863626
# Term 5: 0.0000301794 * ((10 - 72) ** 5) / 120 = -230.4028851757093
# Taylor Series: 5959.1850514140 * ((10 - 72) ** 0) / 1 + 89.6919106984 * ((10 - 72) ** 1) / 1 + 1.1500753222 * ((10 - 72) ** 2) / 2 + 0.0141508328 * ((10 - 72) ** 3) / 6 + 0.0006725580 * ((10 - 72) ** 4) / 24 + 0.0000301794 * ((10 - 72) ** 5) / 120
# Bag Production at x=10: 2230.3194934856915
#
#
# Evaluating Taylor Series around a = 72 for x = 11
# Term 0: 5959.1850514140 * ((11 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((11 - 72) ** 1) / 1 = -5471.206552599596
# Term 2: 1.1500753222 * ((11 - 72) ** 2) / 2 = 2139.7151370263473
# Term 3: 0.0141508328 * ((11 - 72) ** 3) / 6 = -535.3283616694338
# Term 4: 0.0006725580 * ((11 - 72) ** 4) / 24 = 388.0054715565596
# Term 5: 0.0000301794 * ((11 - 72) ** 5) / 120 = -212.41180073669906
# Taylor Series: 5959.1850514140 * ((11 - 72) ** 0) / 1 + 89.6919106984 * ((11 - 72) ** 1) / 1 + 1.1500753222 * ((11 - 72) ** 2) / 2 + 0.0141508328 * ((11 - 72) ** 3) / 6 + 0.0006725580 * ((11 - 72) ** 4) / 24 + 0.0000301794 * ((11 - 72) ** 5) / 120
# Bag Production at x=11: 2267.958944991145
#
#
# Evaluating Taylor Series around a = 72 for x = 12
# Term 0: 5959.1850514140 * ((12 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((12 - 72) ** 1) / 1 = -5381.514641901242
# Term 2: 1.1500753222 * ((12 - 72) ** 2) / 2 = 2070.135580030865
# Term 3: 0.0141508328 * ((12 - 72) ** 3) / 6 = -509.42997925199774
# Term 4: 0.0006725580 * ((12 - 72) ** 4) / 24 = 363.1813272572618
# Term 5: 0.0000301794 * ((12 - 72) ** 5) / 120 = -195.56256173191215
# Taylor Series: 5959.1850514140 * ((12 - 72) ** 0) / 1 + 89.6919106984 * ((12 - 72) ** 1) / 1 + 1.1500753222 * ((12 - 72) ** 2) / 2 + 0.0141508328 * ((12 - 72) ** 3) / 6 + 0.0006725580 * ((12 - 72) ** 4) / 24 + 0.0000301794 * ((12 - 72) ** 5) / 120
# Bag Production at x=12: 2305.9947758169424
#
#
# Evaluating Taylor Series around a = 72 for x = 13
# Term 0: 5959.1850514140 * ((13 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((13 - 72) ** 1) / 1 = -5291.8227312028885
# Term 2: 1.1500753222 * ((13 - 72) ** 2) / 2 = 2001.7060983576227
# Term 3: 0.0141508328 * ((13 - 72) ** 3) / 6 = -484.38064679998166
# Term 4: 0.0006725580 * ((13 - 72) ** 4) / 24 = 339.567843428656
# Term 5: 0.0000301794 * ((13 - 72) ** 5) / 120 = -179.79993230045207
# Taylor Series: 5959.1850514140 * ((13 - 72) ** 0) / 1 + 89.6919106984 * ((13 - 72) ** 1) / 1 + 1.1500753222 * ((13 - 72) ** 2) / 2 + 0.0141508328 * ((13 - 72) ** 3) / 6 + 0.0006725580 * ((13 - 72) ** 4) / 24 + 0.0000301794 * ((13 - 72) ** 5) / 120
# Bag Production at x=13: 2344.455682896924
#
#
# Evaluating Taylor Series around a = 72 for x = 14
# Term 0: 5959.1850514140 * ((14 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((14 - 72) ** 1) / 1 = -5202.130820504534
# Term 2: 1.1500753222 * ((14 - 72) ** 2) / 2 = 1934.4266920066198
# Term 3: 0.0141508328 * ((14 - 72) ** 3) / 6 = -460.1662134806286
# Term 4: 0.0006725580 * ((14 - 72) ** 4) / 24 = 317.12500286894243
# Term 5: 0.0000301794 * ((14 - 72) ** 5) / 120 = -165.07048734588267
# Taylor Series: 5959.1850514140 * ((14 - 72) ** 0) / 1 + 89.6919106984 * ((14 - 72) ** 1) / 1 + 1.1500753222 * ((14 - 72) ** 2) / 2 + 0.0141508328 * ((14 - 72) ** 3) / 6 + 0.0006725580 * ((14 - 72) ** 4) / 24 + 0.0000301794 * ((14 - 72) ** 5) / 120
# Bag Production at x=14: 2383.3692249584833
#
#
# Evaluating Taylor Series around a = 72 for x = 15
# Term 0: 5959.1850514140 * ((15 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((15 - 72) ** 1) / 1 = -5112.43890980618
# Term 2: 1.1500753222 * ((15 - 72) ** 2) / 2 = 1868.297360977856
# Term 3: 0.0141508328 * ((15 - 72) ** 3) / 6 = -436.77252846118154
# Term 4: 0.0006725580 * ((15 - 72) ** 4) / 24 = 295.81346093433507
# Term 5: 0.0000301794 * ((15 - 72) ** 5) / 120 = -151.32258235682062
# Taylor Series: 5959.1850514140 * ((15 - 72) ** 0) / 1 + 89.6919106984 * ((15 - 72) ** 1) / 1 + 1.1500753222 * ((15 - 72) ** 2) / 2 + 0.0141508328 * ((15 - 72) ** 3) / 6 + 0.0006725580 * ((15 - 72) ** 4) / 24 + 0.0000301794 * ((15 - 72) ** 5) / 120
# Bag Production at x=15: 2422.761852701976
#
#
# Evaluating Taylor Series around a = 72 for x = 16
# Term 0: 5959.1850514140 * ((16 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((16 - 72) ** 1) / 1 = -5022.746999107826
# Term 2: 1.1500753222 * ((16 - 72) ** 2) / 2 = 1803.3181052713314
# Term 3: 0.0141508328 * ((16 - 72) ** 3) / 6 = -414.1854409088835
# Term 4: 0.0006725580 * ((16 - 72) ** 4) / 24 = 275.59454553906113
# Term 5: 0.0000301794 * ((16 - 72) ** 5) / 120 = -138.50632322752782
# Taylor Series: 5959.1850514140 * ((16 - 72) ** 0) / 1 + 89.6919106984 * ((16 - 72) ** 1) / 1 + 1.1500753222 * ((16 - 72) ** 2) / 2 + 0.0141508328 * ((16 - 72) ** 3) / 6 + 0.0006725580 * ((16 - 72) ** 4) / 24 + 0.0000301794 * ((16 - 72) ** 5) / 120
# Bag Production at x=16: 2462.658938980122
#
#
# Evaluating Taylor Series around a = 72 for x = 17
# Term 0: 5959.1850514140 * ((17 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((17 - 72) ** 1) / 1 = -4933.055088409472
# Term 2: 1.1500753222 * ((17 - 72) ** 2) / 2 = 1739.4889248870466
# Term 3: 0.0141508328 * ((17 - 72) ** 3) / 6 = -392.3907999909774
# Term 4: 0.0006725580 * ((17 - 72) ** 4) / 24 = 256.4302571553612
# Term 5: 0.0000301794 * ((17 - 72) ** 5) / 120 = -126.57353607850352
# Taylor Series: 5959.1850514140 * ((17 - 72) ** 0) / 1 + 89.6919106984 * ((17 - 72) ** 1) / 1 + 1.1500753222 * ((17 - 72) ** 2) / 2 + 0.0141508328 * ((17 - 72) ** 3) / 6 + 0.0006725580 * ((17 - 72) ** 4) / 24 + 0.0000301794 * ((17 - 72) ** 5) / 120
# Bag Production at x=17: 2503.084808977422
#
#
# Evaluating Taylor Series around a = 72 for x = 18
# Term 0: 5959.1850514140 * ((18 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((18 - 72) ** 1) / 1 = -4843.363177711118
# Term 2: 1.1500753222 * ((18 - 72) ** 2) / 2 = 1676.809819825001
# Term 3: 0.0141508328 * ((18 - 72) ** 3) / 6 = -371.3744548747063
# Term 4: 0.0006725580 * ((18 - 72) ** 4) / 24 = 238.28326881348949
# Term 5: 0.0000301794 * ((18 - 72) ** 5) / 120 = -115.47773707707682
# Taylor Series: 5959.1850514140 * ((18 - 72) ** 0) / 1 + 89.6919106984 * ((18 - 72) ** 1) / 1 + 1.1500753222 * ((18 - 72) ** 2) / 2 + 0.0141508328 * ((18 - 72) ** 3) / 6 + 0.0006725580 * ((18 - 72) ** 4) / 24 + 0.0000301794 * ((18 - 72) ** 5) / 120
# Bag Production at x=18: 2544.0627703895566
#
#
# Evaluating Taylor Series around a = 72 for x = 19
# Term 0: 5959.1850514140 * ((19 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((19 - 72) ** 1) / 1 = -4753.671267012764
# Term 2: 1.1500753222 * ((19 - 72) ** 2) / 2 = 1615.2807900851947
# Term 3: 0.0141508328 * ((19 - 72) ** 3) / 6 = -351.12225472731325
# Term 4: 0.0006725580 * ((19 - 72) ** 4) / 24 = 221.11692610171346
# Term 5: 0.0000301794 * ((19 - 72) ** 5) / 120 = -105.1741022579989
# Taylor Series: 5959.1850514140 * ((19 - 72) ** 0) / 1 + 89.6919106984 * ((19 - 72) ** 1) / 1 + 1.1500753222 * ((19 - 72) ** 2) / 2 + 0.0141508328 * ((19 - 72) ** 3) / 6 + 0.0006725580 * ((19 - 72) ** 4) / 24 + 0.0000301794 * ((19 - 72) ** 5) / 120
# Bag Production at x=19: 2585.6151436027994
#
#
# Evaluating Taylor Series around a = 72 for x = 20
# Term 0: 5959.1850514140 * ((20 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((20 - 72) ** 1) / 1 = -4663.97935631441
# Term 2: 1.1500753222 * ((20 - 72) ** 2) / 2 = 1554.9018356676277
# Term 3: 0.0141508328 * ((20 - 72) ** 3) / 6 = -331.6200487160412
# Term 4: 0.0006725580 * ((20 - 72) ** 4) / 24 = 204.89524716631414
# Term 5: 0.0000301794 * ((20 - 72) ** 5) / 120 = -95.61943734403538
# Taylor Series: 5959.1850514140 * ((20 - 72) ** 0) / 1 + 89.6919106984 * ((20 - 72) ** 1) / 1 + 1.1500753222 * ((20 - 72) ** 2) / 2 + 0.0141508328 * ((20 - 72) ** 3) / 6 + 0.0006725580 * ((20 - 72) ** 4) / 24 + 0.0000301794 * ((20 - 72) ** 5) / 120
# Bag Production at x=20: 2627.763291873422
#
#
# Evaluating Taylor Series around a = 72 for x = 21
# Term 0: 5959.1850514140 * ((21 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((21 - 72) ** 1) / 1 = -4574.287445616056
# Term 2: 1.1500753222 * ((21 - 72) ** 2) / 2 = 1495.6729565723
# Term 3: 0.0141508328 * ((21 - 72) ** 3) / 6 = -312.85368600813314
# Term 4: 0.0006725580 * ((21 - 72) ** 4) / 24 = 189.582922711586
# Term 5: 0.0000301794 * ((21 - 72) ** 5) / 120 = -86.77214756655864
# Taylor Series: 5959.1850514140 * ((21 - 72) ** 0) / 1 + 89.6919106984 * ((21 - 72) ** 1) / 1 + 1.1500753222 * ((21 - 72) ** 2) / 2 + 0.0141508328 * ((21 - 72) ** 3) / 6 + 0.0006725580 * ((21 - 72) ** 4) / 24 + 0.0000301794 * ((21 - 72) ** 5) / 120
# Bag Production at x=21: 2670.527651507105
#
#
# Evaluating Taylor Series around a = 72 for x = 22
# Term 0: 5959.1850514140 * ((22 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((22 - 72) ** 1) / 1 = -4484.595534917702
# Term 2: 1.1500753222 * ((22 - 72) ** 2) / 2 = 1437.594152799212
# Term 3: 0.0141508328 * ((22 - 72) ** 3) / 6 = -294.809015770832
# Term 4: 0.0006725580 * ((22 - 72) ** 4) / 24 = 175.14531599983692
# Term 5: 0.0000301794 * ((22 - 72) ** 5) / 120 = -78.59220748614011
# Taylor Series: 5959.1850514140 * ((22 - 72) ** 0) / 1 + 89.6919106984 * ((22 - 72) ** 1) / 1 + 1.1500753222 * ((22 - 72) ** 2) / 2 + 0.0141508328 * ((22 - 72) ** 3) / 6 + 0.0006725580 * ((22 - 72) ** 4) / 24 + 0.0000301794 * ((22 - 72) ** 5) / 120
# Bag Production at x=22: 2713.9277620383414
#
#
# Evaluating Taylor Series around a = 72 for x = 23
# Term 0: 5959.1850514140 * ((23 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((23 - 72) ** 1) / 1 = -4394.903624219348
# Term 2: 1.1500753222 * ((23 - 72) ** 2) / 2 = 1380.665424348363
# Term 3: 0.0141508328 * ((23 - 72) ** 3) / 6 = -277.47188717138096
# Term 4: 0.0006725580 * ((23 - 72) ** 4) / 24 = 161.5484628513881
# Term 5: 0.0000301794 * ((23 - 72) ** 5) / 120 = -71.0411308131427
# Taylor Series: 5959.1850514140 * ((23 - 72) ** 0) / 1 + 89.6919106984 * ((23 - 72) ** 1) / 1 + 1.1500753222 * ((23 - 72) ** 2) / 2 + 0.0141508328 * ((23 - 72) ** 3) / 6 + 0.0006725580 * ((23 - 72) ** 4) / 24 + 0.0000301794 * ((23 - 72) ** 5) / 120
# Bag Production at x=23: 2757.9822964098466
#
#
# Evaluating Taylor Series around a = 72 for x = 24
# Term 0: 5959.1850514140 * ((24 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((24 - 72) ** 1) / 1 = -4305.211713520994
# Term 2: 1.1500753222 * ((24 - 72) ** 2) / 2 = 1324.8867712197539
# Term 3: 0.0141508328 * ((24 - 72) ** 3) / 6 = -260.82814937702284
# Term 4: 0.0006725580 * ((24 - 72) ** 4) / 24 = 148.75907164457445
# Term 5: 0.0000301794 * ((24 - 72) ** 5) / 120 = -64.08194022831299
# Taylor Series: 5959.1850514140 * ((24 - 72) ** 0) / 1 + 89.6919106984 * ((24 - 72) ** 1) / 1 + 1.1500753222 * ((24 - 72) ** 2) / 2 + 0.0141508328 * ((24 - 72) ** 3) / 6 + 0.0006725580 * ((24 - 72) ** 4) / 24 + 0.0000301794 * ((24 - 72) ** 5) / 120
# Bag Production at x=24: 2802.7090911519654
#
#
# Evaluating Taylor Series around a = 72 for x = 25
# Term 0: 5959.1850514140 * ((25 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((25 - 72) ** 1) / 1 = -4215.51980282264
# Term 2: 1.1500753222 * ((25 - 72) ** 2) / 2 = 1270.2581934133837
# Term 3: 0.0141508328 * ((25 - 72) ** 3) / 6 = -244.86365155500073
# Term 4: 0.0006725580 * ((25 - 72) ** 4) / 24 = 136.74452331574403
# Term 5: 0.0000301794 * ((25 - 72) ** 5) / 120 = -57.67913720337363
# Taylor Series: 5959.1850514140 * ((25 - 72) ** 0) / 1 + 89.6919106984 * ((25 - 72) ** 1) / 1 + 1.1500753222 * ((25 - 72) ** 2) / 2 + 0.0141508328 * ((25 - 72) ** 3) / 6 + 0.0006725580 * ((25 - 72) ** 4) / 24 + 0.0000301794 * ((25 - 72) ** 5) / 120
# Bag Production at x=25: 2848.125176562081
#
#
# Evaluating Taylor Series around a = 72 for x = 26
# Term 0: 5959.1850514140 * ((26 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((26 - 72) ** 1) / 1 = -4125.827892124285
# Term 2: 1.1500753222 * ((26 - 72) ** 2) / 2 = 1216.779690929253
# Term 3: 0.0141508328 * ((26 - 72) ** 3) / 6 = -229.56424287255766
# Term 4: 0.0006725580 * ((26 - 72) ** 4) / 24 = 125.47287135925852
# Term 5: 0.0000301794 * ((26 - 72) ** 5) / 120 = -51.79867182161568
# Taylor Series: 5959.1850514140 * ((26 - 72) ** 0) / 1 + 89.6919106984 * ((26 - 72) ** 1) / 1 + 1.1500753222 * ((26 - 72) ** 2) / 2 + 0.0141508328 * ((26 - 72) ** 3) / 6 + 0.0006725580 * ((26 - 72) ** 4) / 24 + 0.0000301794 * ((26 - 72) ** 5) / 120
# Bag Production at x=26: 2894.2468068840194
#
#
# Evaluating Taylor Series around a = 72 for x = 27
# Term 0: 5959.1850514140 * ((27 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((27 - 72) ** 1) / 1 = -4036.1359814259317
# Term 2: 1.1500753222 * ((27 - 72) ** 2) / 2 = 1164.4512637673618
# Term 3: 0.0141508328 * ((27 - 72) ** 3) / 6 = -214.91577249693657
# Term 4: 0.0006725580 * ((27 - 72) ** 4) / 24 = 114.91284182749298
# Term 5: 0.0000301794 * ((27 - 72) ** 5) / 120 = -46.407912598490874
# Taylor Series: 5959.1850514140 * ((27 - 72) ** 0) / 1 + 89.6919106984 * ((27 - 72) ** 1) / 1 + 1.1500753222 * ((27 - 72) ** 2) / 2 + 0.0141508328 * ((27 - 72) ** 3) / 6 + 0.0006725580 * ((27 - 72) ** 4) / 24 + 0.0000301794 * ((27 - 72) ** 5) / 120
# Bag Production at x=27: 2941.089490487463
#
#
# Evaluating Taylor Series around a = 72 for x = 28
# Term 0: 5959.1850514140 * ((28 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((28 - 72) ** 1) / 1 = -3946.4440707275776
# Term 2: 1.1500753222 * ((28 - 72) ** 2) / 2 = 1113.2729119277099
# Term 3: 0.0141508328 * ((28 - 72) ** 3) / 6 = -200.90408959538044
# Term 4: 0.0006725580 * ((28 - 72) ** 4) / 24 = 105.03383333083595
# Term 5: 0.0000301794 * ((28 - 72) ** 5) / 120 = -41.47561630220403
# Taylor Series: 5959.1850514140 * ((28 - 72) ** 0) / 1 + 89.6919106984 * ((28 - 72) ** 1) / 1 + 1.1500753222 * ((28 - 72) ** 2) / 2 + 0.0141508328 * ((28 - 72) ** 3) / 6 + 0.0006725580 * ((28 - 72) ** 4) / 24 + 0.0000301794 * ((28 - 72) ** 5) / 120
# Bag Production at x=28: 2988.6680200473506
#
#
# Evaluating Taylor Series around a = 72 for x = 29
# Term 0: 5959.1850514140 * ((29 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((29 - 72) ** 1) / 1 = -3856.7521600292234
# Term 2: 1.1500753222 * ((29 - 72) ** 2) / 2 = 1063.2446354102972
# Term 3: 0.0141508328 * ((29 - 72) ** 3) / 6 = -187.51504333513233
# Term 4: 0.0006725580 * ((29 - 72) ** 4) / 24 = 95.80591703768935
# Term 5: 0.0000301794 * ((29 - 72) ** 5) / 120 = -36.97189777430529
# Taylor Series: 5959.1850514140 * ((29 - 72) ** 0) / 1 + 89.6919106984 * ((29 - 72) ** 1) / 1 + 1.1500753222 * ((29 - 72) ** 2) / 2 + 0.0141508328 * ((29 - 72) ** 3) / 6 + 0.0006725580 * ((29 - 72) ** 4) / 24 + 0.0000301794 * ((29 - 72) ** 5) / 120
# Bag Production at x=29: 3036.996502723292
#
#
# Evaluating Taylor Series around a = 72 for x = 30
# Term 0: 5959.1850514140 * ((30 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((30 - 72) ** 1) / 1 = -3767.0602493308697
# Term 2: 1.1500753222 * ((30 - 72) ** 2) / 2 = 1014.366434215124
# Term 3: 0.0141508328 * ((30 - 72) ** 3) / 6 = -174.73448288343522
# Term 4: 0.0006725580 * ((30 - 72) ** 4) / 24 = 87.19983667446856
# Term 5: 0.0000301794 * ((30 - 72) ** 5) / 120 = -32.86819975028248
# Taylor Series: 5959.1850514140 * ((30 - 72) ** 0) / 1 + 89.6919106984 * ((30 - 72) ** 1) / 1 + 1.1500753222 * ((30 - 72) ** 2) / 2 + 0.0141508328 * ((30 - 72) ** 3) / 6 + 0.0006725580 * ((30 - 72) ** 4) / 24 + 0.0000301794 * ((30 - 72) ** 5) / 120
# Bag Production at x=30: 3086.088390338972
#
#
# Evaluating Taylor Series around a = 72 for x = 31
# Term 0: 5959.1850514140 * ((31 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((31 - 72) ** 1) / 1 = -3677.3683386325156
# Term 2: 1.1500753222 * ((31 - 72) ** 2) / 2 = 966.6383083421902
# Term 3: 0.0141508328 * ((31 - 72) ** 3) / 6 = -162.5482574075321
# Term 4: 0.0006725580 * ((31 - 72) ** 4) / 24 = 79.18700852560242
# Term 5: 0.0000301794 * ((31 - 72) ** 5) / 120 = -29.137262680153455
# Taylor Series: 5959.1850514140 * ((31 - 72) ** 0) / 1 + 89.6919106984 * ((31 - 72) ** 1) / 1 + 1.1500753222 * ((31 - 72) ** 2) / 2 + 0.0141508328 * ((31 - 72) ** 3) / 6 + 0.0006725580 * ((31 - 72) ** 4) / 24 + 0.0000301794 * ((31 - 72) ** 5) / 120
# Bag Production at x=31: 3135.956509561558
#
#
# Evaluating Taylor Series around a = 72 for x = 32
# Term 0: 5959.1850514140 * ((32 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((32 - 72) ** 1) / 1 = -3587.6764279341614
# Term 2: 1.1500753222 * ((32 - 72) ** 2) / 2 = 920.0602577914957
# Term 3: 0.0141508328 * ((32 - 72) ** 3) / 6 = -150.942216074666
# Term 4: 0.0006725580 * ((32 - 72) ** 4) / 24 = 71.7395214335332
# Term 5: 0.0000301794 * ((32 - 72) ** 5) / 120 = -25.753094549058396
# Taylor Series: 5959.1850514140 * ((32 - 72) ** 0) / 1 + 89.6919106984 * ((32 - 72) ** 1) / 1 + 1.1500753222 * ((32 - 72) ** 2) / 2 + 0.0141508328 * ((32 - 72) ** 3) / 6 + 0.0006725580 * ((32 - 72) ** 4) / 24 + 0.0000301794 * ((32 - 72) ** 5) / 120
# Bag Production at x=32: 3186.61309208111
#
#
# Evaluating Taylor Series around a = 72 for x = 33
# Term 0: 5959.1850514140 * ((33 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((33 - 72) ** 1) / 1 = -3497.9845172358073
# Term 2: 1.1500753222 * ((33 - 72) ** 2) / 2 = 874.6322825630406
# Term 3: 0.0141508328 * ((33 - 72) ** 3) / 6 = -139.90220805207989
# Term 4: 0.0006725580 * ((33 - 72) ** 4) / 24 = 64.8301367987166
# Term 5: 0.0000301794 * ((33 - 72) ** 5) / 120 = -22.69094069785215
# Taylor Series: 5959.1850514140 * ((33 - 72) ** 0) / 1 + 89.6919106984 * ((33 - 72) ** 1) / 1 + 1.1500753222 * ((33 - 72) ** 2) / 2 + 0.0141508328 * ((33 - 72) ** 3) / 6 + 0.0006725580 * ((33 - 72) ** 4) / 24 + 0.0000301794 * ((33 - 72) ** 5) / 120
# Bag Production at x=33: 3238.0698047899846
#
#
# Evaluating Taylor Series around a = 72 for x = 34
# Term 0: 5959.1850514140 * ((34 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((34 - 72) ** 1) / 1 = -3408.292606537453
# Term 2: 1.1500753222 * ((34 - 72) ** 2) / 2 = 830.3543826568249
# Term 3: 0.0141508328 * ((34 - 72) ** 3) / 6 = -129.41408250701676
# Term 4: 0.0006725580 * ((34 - 72) ** 4) / 24 = 58.43228857962175
# Term 5: 0.0000301794 * ((34 - 72) ** 5) / 120 = -19.92725364369654
# Taylor Series: 5959.1850514140 * ((34 - 72) ** 0) / 1 + 89.6919106984 * ((34 - 72) ** 1) / 1 + 1.1500753222 * ((34 - 72) ** 2) / 2 + 0.0141508328 * ((34 - 72) ** 3) / 6 + 0.0006725580 * ((34 - 72) ** 4) / 24 + 0.0000301794 * ((34 - 72) ** 5) / 120
# Bag Production at x=34: 3290.337779962247
#
#
# Evaluating Taylor Series around a = 72 for x = 35
# Term 0: 5959.1850514140 * ((35 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((35 - 72) ** 1) / 1 = -3318.6006958390994
# Term 2: 1.1500753222 * ((35 - 72) ** 2) / 2 = 787.2265580728484
# Term 3: 0.0141508328 * ((35 - 72) ** 3) / 6 = -119.46368860671964
# Term 4: 0.0006725580 * ((35 - 72) ** 4) / 24 = 52.52008329273125
# Term 5: 0.0000301794 * ((35 - 72) ** 5) / 120 = -17.43966290065273
# Taylor Series: 5959.1850514140 * ((35 - 72) ** 0) / 1 + 89.6919106984 * ((35 - 72) ** 1) / 1 + 1.1500753222 * ((35 - 72) ** 2) / 2 + 0.0141508328 * ((35 - 72) ** 3) / 6 + 0.0006725580 * ((35 - 72) ** 4) / 24 + 0.0000301794 * ((35 - 72) ** 5) / 120
# Bag Production at x=35: 3343.4276454330748
#
#
# Evaluating Taylor Series around a = 72 for x = 36
# Term 0: 5959.1850514140 * ((36 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((36 - 72) ** 1) / 1 = -3228.9087851407453
# Term 2: 1.1500753222 * ((36 - 72) ** 2) / 2 = 745.2488088111115
# Term 3: 0.0141508328 * ((36 - 72) ** 3) / 6 = -110.0368755184315
# Term 4: 0.0006725580 * ((36 - 72) ** 4) / 24 = 47.06830001254113
# Term 5: 0.0000301794 * ((36 - 72) ** 5) / 120 = -15.206944800273492
# Taylor Series: 5959.1850514140 * ((36 - 72) ** 0) / 1 + 89.6919106984 * ((36 - 72) ** 1) / 1 + 1.1500753222 * ((36 - 72) ** 2) / 2 + 0.0141508328 * ((36 - 72) ** 3) / 6 + 0.0006725580 * ((36 - 72) ** 4) / 24 + 0.0000301794 * ((36 - 72) ** 5) / 120
# Bag Production at x=36: 3397.3495547781695
#
#
# Evaluating Taylor Series around a = 72 for x = 37
# Term 0: 5959.1850514140 * ((37 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((37 - 72) ** 1) / 1 = -3139.216874442391
# Term 2: 1.1500753222 * ((37 - 72) ** 2) / 2 = 704.4211348716138
# Term 3: 0.0141508328 * ((37 - 72) ** 3) / 6 = -101.11949240939538
# Term 4: 0.0006725580 * ((37 - 72) ** 4) / 24 = 42.05239037156084
# Term 5: 0.0000301794 * ((37 - 72) ** 5) / 120 = -13.20899231219557
# Taylor Series: 5959.1850514140 * ((37 - 72) ** 0) / 1 + 89.6919106984 * ((37 - 72) ** 1) / 1 + 1.1500753222 * ((37 - 72) ** 2) / 2 + 0.0141508328 * ((37 - 72) ** 3) / 6 + 0.0006725580 * ((37 - 72) ** 4) / 24 + 0.0000301794 * ((37 - 72) ** 5) / 120
# Bag Production at x=37: 3452.1132174931595
#
#
# Evaluating Taylor Series around a = 72 for x = 38
# Term 0: 5959.1850514140 * ((38 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((38 - 72) ** 1) / 1 = -3049.5249637440374
# Term 2: 1.1500753222 * ((38 - 72) ** 2) / 2 = 664.7435362543556
# Term 3: 0.0141508328 * ((38 - 72) ** 3) / 6 = -92.69738844685425
# Term 4: 0.0006725580 * ((38 - 72) ** 4) / 24 = 37.44847856031328
# Term 5: 0.0000301794 * ((38 - 72) ** 5) / 120 = -11.426784864732003
# Taylor Series: 5959.1850514140 * ((38 - 72) ** 0) / 1 + 89.6919106984 * ((38 - 72) ** 1) / 1 + 1.1500753222 * ((38 - 72) ** 2) / 2 + 0.0141508328 * ((38 - 72) ** 3) / 6 + 0.0006725580 * ((38 - 72) ** 4) / 24 + 0.0000301794 * ((38 - 72) ** 5) / 120
# Bag Production at x=38: 3507.727929173012
#
#
# Evaluating Taylor Series around a = 72 for x = 39
# Term 0: 5959.1850514140 * ((39 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((39 - 72) ** 1) / 1 = -2959.8330530456833
# Term 2: 1.1500753222 * ((39 - 72) ** 2) / 2 = 626.2160129593367
# Term 3: 0.0141508328 * ((39 - 72) ** 3) / 6 = -84.75641279805113
# Term 4: 0.0006725580 * ((39 - 72) ** 4) / 24 = 33.23336132733481
# Term 5: 0.0000301794 * ((39 - 72) ** 5) / 120 = -9.842358165464434
# Taylor Series: 5959.1850514140 * ((39 - 72) ** 0) / 1 + 89.6919106984 * ((39 - 72) ** 1) / 1 + 1.1500753222 * ((39 - 72) ** 2) / 2 + 0.0141508328 * ((39 - 72) ** 3) / 6 + 0.0006725580 * ((39 - 72) ** 4) / 24 + 0.0000301794 * ((39 - 72) ** 5) / 120
# Bag Production at x=39: 3564.2026016914397
#
#
# Evaluating Taylor Series around a = 72 for x = 40
# Term 0: 5959.1850514140 * ((40 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((40 - 72) ** 1) / 1 = -2870.141142347329
# Term 2: 1.1500753222 * ((40 - 72) ** 2) / 2 = 588.8385649865572
# Term 3: 0.0141508328 * ((40 - 72) ** 3) / 6 = -77.28241463022898
# Term 4: 0.0006725580 * ((40 - 72) ** 4) / 24 = 29.384507979175197
# Term 5: 0.0000301794 * ((40 - 72) ** 5) / 120 = -8.438774021835455
# Taylor Series: 5959.1850514140 * ((40 - 72) ** 0) / 1 + 89.6919106984 * ((40 - 72) ** 1) / 1 + 1.1500753222 * ((40 - 72) ** 2) / 2 + 0.0141508328 * ((40 - 72) ** 3) / 6 + 0.0006725580 * ((40 - 72) ** 4) / 24 + 0.0000301794 * ((40 - 72) ** 5) / 120
# Bag Production at x=40: 3621.545793380306
#
#
# Evaluating Taylor Series around a = 72 for x = 41
# Term 0: 5959.1850514140 * ((41 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((41 - 72) ** 1) / 1 = -2780.449231648975
# Term 2: 1.1500753222 * ((41 - 72) ** 2) / 2 = 552.6111923360171
# Term 3: 0.0141508328 * ((41 - 72) ** 3) / 6 = -70.26124311063086
# Term 4: 0.0006725580 * ((41 - 72) ** 4) / 24 = 25.880060380397662
# Term 5: 0.0000301794 * ((41 - 72) ** 5) / 120 = -7.200090161740915
# Taylor Series: 5959.1850514140 * ((41 - 72) ** 0) / 1 + 89.6919106984 * ((41 - 72) ** 1) / 1 + 1.1500753222 * ((41 - 72) ** 2) / 2 + 0.0141508328 * ((41 - 72) ** 3) / 6 + 0.0006725580 * ((41 - 72) ** 4) / 24 + 0.0000301794 * ((41 - 72) ** 5) / 120
# Bag Production at x=41: 3679.765739209035
#
#
# Evaluating Taylor Series around a = 72 for x = 42
# Term 0: 5959.1850514140 * ((42 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((42 - 72) ** 1) / 1 = -2690.757320950621
# Term 2: 1.1500753222 * ((42 - 72) ** 2) / 2 = 517.5338950077163
# Term 3: 0.0141508328 * ((42 - 72) ** 3) / 6 = -63.67874740649972
# Term 4: 0.0006725580 * ((42 - 72) ** 4) / 24 = 22.69883295357886
# Term 5: 0.0000301794 * ((42 - 72) ** 5) / 120 = -6.111330054122255
# Taylor Series: 5959.1850514140 * ((42 - 72) ** 0) / 1 + 89.6919106984 * ((42 - 72) ** 1) / 1 + 1.1500753222 * ((42 - 72) ** 2) / 2 + 0.0141508328 * ((42 - 72) ** 3) / 6 + 0.0006725580 * ((42 - 72) ** 4) / 24 + 0.0000301794 * ((42 - 72) ** 5) / 120
# Bag Production at x=42: 3738.870380964019
#
#
# Evaluating Taylor Series around a = 72 for x = 43
# Term 0: 5959.1850514140 * ((43 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((43 - 72) ** 1) / 1 = -2601.065410252267
# Term 2: 1.1500753222 * ((43 - 72) ** 2) / 2 = 483.60667300165494
# Term 3: 0.0141508328 * ((43 - 72) ** 3) / 6 = -57.52077668507857
# Term 4: 0.0006725580 * ((43 - 72) ** 4) / 24 = 19.820312679308902
# Term 5: 0.0000301794 * ((43 - 72) ** 5) / 120 = -5.158452729558833
# Taylor Series: 5959.1850514140 * ((43 - 72) ** 0) / 1 + 89.6919106984 * ((43 - 72) ** 1) / 1 + 1.1500753222 * ((43 - 72) ** 2) / 2 + 0.0141508328 * ((43 - 72) ** 3) / 6 + 0.0006725580 * ((43 - 72) ** 4) / 24 + 0.0000301794 * ((43 - 72) ** 5) / 120
# Bag Production at x=43: 3798.867397428026
#
#
# Evaluating Taylor Series around a = 72 for x = 44
# Term 0: 5959.1850514140 * ((44 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((44 - 72) ** 1) / 1 = -2511.373499553913
# Term 2: 1.1500753222 * ((44 - 72) ** 2) / 2 = 450.82952631783286
# Term 3: 0.0141508328 * ((44 - 72) ** 3) / 6 = -51.77318011361044
# Term 4: 0.0006725580 * ((44 - 72) ** 4) / 24 = 17.22465909619132
# Term 5: 0.0000301794 * ((44 - 72) ** 5) / 120 = -4.328322600860244
# Taylor Series: 5959.1850514140 * ((44 - 72) ** 0) / 1 + 89.6919106984 * ((44 - 72) ** 1) / 1 + 1.1500753222 * ((44 - 72) ** 2) / 2 + 0.0141508328 * ((44 - 72) ** 3) / 6 + 0.0006725580 * ((44 - 72) ** 4) / 24 + 0.0000301794 * ((44 - 72) ** 5) / 120
# Bag Production at x=44: 3859.7642345596073
#
#
# Evaluating Taylor Series around a = 72 for x = 45
# Term 0: 5959.1850514140 * ((45 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((45 - 72) ** 1) / 1 = -2421.681588855559
# Term 2: 1.1500753222 * ((45 - 72) ** 2) / 2 = 419.2024549562502
# Term 3: 0.0141508328 * ((45 - 72) ** 3) / 6 = -46.42180685933829
# Term 4: 0.0006725580 * ((45 - 72) ** 4) / 24 = 14.892704300843093
# Term 5: 0.0000301794 * ((45 - 72) ** 5) / 120 = -3.6086792836586508
# Taylor Series: 5959.1850514140 * ((45 - 72) ** 0) / 1 + 89.6919106984 * ((45 - 72) ** 1) / 1 + 1.1500753222 * ((45 - 72) ** 2) / 2 + 0.0141508328 * ((45 - 72) ** 3) / 6 + 0.0006725580 * ((45 - 72) ** 4) / 24 + 0.0000301794 * ((45 - 72) ** 5) / 120
# Bag Production at x=45: 3921.5681356725045
#
#
# Evaluating Taylor Series around a = 72 for x = 46
# Term 0: 5959.1850514140 * ((46 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((46 - 72) ** 1) / 1 = -2331.989678157205
# Term 2: 1.1500753222 * ((46 - 72) ** 2) / 2 = 388.7254589169069
# Term 3: 0.0141508328 * ((46 - 72) ** 3) / 6 = -41.45250608950515
# Term 4: 0.0006725580 * ((46 - 72) ** 4) / 24 = 12.805952947894633
# Term 5: 0.0000301794 * ((46 - 72) ** 5) / 120 = -2.9881074170011055
# Taylor Series: 5959.1850514140 * ((46 - 72) ** 0) / 1 + 89.6919106984 * ((46 - 72) ** 1) / 1 + 1.1500753222 * ((46 - 72) ** 2) / 2 + 0.0141508328 * ((46 - 72) ** 3) / 6 + 0.0006725580 * ((46 - 72) ** 4) / 24 + 0.0000301794 * ((46 - 72) ** 5) / 120
# Bag Production at x=46: 3984.286171615057
#
#
# Evaluating Taylor Series around a = 72 for x = 47
# Term 0: 5959.1850514140 * ((47 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((47 - 72) ** 1) / 1 = -2242.297767458851
# Term 2: 1.1500753222 * ((47 - 72) ** 2) / 2 = 359.398538199803
# Term 3: 0.0141508328 * ((47 - 72) ** 3) / 6 = -36.851126971354
# Term 4: 0.0006725580 * ((47 - 72) ** 4) / 24 = 10.946582249989808
# Term 5: 0.0000301794 * ((47 - 72) ** 5) / 120 = -2.4560064839418785
# Taylor Series: 5959.1850514140 * ((47 - 72) ** 0) / 1 + 89.6919106984 * ((47 - 72) ** 1) / 1 + 1.1500753222 * ((47 - 72) ** 2) / 2 + 0.0141508328 * ((47 - 72) ** 3) / 6 + 0.0006725580 * ((47 - 72) ** 4) / 24 + 0.0000301794 * ((47 - 72) ** 5) / 120
# Bag Production at x=47: 4047.9252709496127
#
#
# Evaluating Taylor Series around a = 72 for x = 48
# Term 0: 5959.1850514140 * ((48 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((48 - 72) ** 1) / 1 = -2152.605856760497
# Term 2: 1.1500753222 * ((48 - 72) ** 2) / 2 = 331.22169280493847
# Term 3: 0.0141508328 * ((48 - 72) ** 3) / 6 = -32.603518672127855
# Term 4: 0.0006725580 * ((48 - 72) ** 4) / 24 = 9.297441977785903
# Term 5: 0.0000301794 * ((48 - 72) ** 5) / 120 = -2.002560632134781
# Taylor Series: 5959.1850514140 * ((48 - 72) ** 0) / 1 + 89.6919106984 * ((48 - 72) ** 1) / 1 + 1.1500753222 * ((48 - 72) ** 2) / 2 + 0.0141508328 * ((48 - 72) ** 3) / 6 + 0.0006725580 * ((48 - 72) ** 4) / 24 + 0.0000301794 * ((48 - 72) ** 5) / 120
# Bag Production at x=48: 4112.492250131931
#
#
# Evaluating Taylor Series around a = 72 for x = 49
# Term 0: 5959.1850514140 * ((49 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((49 - 72) ** 1) / 1 = -2062.9139460621427
# Term 2: 1.1500753222 * ((49 - 72) ** 2) / 2 = 304.1949227323133
# Term 3: 0.0141508328 * ((49 - 72) ** 3) / 6 = -28.695530359069707
# Term 4: 0.0006725580 * ((49 - 72) ** 4) / 24 = 7.8420544599536575
# Term 5: 0.0000301794 * ((49 - 72) ** 5) / 120 = -1.61870849442549
# Taylor Series: 5959.1850514140 * ((49 - 72) ** 0) / 1 + 89.6919106984 * ((49 - 72) ** 1) / 1 + 1.1500753222 * ((49 - 72) ** 2) / 2 + 0.0141508328 * ((49 - 72) ** 3) / 6 + 0.0006725580 * ((49 - 72) ** 4) / 24 + 0.0000301794 * ((49 - 72) ** 5) / 120
# Bag Production at x=49: 4177.993843690596
#
#
# Evaluating Taylor Series around a = 72 for x = 50
# Term 0: 5959.1850514140 * ((50 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((50 - 72) ** 1) / 1 = -1973.2220353637888
# Term 2: 1.1500753222 * ((50 - 72) ** 2) / 2 = 278.31822798192746
# Term 3: 0.0141508328 * ((50 - 72) ** 3) / 6 = -25.113011199422555
# Term 4: 0.0006725580 * ((50 - 72) ** 4) / 24 = 6.564614583177247
# Term 5: 0.0000301794 * ((50 - 72) ** 5) / 120 = -1.296113009443876
# Taylor Series: 5959.1850514140 * ((50 - 72) ** 0) / 1 + 89.6919106984 * ((50 - 72) ** 1) / 1 + 1.1500753222 * ((50 - 72) ** 2) / 2 + 0.0141508328 * ((50 - 72) ** 3) / 6 + 0.0006725580 * ((50 - 72) ** 4) / 24 + 0.0000301794 * ((50 - 72) ** 5) / 120
# Bag Production at x=50: 4244.436734406417
#
#
# Evaluating Taylor Series around a = 72 for x = 51
# Term 0: 5959.1850514140 * ((51 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((51 - 72) ** 1) / 1 = -1883.5301246654349
# Term 2: 1.1500753222 * ((51 - 72) ** 2) / 2 = 253.591608553781
# Term 3: 0.0141508328 * ((51 - 72) ** 3) / 6 = -21.841810360429402
# Term 4: 0.0006725580 * ((51 - 72) ** 4) / 24 = 5.449989792154285
# Term 5: 0.0000301794 * ((51 - 72) ** 5) / 120 = -1.0271312421963275
# Taylor Series: 5959.1850514140 * ((51 - 72) ** 0) / 1 + 89.6919106984 * ((51 - 72) ** 1) / 1 + 1.1500753222 * ((51 - 72) ** 2) / 2 + 0.0141508328 * ((51 - 72) ** 3) / 6 + 0.0006725580 * ((51 - 72) ** 4) / 24 + 0.0000301794 * ((51 - 72) ** 5) / 120
# Bag Production at x=51: 4311.827583491841
#
#
# Evaluating Taylor Series around a = 72 for x = 52
# Term 0: 5959.1850514140 * ((52 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((52 - 72) ** 1) / 1 = -1793.8382139670807
# Term 2: 1.1500753222 * ((52 - 72) ** 2) / 2 = 230.01506444787393
# Term 3: 0.0141508328 * ((52 - 72) ** 3) / 6 = -18.86777700933325
# Term 4: 0.0006725580 * ((52 - 72) ** 4) / 24 = 4.483720089595825
# Term 5: 0.0000301794 * ((52 - 72) ** 5) / 120 = -0.8047842046580749
# Taylor Series: 5959.1850514140 * ((52 - 72) ** 0) / 1 + 89.6919106984 * ((52 - 72) ** 1) / 1 + 1.1500753222 * ((52 - 72) ** 2) / 2 + 0.0141508328 * ((52 - 72) ** 3) / 6 + 0.0006725580 * ((52 - 72) ** 4) / 24 + 0.0000301794 * ((52 - 72) ** 5) / 120
# Bag Production at x=52: 4380.173060770364
#
#
# Evaluating Taylor Series around a = 72 for x = 53
# Term 0: 5959.1850514140 * ((53 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((53 - 72) ** 1) / 1 = -1704.1463032687266
# Term 2: 1.1500753222 * ((53 - 72) ** 2) / 2 = 207.58859566420622
# Term 3: 0.0141508328 * ((53 - 72) ** 3) / 6 = -16.176760313377095
# Term 4: 0.0006725580 * ((53 - 72) ** 4) / 24 = 3.6520180362263592
# Term 5: 0.0000301794 * ((53 - 72) ** 5) / 120 = -0.6227266763655169
# Taylor Series: 5959.1850514140 * ((53 - 72) ** 0) / 1 + 89.6919106984 * ((53 - 72) ** 1) / 1 + 1.1500753222 * ((53 - 72) ** 2) / 2 + 0.0141508328 * ((53 - 72) ** 3) / 6 + 0.0006725580 * ((53 - 72) ** 4) / 24 + 0.0000301794 * ((53 - 72) ** 5) / 120
# Bag Production at x=53: 4449.479874855931
#
#
# Evaluating Taylor Series around a = 72 for x = 54
# Term 0: 5959.1850514140 * ((54 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((54 - 72) ** 1) / 1 = -1614.4543925703726
# Term 2: 1.1500753222 * ((54 - 72) ** 2) / 2 = 186.31220220277788
# Term 3: 0.0141508328 * ((54 - 72) ** 3) / 6 = -13.754609439803938
# Term 4: 0.0006725580 * ((54 - 72) ** 4) / 24 = 2.9417687507838206
# Term 5: 0.0000301794 * ((54 - 72) ** 5) / 120 = -0.4752170250085466
# Taylor Series: 5959.1850514140 * ((54 - 72) ** 0) / 1 + 89.6919106984 * ((54 - 72) ** 1) / 1 + 1.1500753222 * ((54 - 72) ** 2) / 2 + 0.0141508328 * ((54 - 72) ** 3) / 6 + 0.0006725580 * ((54 - 72) ** 4) / 24 + 0.0000301794 * ((54 - 72) ** 5) / 120
# Bag Production at x=54: 4519.754803332344
#
#
# Evaluating Taylor Series around a = 72 for x = 55
# Term 0: 5959.1850514140 * ((55 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((55 - 72) ** 1) / 1 = -1524.7624818720187
# Term 2: 1.1500753222 * ((55 - 72) ** 2) / 2 = 166.1858840635889
# Term 3: 0.0141508328 * ((55 - 72) ** 3) / 6 = -11.587173555856781
# Term 4: 0.0006725580 * ((55 - 72) ** 4) / 24 = 2.34052991001958
# Term 5: 0.0000301794 * ((55 - 72) ** 5) / 120 = -0.3570870270228751
# Taylor Series: 5959.1850514140 * ((55 - 72) ** 0) / 1 + 89.6919106984 * ((55 - 72) ** 1) / 1 + 1.1500753222 * ((55 - 72) ** 2) / 2 + 0.0141508328 * ((55 - 72) ** 3) / 6 + 0.0006725580 * ((55 - 72) ** 4) / 24 + 0.0000301794 * ((55 - 72) ** 5) / 120
# Bag Production at x=55: 4591.0047229326765
#
#
# Evaluating Taylor Series around a = 72 for x = 56
# Term 0: 5959.1850514140 * ((56 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((56 - 72) ** 1) / 1 = -1435.0705711736646
# Term 2: 1.1500753222 * ((56 - 72) ** 2) / 2 = 147.2096412466393
# Term 3: 0.0141508328 * ((56 - 72) ** 3) / 6 = -9.660301828778623
# Term 4: 0.0006725580 * ((56 - 72) ** 4) / 24 = 1.8365317486984498
# Term 5: 0.0000301794 * ((56 - 72) ** 5) / 120 = -0.26371168818235796
# Taylor Series: 5959.1850514140 * ((56 - 72) ** 0) / 1 + 89.6919106984 * ((56 - 72) ** 1) / 1 + 1.1500753222 * ((56 - 72) ** 2) / 2 + 0.0141508328 * ((56 - 72) ** 3) / 6 + 0.0006725580 * ((56 - 72) ** 4) / 24 + 0.0000301794 * ((56 - 72) ** 5) / 120
# Bag Production at x=56: 4663.236639718679
#
#
# Evaluating Taylor Series around a = 72 for x = 57
# Term 0: 5959.1850514140 * ((57 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((57 - 72) ** 1) / 1 = -1345.3786604753104
# Term 2: 1.1500753222 * ((57 - 72) ** 2) / 2 = 129.38347375192907
# Term 3: 0.0141508328 * ((57 - 72) ** 3) / 6 = -7.959843425812465
# Term 4: 0.0006725580 * ((57 - 72) ** 4) / 24 = 1.4186770595986788
# Term 5: 0.0000301794 * ((57 - 72) ** 5) / 120 = -0.19097906419132046
# Taylor Series: 5959.1850514140 * ((57 - 72) ** 0) / 1 + 89.6919106984 * ((57 - 72) ** 1) / 1 + 1.1500753222 * ((57 - 72) ** 2) / 2 + 0.0141508328 * ((57 - 72) ** 3) / 6 + 0.0006725580 * ((57 - 72) ** 4) / 24 + 0.0000301794 * ((57 - 72) ** 5) / 120
# Bag Production at x=57: 4736.457719260181
#
#
# Evaluating Taylor Series around a = 72 for x = 58
# Term 0: 5959.1850514140 * ((58 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((58 - 72) ** 1) / 1 = -1255.6867497769565
# Term 2: 1.1500753222 * ((58 - 72) ** 2) / 2 = 112.70738157945821
# Term 3: 0.0141508328 * ((58 - 72) ** 3) / 6 = -6.471647514201305
# Term 4: 0.0006725580 * ((58 - 72) ** 4) / 24 = 1.0765411935119575
# Term 5: 0.0000301794 * ((58 - 72) ** 5) / 120 = -0.13526008127688263
# Taylor Series: 5959.1850514140 * ((58 - 72) ** 0) / 1 + 89.6919106984 * ((58 - 72) ** 1) / 1 + 1.1500753222 * ((58 - 72) ** 2) / 2 + 0.0141508328 * ((58 - 72) ** 3) / 6 + 0.0006725580 * ((58 - 72) ** 4) / 24 + 0.0000301794 * ((58 - 72) ** 5) / 120
# Bag Production at x=58: 4810.675316814502
#
#
# Evaluating Taylor Series around a = 72 for x = 59
# Term 0: 5959.1850514140 * ((59 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((59 - 72) ** 1) / 1 = -1165.9948390786026
# Term 2: 1.1500753222 * ((59 - 72) ** 2) / 2 = 97.18136472922673
# Term 3: 0.0141508328 * ((59 - 72) ** 3) / 6 = -5.181563261188144
# Term 4: 0.0006725580 * ((59 - 72) ** 4) / 24 = 0.8003720592434146
# Term 5: 0.0000301794 * ((59 - 72) ** 5) / 120 = -0.09337835678128455
# Taylor Series: 5959.1850514140 * ((59 - 72) ** 0) / 1 + 89.6919106984 * ((59 - 72) ** 1) / 1 + 1.1500753222 * ((59 - 72) ** 2) / 2 + 0.0141508328 * ((59 - 72) ** 3) / 6 + 0.0006725580 * ((59 - 72) ** 4) / 24 + 0.0000301794 * ((59 - 72) ** 5) / 120
# Bag Production at x=59: 4885.897007505865
#
#
# Evaluating Taylor Series around a = 72 for x = 60
# Term 0: 5959.1850514140 * ((60 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((60 - 72) ** 1) / 1 = -1076.3029283802484
# Term 2: 1.1500753222 * ((60 - 72) ** 2) / 2 = 82.80542320123462
# Term 3: 0.0141508328 * ((60 - 72) ** 3) / 6 = -4.075439834015982
# Term 4: 0.0006725580 * ((60 - 72) ** 4) / 24 = 0.5810901236116189
# Term 5: 0.0000301794 * ((60 - 72) ** 5) / 120 = -0.0625800197542119
# Taylor Series: 5959.1850514140 * ((60 - 72) ** 0) / 1 + 89.6919106984 * ((60 - 72) ** 1) / 1 + 1.1500753222 * ((60 - 72) ** 2) / 2 + 0.0141508328 * ((60 - 72) ** 3) / 6 + 0.0006725580 * ((60 - 72) ** 4) / 24 + 0.0000301794 * ((60 - 72) ** 5) / 120
# Bag Production at x=60: 4962.1306165047945
#
#
# Evaluating Taylor Series around a = 72 for x = 61
# Term 0: 5959.1850514140 * ((61 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((61 - 72) ** 1) / 1 = -986.6110176818944
# Term 2: 1.1500753222 * ((61 - 72) ** 2) / 2 = 69.57955699548187
# Term 3: 0.0141508328 * ((61 - 72) ** 3) / 6 = -3.1391263999278194
# Term 4: 0.0006725580 * ((61 - 72) ** 4) / 24 = 0.4102884114485779
# Term 5: 0.0000301794 * ((61 - 72) ** 5) / 120 = -0.040503531545121124
# Taylor Series: 5959.1850514140 * ((61 - 72) ** 0) / 1 + 89.6919106984 * ((61 - 72) ** 1) / 1 + 1.1500753222 * ((61 - 72) ** 2) / 2 + 0.0141508328 * ((61 - 72) ** 3) / 6 + 0.0006725580 * ((61 - 72) ** 4) / 24 + 0.0000301794 * ((61 - 72) ** 5) / 120
# Bag Production at x=61: 5039.384249207529
#
#
# Evaluating Taylor Series around a = 72 for x = 62
# Term 0: 5959.1850514140 * ((62 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((62 - 72) ** 1) / 1 = -896.9191069835404
# Term 2: 1.1500753222 * ((62 - 72) ** 2) / 2 = 57.50376611196848
# Term 3: 0.0141508328 * ((62 - 72) ** 3) / 6 = -2.358472126166656
# Term 4: 0.0006725580 * ((62 - 72) ** 4) / 24 = 0.28023250559973906
# Term 5: 0.0000301794 * ((62 - 72) ** 5) / 120 = -0.02514950639556484
# Taylor Series: 5959.1850514140 * ((62 - 72) ** 0) / 1 + 89.6919106984 * ((62 - 72) ** 1) / 1 + 1.1500753222 * ((62 - 72) ** 2) / 2 + 0.0141508328 * ((62 - 72) ** 3) / 6 + 0.0006725580 * ((62 - 72) ** 4) / 24 + 0.0000301794 * ((62 - 72) ** 5) / 120
# Bag Production at x=62: 5117.666321415432
#
#
# Evaluating Taylor Series around a = 72 for x = 63
# Term 0: 5959.1850514140 * ((63 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((63 - 72) ** 1) / 1 = -807.2271962851863
# Term 2: 1.1500753222 * ((63 - 72) ** 2) / 2 = 46.57805055069447
# Term 3: 0.0141508328 * ((63 - 72) ** 3) / 6 = -1.7193261799754922
# Term 4: 0.0006725580 * ((63 - 72) ** 4) / 24 = 0.1838605469239888
# Term 5: 0.0000301794 * ((63 - 72) ** 5) / 120 = -0.014850532031517082
# Taylor Series: 5959.1850514140 * ((63 - 72) ** 0) / 1 + 89.6919106984 * ((63 - 72) ** 1) / 1 + 1.1500753222 * ((63 - 72) ** 2) / 2 + 0.0141508328 * ((63 - 72) ** 3) / 6 + 0.0006725580 * ((63 - 72) ** 4) / 24 + 0.0000301794 * ((63 - 72) ** 5) / 120
# Bag Production at x=63: 5196.985589514392
#
#
# Evaluating Taylor Series around a = 72 for x = 64
# Term 0: 5959.1850514140 * ((64 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((64 - 72) ** 1) / 1 = -717.5352855868323
# Term 2: 1.1500753222 * ((64 - 72) ** 2) / 2 = 36.80241031165983
# Term 3: 0.0141508328 * ((64 - 72) ** 3) / 6 = -1.2075377285973279
# Term 4: 0.0006725580 * ((64 - 72) ** 4) / 24 = 0.11478323429365311
# Term 5: 0.0000301794 * ((64 - 72) ** 5) / 120 = -0.008240990255698686
# Taylor Series: 5959.1850514140 * ((64 - 72) ** 0) / 1 + 89.6919106984 * ((64 - 72) ** 1) / 1 + 1.1500753222 * ((64 - 72) ** 2) / 2 + 0.0141508328 * ((64 - 72) ** 3) / 6 + 0.0006725580 * ((64 - 72) ** 4) / 24 + 0.0000301794 * ((64 - 72) ** 5) / 120
# Bag Production at x=64: 5277.351180654235
#
#
# Evaluating Taylor Series around a = 72 for x = 65
# Term 0: 5959.1850514140 * ((65 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((65 - 72) ** 1) / 1 = -627.8433748884783
# Term 2: 1.1500753222 * ((65 - 72) ** 2) / 2 = 28.176845394864554
# Term 3: 0.0141508328 * ((65 - 72) ** 3) / 6 = -0.8089559392751631
# Term 4: 0.0006725580 * ((65 - 72) ** 4) / 24 = 0.06728382459449735
# ...
# Bag Production at x=123: 12618.354209888601
#
#
# Evaluating Taylor Series around a = 72 for x = 124
# Term 0: 5959.1850514140 * ((124 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((124 - 72) ** 1) / 1 = 4663.97935631441
# Term 2: 1.1500753222 * ((124 - 72) ** 2) / 2 = 1554.9018356676277
# Term 3: 0.0141508328 * ((124 - 72) ** 3) / 6 = 331.6200487160412
# Term 4: 0.0006725580 * ((124 - 72) ** 4) / 24 = 204.89524716631414
# Term 5: 0.0000301794 * ((124 - 72) ** 5) / 120 = 95.61943734403538
# Taylor Series: 5959.1850514140 * ((124 - 72) ** 0) / 1 + 89.6919106984 * ((124 - 72) ** 1) / 1 + 1.1500753222 * ((124 - 72) ** 2) / 2 + 0.0141508328 * ((124 - 72) ** 3) / 6 + 0.0006725580 * ((124 - 72) ** 4) / 24 + 0.0000301794 * ((124 - 72) ** 5) / 120
# Bag Production at x=124: 12810.200976622396
#
#
# Evaluating Taylor Series around a = 72 for x = 125
# Term 0: 5959.1850514140 * ((125 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((125 - 72) ** 1) / 1 = 4753.671267012764
# Term 2: 1.1500753222 * ((125 - 72) ** 2) / 2 = 1615.2807900851947
# Term 3: 0.0141508328 * ((125 - 72) ** 3) / 6 = 351.12225472731325
# Term 4: 0.0006725580 * ((125 - 72) ** 4) / 24 = 221.11692610171346
# Term 5: 0.0000301794 * ((125 - 72) ** 5) / 120 = 105.1741022579989
# Taylor Series: 5959.1850514140 * ((125 - 72) ** 0) / 1 + 89.6919106984 * ((125 - 72) ** 1) / 1 + 1.1500753222 * ((125 - 72) ** 2) / 2 + 0.0141508328 * ((125 - 72) ** 3) / 6 + 0.0006725580 * ((125 - 72) ** 4) / 24 + 0.0000301794 * ((125 - 72) ** 5) / 120
# Bag Production at x=125: 13005.55039159895
#
#
# Evaluating Taylor Series around a = 72 for x = 126
# Term 0: 5959.1850514140 * ((126 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((126 - 72) ** 1) / 1 = 4843.363177711118
# Term 2: 1.1500753222 * ((126 - 72) ** 2) / 2 = 1676.809819825001
# Term 3: 0.0141508328 * ((126 - 72) ** 3) / 6 = 371.3744548747063
# Term 4: 0.0006725580 * ((126 - 72) ** 4) / 24 = 238.28326881348949
# Term 5: 0.0000301794 * ((126 - 72) ** 5) / 120 = 115.47773707707682
# Taylor Series: 5959.1850514140 * ((126 - 72) ** 0) / 1 + 89.6919106984 * ((126 - 72) ** 1) / 1 + 1.1500753222 * ((126 - 72) ** 2) / 2 + 0.0141508328 * ((126 - 72) ** 3) / 6 + 0.0006725580 * ((126 - 72) ** 4) / 24 + 0.0000301794 * ((126 - 72) ** 5) / 120
# Bag Production at x=126: 13204.493509715358
#
#
# Evaluating Taylor Series around a = 72 for x = 127
# Term 0: 5959.1850514140 * ((127 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((127 - 72) ** 1) / 1 = 4933.055088409472
# Term 2: 1.1500753222 * ((127 - 72) ** 2) / 2 = 1739.4889248870466
# Term 3: 0.0141508328 * ((127 - 72) ** 3) / 6 = 392.3907999909774
# Term 4: 0.0006725580 * ((127 - 72) ** 4) / 24 = 256.4302571553612
# Term 5: 0.0000301794 * ((127 - 72) ** 5) / 120 = 126.57353607850352
# Taylor Series: 5959.1850514140 * ((127 - 72) ** 0) / 1 + 89.6919106984 * ((127 - 72) ** 1) / 1 + 1.1500753222 * ((127 - 72) ** 2) / 2 + 0.0141508328 * ((127 - 72) ** 3) / 6 + 0.0006725580 * ((127 - 72) ** 4) / 24 + 0.0000301794 * ((127 - 72) ** 5) / 120
# Bag Production at x=127: 13407.123657935328
#
#
# Evaluating Taylor Series around a = 72 for x = 128
# Term 0: 5959.1850514140 * ((128 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((128 - 72) ** 1) / 1 = 5022.746999107826
# Term 2: 1.1500753222 * ((128 - 72) ** 2) / 2 = 1803.3181052713314
# Term 3: 0.0141508328 * ((128 - 72) ** 3) / 6 = 414.1854409088835
# Term 4: 0.0006725580 * ((128 - 72) ** 4) / 24 = 275.59454553906113
# Term 5: 0.0000301794 * ((128 - 72) ** 5) / 120 = 138.50632322752782
# Taylor Series: 5959.1850514140 * ((128 - 72) ** 0) / 1 + 89.6919106984 * ((128 - 72) ** 1) / 1 + 1.1500753222 * ((128 - 72) ** 2) / 2 + 0.0141508328 * ((128 - 72) ** 3) / 6 + 0.0006725580 * ((128 - 72) ** 4) / 24 + 0.0000301794 * ((128 - 72) ** 5) / 120
# Bag Production at x=128: 13613.536465468596
#
#
# Evaluating Taylor Series around a = 72 for x = 129
# Term 0: 5959.1850514140 * ((129 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((129 - 72) ** 1) / 1 = 5112.43890980618
# Term 2: 1.1500753222 * ((129 - 72) ** 2) / 2 = 1868.297360977856
# Term 3: 0.0141508328 * ((129 - 72) ** 3) / 6 = 436.77252846118154
# Term 4: 0.0006725580 * ((129 - 72) ** 4) / 24 = 295.81346093433507
# Term 5: 0.0000301794 * ((129 - 72) ** 5) / 120 = 151.32258235682062
# Taylor Series: 5959.1850514140 * ((129 - 72) ** 0) / 1 + 89.6919106984 * ((129 - 72) ** 1) / 1 + 1.1500753222 * ((129 - 72) ** 2) / 2 + 0.0141508328 * ((129 - 72) ** 3) / 6 + 0.0006725580 * ((129 - 72) ** 4) / 24 + 0.0000301794 * ((129 - 72) ** 5) / 120
# Bag Production at x=129: 13823.829893950338
#
#
# Evaluating Taylor Series around a = 72 for x = 130
# Term 0: 5959.1850514140 * ((130 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((130 - 72) ** 1) / 1 = 5202.130820504534
# Term 2: 1.1500753222 * ((130 - 72) ** 2) / 2 = 1934.4266920066198
# Term 3: 0.0141508328 * ((130 - 72) ** 3) / 6 = 460.1662134806286
# Term 4: 0.0006725580 * ((130 - 72) ** 4) / 24 = 317.12500286894243
# Term 5: 0.0000301794 * ((130 - 72) ** 5) / 120 = 165.07048734588267
# Taylor Series: 5959.1850514140 * ((130 - 72) ** 0) / 1 + 89.6919106984 * ((130 - 72) ** 1) / 1 + 1.1500753222 * ((130 - 72) ** 2) / 2 + 0.0141508328 * ((130 - 72) ** 3) / 6 + 0.0006725580 * ((130 - 72) ** 4) / 24 + 0.0000301794 * ((130 - 72) ** 5) / 120
# Bag Production at x=130: 14038.104267620576
#
#
# Evaluating Taylor Series around a = 72 for x = 131
# Term 0: 5959.1850514140 * ((131 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((131 - 72) ** 1) / 1 = 5291.8227312028885
# Term 2: 1.1500753222 * ((131 - 72) ** 2) / 2 = 2001.7060983576227
# Term 3: 0.0141508328 * ((131 - 72) ** 3) / 6 = 484.38064679998166
# Term 4: 0.0006725580 * ((131 - 72) ** 4) / 24 = 339.567843428656
# Term 5: 0.0000301794 * ((131 - 72) ** 5) / 120 = 179.79993230045207
# Taylor Series: 5959.1850514140 * ((131 - 72) ** 0) / 1 + 89.6919106984 * ((131 - 72) ** 1) / 1 + 1.1500753222 * ((131 - 72) ** 2) / 2 + 0.0141508328 * ((131 - 72) ** 3) / 6 + 0.0006725580 * ((131 - 72) ** 4) / 24 + 0.0000301794 * ((131 - 72) ** 5) / 120
# Bag Production at x=131: 14256.46230350357
#
#
# Evaluating Taylor Series around a = 72 for x = 132
# Term 0: 5959.1850514140 * ((132 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((132 - 72) ** 1) / 1 = 5381.514641901242
# Term 2: 1.1500753222 * ((132 - 72) ** 2) / 2 = 2070.135580030865
# Term 3: 0.0141508328 * ((132 - 72) ** 3) / 6 = 509.42997925199774
# Term 4: 0.0006725580 * ((132 - 72) ** 4) / 24 = 363.1813272572618
# Term 5: 0.0000301794 * ((132 - 72) ** 5) / 120 = 195.56256173191215
# Taylor Series: 5959.1850514140 * ((132 - 72) ** 0) / 1 + 89.6919106984 * ((132 - 72) ** 1) / 1 + 1.1500753222 * ((132 - 72) ** 2) / 2 + 0.0141508328 * ((132 - 72) ** 3) / 6 + 0.0006725580 * ((132 - 72) ** 4) / 24 + 0.0000301794 * ((132 - 72) ** 5) / 120
# Bag Production at x=132: 14479.009141587245
#
#
# Evaluating Taylor Series around a = 72 for x = 133
# Term 0: 5959.1850514140 * ((133 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((133 - 72) ** 1) / 1 = 5471.206552599596
# Term 2: 1.1500753222 * ((133 - 72) ** 2) / 2 = 2139.7151370263473
# Term 3: 0.0141508328 * ((133 - 72) ** 3) / 6 = 535.3283616694338
# Term 4: 0.0006725580 * ((133 - 72) ** 4) / 24 = 388.0054715565596
# Term 5: 0.0000301794 * ((133 - 72) ** 5) / 120 = 212.41180073669906
# Taylor Series: 5959.1850514140 * ((133 - 72) ** 0) / 1 + 89.6919106984 * ((133 - 72) ** 1) / 1 + 1.1500753222 * ((133 - 72) ** 2) / 2 + 0.0141508328 * ((133 - 72) ** 3) / 6 + 0.0006725580 * ((133 - 72) ** 4) / 24 + 0.0000301794 * ((133 - 72) ** 5) / 120
# Bag Production at x=133: 14705.852375002603
#
#
# Evaluating Taylor Series around a = 72 for x = 134
# Term 0: 5959.1850514140 * ((134 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((134 - 72) ** 1) / 1 = 5560.89846329795
# Term 2: 1.1500753222 * ((134 - 72) ** 2) / 2 = 2210.4447693440684
# Term 3: 0.0141508328 * ((134 - 72) ** 3) / 6 = 562.0899448850469
# Term 4: 0.0006725580 * ((134 - 72) ** 4) / 24 = 414.0809660863626
# Term 5: 0.0000301794 * ((134 - 72) ** 5) / 120 = 230.4028851757093
# Taylor Series: 5959.1850514140 * ((134 - 72) ** 0) / 1 + 89.6919106984 * ((134 - 72) ** 1) / 1 + 1.1500753222 * ((134 - 72) ** 2) / 2 + 0.0141508328 * ((134 - 72) ** 3) / 6 + 0.0006725580 * ((134 - 72) ** 4) / 24 + 0.0000301794 * ((134 - 72) ** 5) / 120
# Bag Production at x=134: 14937.102080203105
#
#
# Evaluating Taylor Series around a = 72 for x = 135
# Term 0: 5959.1850514140 * ((135 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((135 - 72) ** 1) / 1 = 5650.590373996304
# Term 2: 1.1500753222 * ((135 - 72) ** 2) / 2 = 2282.324476984029
# Term 3: 0.0141508328 * ((135 - 72) ** 3) / 6 = 589.7288797315939
# Term 4: 0.0006725580 * ((135 - 72) ** 4) / 24 = 441.4491731644971
# Term 5: 0.0000301794 * ((135 - 72) ** 5) / 120 = 249.59289185370758
# Taylor Series: 5959.1850514140 * ((135 - 72) ** 0) / 1 + 89.6919106984 * ((135 - 72) ** 1) / 1 + 1.1500753222 * ((135 - 72) ** 2) / 2 + 0.0141508328 * ((135 - 72) ** 3) / 6 + 0.0006725580 * ((135 - 72) ** 4) / 24 + 0.0000301794 * ((135 - 72) ** 5) / 120
# Bag Production at x=135: 15172.8708471441
#
#
# Evaluating Taylor Series around a = 72 for x = 136
# Term 0: 5959.1850514140 * ((136 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((136 - 72) ** 1) / 1 = 5740.282284694658
# Term 2: 1.1500753222 * ((136 - 72) ** 2) / 2 = 2355.354259946229
# Term 3: 0.0141508328 * ((136 - 72) ** 3) / 6 = 618.2593170418319
# Term 4: 0.0006725580 * ((136 - 72) ** 4) / 24 = 470.15212766680315
# Term 5: 0.0000301794 * ((136 - 72) ** 5) / 120 = 270.04076869873455
# Taylor Series: 5959.1850514140 * ((136 - 72) ** 0) / 1 + 89.6919106984 * ((136 - 72) ** 1) / 1 + 1.1500753222 * ((136 - 72) ** 2) / 2 + 0.0141508328 * ((136 - 72) ** 3) / 6 + 0.0006725580 * ((136 - 72) ** 4) / 24 + 0.0000301794 * ((136 - 72) ** 5) / 120
# Bag Production at x=136: 15413.273809462222
#
#
# Evaluating Taylor Series around a = 72 for x = 137
# Term 0: 5959.1850514140 * ((137 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((137 - 72) ** 1) / 1 = 5829.974195393012
# Term 2: 1.1500753222 * ((137 - 72) ** 2) / 2 = 2429.5341182306684
# Term 3: 0.0141508328 * ((137 - 72) ** 3) / 6 = 647.695407648518
# Term 4: 0.0006725580 * ((137 - 72) ** 4) / 24 = 500.2325370271342
# Term 5: 0.0000301794 * ((137 - 72) ** 5) / 120 = 291.80736494151427
# Taylor Series: 5959.1850514140 * ((137 - 72) ** 0) / 1 + 89.6919106984 * ((137 - 72) ** 1) / 1 + 1.1500753222 * ((137 - 72) ** 2) / 2 + 0.0141508328 * ((137 - 72) ** 3) / 6 + 0.0006725580 * ((137 - 72) ** 4) / 24 + 0.0000301794 * ((137 - 72) ** 5) / 120
# Bag Production at x=137: 15658.428674654815
#
#
# Evaluating Taylor Series around a = 72 for x = 138
# Term 0: 5959.1850514140 * ((138 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((138 - 72) ** 1) / 1 = 5919.666106091367
# Term 2: 1.1500753222 * ((138 - 72) ** 2) / 2 = 2504.864051837347
# Term 3: 0.0141508328 * ((138 - 72) ** 3) / 6 = 678.051302384409
# Term 4: 0.0006725580 * ((138 - 72) ** 4) / 24 = 531.733781237357
# Term 5: 0.0000301794 * ((138 - 72) ** 5) / 120 = 314.9554612948619
# Taylor Series: 5959.1850514140 * ((138 - 72) ** 0) / 1 + 89.6919106984 * ((138 - 72) ** 1) / 1 + 1.1500753222 * ((138 - 72) ** 2) / 2 + 0.0141508328 * ((138 - 72) ** 3) / 6 + 0.0006725580 * ((138 - 72) ** 4) / 24 + 0.0000301794 * ((138 - 72) ** 5) / 120
# Bag Production at x=138: 15908.455754259308
#
#
# Evaluating Taylor Series around a = 72 for x = 139
# Term 0: 5959.1850514140 * ((139 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((139 - 72) ** 1) / 1 = 6009.358016789721
# Term 2: 1.1500753222 * ((139 - 72) ** 2) / 2 = 2581.344060766265
# Term 3: 0.0141508328 * ((139 - 72) ** 3) / 6 = 709.3411520822619
# Term 4: 0.0006725580 * ((139 - 72) ** 4) / 24 = 564.6999128473519
# Term 5: 0.0000301794 * ((139 - 72) ** 5) / 120 = 339.5498001330916
# Taylor Series: 5959.1850514140 * ((139 - 72) ** 0) / 1 + 89.6919106984 * ((139 - 72) ** 1) / 1 + 1.1500753222 * ((139 - 72) ** 2) / 2 + 0.0141508328 * ((139 - 72) ** 3) / 6 + 0.0006725580 * ((139 - 72) ** 4) / 24 + 0.0000301794 * ((139 - 72) ** 5) / 120
# Bag Production at x=139: 16163.477994032659
#
#
# Evaluating Taylor Series around a = 72 for x = 140
# Term 0: 5959.1850514140 * ((140 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((140 - 72) ** 1) / 1 = 6099.049927488075
# Term 2: 1.1500753222 * ((140 - 72) ** 2) / 2 = 2658.9741450174224
# Term 3: 0.0141508328 * ((140 - 72) ** 3) / 6 = 741.579107574834
# Term 4: 0.0006725580 * ((140 - 72) ** 4) / 24 = 599.1756569650125
# Term 5: 0.0000301794 * ((140 - 72) ** 5) / 120 = 365.6571156714241
# Taylor Series: 5959.1850514140 * ((140 - 72) ** 0) / 1 + 89.6919106984 * ((140 - 72) ** 1) / 1 + 1.1500753222 * ((140 - 72) ** 2) / 2 + 0.0141508328 * ((140 - 72) ** 3) / 6 + 0.0006725580 * ((140 - 72) ** 4) / 24 + 0.0000301794 * ((140 - 72) ** 5) / 120
# Bag Production at x=140: 16423.621004130735
#
#
# Evaluating Taylor Series around a = 72 for x = 141
# Term 0: 5959.1850514140 * ((141 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((141 - 72) ** 1) / 1 = 6188.741838186428
# Term 2: 1.1500753222 * ((141 - 72) ** 2) / 2 = 2737.754304590819
# Term 3: 0.0141508328 * ((141 - 72) ** 3) / 6 = 774.779319694882
# Term 4: 0.0006725580 * ((141 - 72) ** 4) / 24 = 635.2064112562463
# Term 5: 0.0000301794 * ((141 - 72) ** 5) / 120 = 393.346164145394
# Taylor Series: 5959.1850514140 * ((141 - 72) ** 0) / 1 + 89.6919106984 * ((141 - 72) ** 1) / 1 + 1.1500753222 * ((141 - 72) ** 2) / 2 + 0.0141508328 * ((141 - 72) ** 3) / 6 + 0.0006725580 * ((141 - 72) ** 4) / 24 + 0.0000301794 * ((141 - 72) ** 5) / 120
# Bag Production at x=141: 16689.013089287735
#
#
# Evaluating Taylor Series around a = 72 for x = 142
# Term 0: 5959.1850514140 * ((142 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((142 - 72) ** 1) / 1 = 6278.433748884782
# Term 2: 1.1500753222 * ((142 - 72) ** 2) / 2 = 2817.6845394864554
# Term 3: 0.0141508328 * ((142 - 72) ** 3) / 6 = 808.955939275163
# Term 4: 0.0006725580 * ((142 - 72) ** 4) / 24 = 672.8382459449734
# Term 5: 0.0000301794 * ((142 - 72) ** 5) / 120 = 422.6877539902582
# Taylor Series: 5959.1850514140 * ((142 - 72) ** 0) / 1 + 89.6919106984 * ((142 - 72) ** 1) / 1 + 1.1500753222 * ((142 - 72) ** 2) / 2 + 0.0141508328 * ((142 - 72) ** 3) / 6 + 0.0006725580 * ((142 - 72) ** 4) / 24 + 0.0000301794 * ((142 - 72) ** 5) / 120
# Bag Production at x=142: 16959.7852789956
#
#
# Evaluating Taylor Series around a = 72 for x = 143
# Term 0: 5959.1850514140 * ((143 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((143 - 72) ** 1) / 1 = 6368.125659583136
# Term 2: 1.1500753222 * ((143 - 72) ** 2) / 2 = 2898.764849704331
# Term 3: 0.0141508328 * ((143 - 72) ** 3) / 6 = 844.1231171484341
# Term 4: 0.0006725580 * ((143 - 72) ** 4) / 24 = 712.1179038131282
# Term 5: 0.0000301794 * ((143 - 72) ** 5) / 120 = 453.75477602040297
# Taylor Series: 5959.1850514140 * ((143 - 72) ** 0) / 1 + 89.6919106984 * ((143 - 72) ** 1) / 1 + 1.1500753222 * ((143 - 72) ** 2) / 2 + 0.0141508328 * ((143 - 72) ** 3) / 6 + 0.0006725580 * ((143 - 72) ** 4) / 24 + 0.0000301794 * ((143 - 72) ** 5) / 120
# Bag Production at x=143: 17236.0713576834
#
#
# Evaluating Taylor Series around a = 72 for x = 144
# Term 0: 5959.1850514140 * ((144 - 72) ** 0) / 1 = 5959.185051413967
# Term 1: 89.6919106984 * ((144 - 72) ** 1) / 1 = 6457.817570281491
# Term 2: 1.1500753222 * ((144 - 72) ** 2) / 2 = 2980.995235244446
# Term 3: 0.0141508328 * ((144 - 72) ** 3) / 6 = 880.295004147452
# Term 4: 0.0006725580 * ((144 - 72) ** 4) / 24 = 753.0928002006581
# Term 5: 0.0000301794 * ((144 - 72) ** 5) / 120 = 486.62223360875174
# Taylor Series: 5959.1850514140 * ((144 - 72) ** 0) / 1 + 89.6919106984 * ((144 - 72) ** 1) / 1 + 1.1500753222 * ((144 - 72) ** 2) / 2 + 0.0141508328 * ((144 - 72) ** 3) / 6 + 0.0006725580 * ((144 - 72) ** 4) / 24 + 0.0000301794 * ((144 - 72) ** 5) / 120
# Bag Production at x=144: 17518.007894896764
# Mean Squared Error (Taylor Series Approximation): 79412.21257840592

# %% [markdown]
# ## Maclaurin Series (a = 0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from sklearn.metrics import mean_squared_error

# Data

months = np.arange(1, 145)
data = [
    1863, 1614, 2570, 1685, 2101, 1811, 2457, 2171, 2134, 2502, 2358, 2399, 2048, 2523, 2086, 2391,
    2150, 2340, 3129, 2277, 2964, 2997, 2747, 2862, 3405, 2677, 2749, 2755, 2963, 3161, 3623, 2768,
    3141, 3439, 3601, 3531, 3477, 3376, 4027, 3175, 3274, 3334, 3964, 3649, 3502, 3688, 3657, 4422,
    4197, 4441, 4736, 4521, 4485, 4644, 5036, 4876, 4789, 4544, 4975, 5211, 4880, 4933, 5079, 5339,
    5232, 5520, 5714, 5260, 6110, 5334, 5988, 6235, 6365, 6266, 6345, 6118, 6497, 6278, 6638, 6590,
    6271, 7246, 6584, 6594, 7092, 7326, 7409, 7976, 7959, 8012, 8195, 8008, 8313, 7791, 8368, 8933,
    8756, 8613, 8705, 9098, 8769, 9544, 9050, 9186, 10012, 9685, 9966, 10048, 10244, 10740, 10318,
    10393, 10986, 10635, 10731, 11749, 11849, 12123, 12274, 11666, 11960, 12629, 12915, 13051,
    13387, 13309, 13732, 13162, 13644, 13808, 14101, 13992, 15191, 15018, 14917, 15046, 15556,
    15893, 16388, 16782, 16716, 17033, 16896, 17689
]

# Polynomial Model Equation Degree 5

poly_coeffs = np.polyfit(months, data, 5)
poly_model = np.poly1d(poly_coeffs)

# Find the derivative of Polynomial

poly_derivatives = [np.polyder(poly_model, m) for m in range(6)]

# Function to make a maclaurin Series

def maclaurin_series_approximation(x, a, derivatives):
    approximation = 0
    terms = []
    print(f'\nEvaluating Maclaurin Series around a = {a} for x = {x}')
    for n, derivative in enumerate(derivatives):
        term_value = derivative(a) * ((x - a) ** n) / math.factorial(n)
        approximation += term_value
        term_str = f"{derivative(a):.10f} * (({x} - {a}) ** {n}) / {math.factorial(n)}"
        terms.append(term_str)
        print(f'Term {n}: {term_str} = {term_value}')
    return approximation, terms

a = 0 # Maclaurin Series (a = 0)

# maclaurin Series Value Printing

maclaurin_approximations = []
for x in months:
    approx, terms = maclaurin_series_approximation(x, a, poly_derivatives)
    maclaurin_approximations.append(approx)
    print(f'Maclaurin Series: {" + ".join(terms)}\nBag Production at x={x}: {approx}\n')

# Plotting the Original Data, Polynomial Model, and maclaurin Series Model

plt.figure(figsize=(10, 6))
plt.plot(months, data, label='Monthly Production', color='blue')
plt.plot(months, poly_model(months), label='Polynomial Model (Degree 5)', color='red')
plt.plot(months, maclaurin_approximations, label='Maclaurin Series Approximation', color='green', linestyle='dashed')
plt.xlabel('Month')
plt.ylabel('Production')
plt.title('Maclaurin Series Approximation of Polynomial Model')
plt.legend()
plt.grid(True)
plt.show()

# Evaluate the maclaurin Series Approximation

mse_maclaurin = mean_squared_error(data, maclaurin_approximations)
print(f'Mean Squared Error (maclaurin Series Approximation): {mse_maclaurin}\n')

# Code to evaluate another Y value based on X-value given

x_manual = months[73]  # Change any x-value
a = 0 # Maclaurin Series (a = 0)
approx_manual, terms_manual = maclaurin_series_approximation(x_manual, a, poly_derivatives)
print(f'Maclaurin Series at x={x_manual}: {approx_manual}\nTerms: {" + ".join(terms_manual)}\n')
# Out:
# Evaluating Maclaurin Series around a = 0 for x = 1
# Term 0: 1868.5382788214 * ((1 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((1 - 0) ** 1) / 1 = 35.52016777050117
# Term 2: -0.0029148581 * ((1 - 0) ** 2) / 2 = -0.0014574290280632697
# Term 3: 0.0439516805 * ((1 - 0) ** 3) / 6 = 0.007325280080354983
# Term 4: -0.0015003593 * ((1 - 0) ** 4) / 24 = -6.25149724640595e-05
# Term 5: 0.0000301794 * ((1 - 0) ** 5) / 120 = 2.514950639556484e-07
# Maclaurin Series: 1868.5382788214 * ((1 - 0) ** 0) / 1 + 35.5201677705 * ((1 - 0) ** 1) / 1 + -0.0029148581 * ((1 - 0) ** 2) / 2 + 0.0439516805 * ((1 - 0) ** 3) / 6 + -0.0015003593 * ((1 - 0) ** 4) / 24 + 0.0000301794 * ((1 - 0) ** 5) / 120
# Bag Production at x=1: 1904.0642521794507
#
#
# Evaluating Maclaurin Series around a = 0 for x = 2
# Term 0: 1868.5382788214 * ((2 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((2 - 0) ** 1) / 1 = 71.04033554100234
# Term 2: -0.0029148581 * ((2 - 0) ** 2) / 2 = -0.005829716112253079
# Term 3: 0.0439516805 * ((2 - 0) ** 3) / 6 = 0.058602240642839865
# Term 4: -0.0015003593 * ((2 - 0) ** 4) / 24 = -0.001000239559424952
# Term 5: 0.0000301794 * ((2 - 0) ** 5) / 120 = 8.047842046580748e-06
# Maclaurin Series: 1868.5382788214 * ((2 - 0) ** 0) / 1 + 35.5201677705 * ((2 - 0) ** 1) / 1 + -0.0029148581 * ((2 - 0) ** 2) / 2 + 0.0439516805 * ((2 - 0) ** 3) / 6 + -0.0015003593 * ((2 - 0) ** 4) / 24 + 0.0000301794 * ((2 - 0) ** 5) / 120
# Bag Production at x=2: 1939.6303946951905
#
#
# Evaluating Maclaurin Series around a = 0 for x = 3
# Term 0: 1868.5382788214 * ((3 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((3 - 0) ** 1) / 1 = 106.56050331150351
# Term 2: -0.0029148581 * ((3 - 0) ** 2) / 2 = -0.013116861252569428
# Term 3: 0.0439516805 * ((3 - 0) ** 3) / 6 = 0.19778256216958454
# Term 4: -0.0015003593 * ((3 - 0) ** 4) / 24 = -0.00506371276958882
# Term 5: 0.0000301794 * ((3 - 0) ** 5) / 120 = 6.111330054122256e-05
# Maclaurin Series: 1868.5382788214 * ((3 - 0) ** 0) / 1 + 35.5201677705 * ((3 - 0) ** 1) / 1 + -0.0029148581 * ((3 - 0) ** 2) / 2 + 0.0439516805 * ((3 - 0) ** 3) / 6 + -0.0015003593 * ((3 - 0) ** 4) / 24 + 0.0000301794 * ((3 - 0) ** 5) / 120
# Bag Production at x=3: 1975.2784452343262
#
#
# Evaluating Maclaurin Series around a = 0 for x = 4
# Term 0: 1868.5382788214 * ((4 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((4 - 0) ** 1) / 1 = 142.08067108200467
# Term 2: -0.0029148581 * ((4 - 0) ** 2) / 2 = -0.023318864449012315
# Term 3: 0.0439516805 * ((4 - 0) ** 3) / 6 = 0.4688179251427189
# Term 4: -0.0015003593 * ((4 - 0) ** 4) / 24 = -0.016003832950799234
# Term 5: 0.0000301794 * ((4 - 0) ** 5) / 120 = 0.00025753094549058395
# Maclaurin Series: 1868.5382788214 * ((4 - 0) ** 0) / 1 + 35.5201677705 * ((4 - 0) ** 1) / 1 + -0.0029148581 * ((4 - 0) ** 2) / 2 + 0.0439516805 * ((4 - 0) ** 3) / 6 + -0.0015003593 * ((4 - 0) ** 4) / 24 + 0.0000301794 * ((4 - 0) ** 5) / 120
# Bag Production at x=4: 2011.0487026620679
#
#
# Evaluating Maclaurin Series around a = 0 for x = 5
# Term 0: 1868.5382788214 * ((5 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((5 - 0) ** 1) / 1 = 177.60083885250583
# Term 2: -0.0029148581 * ((5 - 0) ** 2) / 2 = -0.03643572570158174
# Term 3: 0.0439516805 * ((5 - 0) ** 3) / 6 = 0.9156600100443729
# Term 4: -0.0015003593 * ((5 - 0) ** 4) / 24 = -0.03907185779003719
# Term 5: 0.0000301794 * ((5 - 0) ** 5) / 120 = 0.0007859220748614012
# Maclaurin Series: 1868.5382788214 * ((5 - 0) ** 0) / 1 + 35.5201677705 * ((5 - 0) ** 1) / 1 + -0.0029148581 * ((5 - 0) ** 2) / 2 + 0.0439516805 * ((5 - 0) ** 3) / 6 + -0.0015003593 * ((5 - 0) ** 4) / 24 + 0.0000301794 * ((5 - 0) ** 5) / 120
# Bag Production at x=5: 2046.9800560225083
#
#
# Evaluating Maclaurin Series around a = 0 for x = 6
# Term 0: 1868.5382788214 * ((6 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((6 - 0) ** 1) / 1 = 213.12100662300702
# Term 2: -0.0029148581 * ((6 - 0) ** 2) / 2 = -0.05246744501027771
# Term 3: 0.0439516805 * ((6 - 0) ** 3) / 6 = 1.5822604973566763
# Term 4: -0.0015003593 * ((6 - 0) ** 4) / 24 = -0.08101940431342113
# Term 5: 0.0000301794 * ((6 - 0) ** 5) / 120 = 0.001955625617319122
# Maclaurin Series: 1868.5382788214 * ((6 - 0) ** 0) / 1 + 35.5201677705 * ((6 - 0) ** 1) / 1 + -0.0029148581 * ((6 - 0) ** 2) / 2 + 0.0439516805 * ((6 - 0) ** 3) / 6 + -0.0015003593 * ((6 - 0) ** 4) / 24 + 0.0000301794 * ((6 - 0) ** 5) / 120
# Bag Production at x=6: 2083.1100147180327
#
#
# Evaluating Maclaurin Series around a = 0 for x = 7
# Term 0: 1868.5382788214 * ((7 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((7 - 0) ** 1) / 1 = 248.64117439350818
# Term 2: -0.0029148581 * ((7 - 0) ** 2) / 2 = -0.07141402237510021
# Term 3: 0.0439516805 * ((7 - 0) ** 3) / 6 = 2.512571067561759
# Term 4: -0.0015003593 * ((7 - 0) ** 4) / 24 = -0.15009844888620688
# Term 5: 0.0000301794 * ((7 - 0) ** 5) / 120 = 0.004226877539902582
# Maclaurin Series: 1868.5382788214 * ((7 - 0) ** 0) / 1 + 35.5201677705 * ((7 - 0) ** 1) / 1 + -0.0029148581 * ((7 - 0) ** 2) / 2 + 0.0439516805 * ((7 - 0) ** 3) / 6 + -0.0015003593 * ((7 - 0) ** 4) / 24 + 0.0000301794 * ((7 - 0) ** 5) / 120
# Bag Production at x=7: 2119.4747386887234
#
#
# Evaluating Maclaurin Series around a = 0 for x = 8
# Term 0: 1868.5382788214 * ((8 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((8 - 0) ** 1) / 1 = 284.16134216400934
# Term 2: -0.0029148581 * ((8 - 0) ** 2) / 2 = -0.09327545779604926
# Term 3: 0.0439516805 * ((8 - 0) ** 3) / 6 = 3.7505434011417513
# Term 4: -0.0015003593 * ((8 - 0) ** 4) / 24 = -0.25606132721278774
# Term 5: 0.0000301794 * ((8 - 0) ** 5) / 120 = 0.008240990255698686
# Maclaurin Series: 1868.5382788214 * ((8 - 0) ** 0) / 1 + 35.5201677705 * ((8 - 0) ** 1) / 1 + -0.0029148581 * ((8 - 0) ** 2) / 2 + 0.0439516805 * ((8 - 0) ** 3) / 6 + -0.0015003593 * ((8 - 0) ** 4) / 24 + 0.0000301794 * ((8 - 0) ** 5) / 120
# Bag Production at x=8: 2156.109068591773
#
#
# Evaluating Maclaurin Series around a = 0 for x = 9
# Term 0: 1868.5382788214 * ((9 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((9 - 0) ** 1) / 1 = 319.68150993451053
# Term 2: -0.0029148581 * ((9 - 0) ** 2) / 2 = -0.11805175127312484
# Term 3: 0.0439516805 * ((9 - 0) ** 3) / 6 = 5.340129178578782
# Term 4: -0.0015003593 * ((9 - 0) ** 4) / 24 = -0.4101607343366944
# Term 5: 0.0000301794 * ((9 - 0) ** 5) / 120 = 0.014850532031517082
# Maclaurin Series: 1868.5382788214 * ((9 - 0) ** 0) / 1 + 35.5201677705 * ((9 - 0) ** 1) / 1 + -0.0029148581 * ((9 - 0) ** 2) / 2 + 0.0439516805 * ((9 - 0) ** 3) / 6 + -0.0015003593 * ((9 - 0) ** 4) / 24 + 0.0000301794 * ((9 - 0) ** 5) / 120
# Bag Production at x=9: 2193.0465559808863
#
#
# Evaluating Maclaurin Series around a = 0 for x = 10
# Term 0: 1868.5382788214 * ((10 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((10 - 0) ** 1) / 1 = 355.20167770501166
# Term 2: -0.0029148581 * ((10 - 0) ** 2) / 2 = -0.14574290280632696
# Term 3: 0.0439516805 * ((10 - 0) ** 3) / 6 = 7.325280080354983
# Term 4: -0.0015003593 * ((10 - 0) ** 4) / 24 = -0.625149724640595
# Term 5: 0.0000301794 * ((10 - 0) ** 5) / 120 = 0.02514950639556484
# Maclaurin Series: 1868.5382788214 * ((10 - 0) ** 0) / 1 + 35.5201677705 * ((10 - 0) ** 1) / 1 + -0.0029148581 * ((10 - 0) ** 2) / 2 + 0.0439516805 * ((10 - 0) ** 3) / 6 + -0.0015003593 * ((10 - 0) ** 4) / 24 + 0.0000301794 * ((10 - 0) ** 5) / 120
# Bag Production at x=10: 2230.31949348569
#
#
# Evaluating Maclaurin Series around a = 0 for x = 11
# Term 0: 1868.5382788214 * ((11 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((11 - 0) ** 1) / 1 = 390.72184547551285
# Term 2: -0.0029148581 * ((11 - 0) ** 2) / 2 = -0.17634891239565564
# Term 3: 0.0439516805 * ((11 - 0) ** 3) / 6 = 9.749947786952482
# Term 4: -0.0015003593 * ((11 - 0) ** 4) / 24 = -0.9152817118462951
# Term 5: 0.0000301794 * ((11 - 0) ** 5) / 120 = 0.040503531545121124
# Maclaurin Series: 1868.5382788214 * ((11 - 0) ** 0) / 1 + 35.5201677705 * ((11 - 0) ** 1) / 1 + -0.0029148581 * ((11 - 0) ** 2) / 2 + 0.0439516805 * ((11 - 0) ** 3) / 6 + -0.0015003593 * ((11 - 0) ** 4) / 24 + 0.0000301794 * ((11 - 0) ** 5) / 120
# Bag Production at x=11: 2267.9589449911437
#
#
# Evaluating Maclaurin Series around a = 0 for x = 12
# Term 0: 1868.5382788214 * ((12 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((12 - 0) ** 1) / 1 = 426.24201324601404
# Term 2: -0.0029148581 * ((12 - 0) ** 2) / 2 = -0.20986978004111084
# Term 3: 0.0439516805 * ((12 - 0) ** 3) / 6 = 12.65808397885341
# Term 4: -0.0015003593 * ((12 - 0) ** 4) / 24 = -1.296310469014738
# Term 5: 0.0000301794 * ((12 - 0) ** 5) / 120 = 0.0625800197542119
# Maclaurin Series: 1868.5382788214 * ((12 - 0) ** 0) / 1 + 35.5201677705 * ((12 - 0) ** 1) / 1 + -0.0029148581 * ((12 - 0) ** 2) / 2 + 0.0439516805 * ((12 - 0) ** 3) / 6 + -0.0015003593 * ((12 - 0) ** 4) / 24 + 0.0000301794 * ((12 - 0) ** 5) / 120
# Bag Production at x=12: 2305.9947758169405
#
#
# Evaluating Maclaurin Series around a = 0 for x = 13
# Term 0: 1868.5382788214 * ((13 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((13 - 0) ** 1) / 1 = 461.76218101651517
# Term 2: -0.0029148581 * ((13 - 0) ** 2) / 2 = -0.24630550574269258
# Term 3: 0.0439516805 * ((13 - 0) ** 3) / 6 = 16.0936403365399
# Term 4: -0.0015003593 * ((13 - 0) ** 4) / 24 = -1.7854901285460034
# Term 5: 0.0000301794 * ((13 - 0) ** 5) / 120 = 0.09337835678128455
# Maclaurin Series: 1868.5382788214 * ((13 - 0) ** 0) / 1 + 35.5201677705 * ((13 - 0) ** 1) / 1 + -0.0029148581 * ((13 - 0) ** 2) / 2 + 0.0439516805 * ((13 - 0) ** 3) / 6 + -0.0015003593 * ((13 - 0) ** 4) / 24 + 0.0000301794 * ((13 - 0) ** 5) / 120
# Bag Production at x=13: 2344.4556828969226
#
#
# Evaluating Maclaurin Series around a = 0 for x = 14
# Term 0: 1868.5382788214 * ((14 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((14 - 0) ** 1) / 1 = 497.28234878701636
# Term 2: -0.0029148581 * ((14 - 0) ** 2) / 2 = -0.28565608950040083
# Term 3: 0.0439516805 * ((14 - 0) ** 3) / 6 = 20.100568540494073
# Term 4: -0.0015003593 * ((14 - 0) ** 4) / 24 = -2.40157518217931
# Term 5: 0.0000301794 * ((14 - 0) ** 5) / 120 = 0.13526008127688263
# Maclaurin Series: 1868.5382788214 * ((14 - 0) ** 0) / 1 + 35.5201677705 * ((14 - 0) ** 1) / 1 + -0.0029148581 * ((14 - 0) ** 2) / 2 + 0.0439516805 * ((14 - 0) ** 3) / 6 + -0.0015003593 * ((14 - 0) ** 4) / 24 + 0.0000301794 * ((14 - 0) ** 5) / 120
# Bag Production at x=14: 2383.3692249584824
#
#
# Evaluating Maclaurin Series around a = 0 for x = 15
# Term 0: 1868.5382788214 * ((15 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((15 - 0) ** 1) / 1 = 532.8025165575175
# Term 2: -0.0029148581 * ((15 - 0) ** 2) / 2 = -0.3279215313142357
# Term 3: 0.0439516805 * ((15 - 0) ** 3) / 6 = 24.72282027119807
# Term 4: -0.0015003593 * ((15 - 0) ** 4) / 24 = -3.1648204809930127
# Term 5: 0.0000301794 * ((15 - 0) ** 5) / 120 = 0.19097906419132046
# Maclaurin Series: 1868.5382788214 * ((15 - 0) ** 0) / 1 + 35.5201677705 * ((15 - 0) ** 1) / 1 + -0.0029148581 * ((15 - 0) ** 2) / 2 + 0.0439516805 * ((15 - 0) ** 3) / 6 + -0.0015003593 * ((15 - 0) ** 4) / 24 + 0.0000301794 * ((15 - 0) ** 5) / 120
# Bag Production at x=15: 2422.7618527019745
#
#
# Evaluating Maclaurin Series around a = 0 for x = 16
# Term 0: 1868.5382788214 * ((16 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((16 - 0) ** 1) / 1 = 568.3226843280187
# Term 2: -0.0029148581 * ((16 - 0) ** 2) / 2 = -0.37310183118419704
# Term 3: 0.0439516805 * ((16 - 0) ** 3) / 6 = 30.00434720913401
# Term 4: -0.0015003593 * ((16 - 0) ** 4) / 24 = -4.096981235404604
# Term 5: 0.0000301794 * ((16 - 0) ** 5) / 120 = 0.26371168818235796
# Maclaurin Series: 1868.5382788214 * ((16 - 0) ** 0) / 1 + 35.5201677705 * ((16 - 0) ** 1) / 1 + -0.0029148581 * ((16 - 0) ** 2) / 2 + 0.0439516805 * ((16 - 0) ** 3) / 6 + -0.0015003593 * ((16 - 0) ** 4) / 24 + 0.0000301794 * ((16 - 0) ** 5) / 120
# Bag Production at x=16: 2462.658938980121
#
#
# Evaluating Maclaurin Series around a = 0 for x = 17
# Term 0: 1868.5382788214 * ((17 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((17 - 0) ** 1) / 1 = 603.8428520985199
# Term 2: -0.0029148581 * ((17 - 0) ** 2) / 2 = -0.4211969891102849
# Term 3: 0.0439516805 * ((17 - 0) ** 3) / 6 = 35.989101034784035
# Term 4: -0.0015003593 * ((17 - 0) ** 4) / 24 = -5.221313015170714
# Term 5: 0.0000301794 * ((17 - 0) ** 5) / 120 = 0.3570870270228751
# Maclaurin Series: 1868.5382788214 * ((17 - 0) ** 0) / 1 + 35.5201677705 * ((17 - 0) ** 1) / 1 + -0.0029148581 * ((17 - 0) ** 2) / 2 + 0.0439516805 * ((17 - 0) ** 3) / 6 + -0.0015003593 * ((17 - 0) ** 4) / 24 + 0.0000301794 * ((17 - 0) ** 5) / 120
# Bag Production at x=17: 2503.0848089774204
#
#
# Evaluating Maclaurin Series around a = 0 for x = 18
# Term 0: 1868.5382788214 * ((18 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((18 - 0) ** 1) / 1 = 639.3630198690211
# Term 2: -0.0029148581 * ((18 - 0) ** 2) / 2 = -0.47220700509249935
# Term 3: 0.0439516805 * ((18 - 0) ** 3) / 6 = 42.72103342863026
# Term 4: -0.0015003593 * ((18 - 0) ** 4) / 24 = -6.562571749387111
# Term 5: 0.0000301794 * ((18 - 0) ** 5) / 120 = 0.4752170250085466
# Maclaurin Series: 1868.5382788214 * ((18 - 0) ** 0) / 1 + 35.5201677705 * ((18 - 0) ** 1) / 1 + -0.0029148581 * ((18 - 0) ** 2) / 2 + 0.0439516805 * ((18 - 0) ** 3) / 6 + -0.0015003593 * ((18 - 0) ** 4) / 24 + 0.0000301794 * ((18 - 0) ** 5) / 120
# Bag Production at x=18: 2544.0627703895548
#
#
# Evaluating Maclaurin Series around a = 0 for x = 19
# Term 0: 1868.5382788214 * ((19 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((19 - 0) ** 1) / 1 = 674.8831876395221
# Term 2: -0.0029148581 * ((19 - 0) ** 2) / 2 = -0.5261318791308404
# Term 3: 0.0439516805 * ((19 - 0) ** 3) / 6 = 50.244096071154836
# Term 4: -0.0015003593 * ((19 - 0) ** 4) / 24 = -8.1470137264887
# Term 5: 0.0000301794 * ((19 - 0) ** 5) / 120 = 0.6227266763655169
# Maclaurin Series: 1868.5382788214 * ((19 - 0) ** 0) / 1 + 35.5201677705 * ((19 - 0) ** 1) / 1 + -0.0029148581 * ((19 - 0) ** 2) / 2 + 0.0439516805 * ((19 - 0) ** 3) / 6 + -0.0015003593 * ((19 - 0) ** 4) / 24 + 0.0000301794 * ((19 - 0) ** 5) / 120
# Bag Production at x=19: 2585.6151436027976
#
#
# Evaluating Maclaurin Series around a = 0 for x = 20
# Term 0: 1868.5382788214 * ((20 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((20 - 0) ** 1) / 1 = 710.4033554100233
# Term 2: -0.0029148581 * ((20 - 0) ** 2) / 2 = -0.5829716112253078
# Term 3: 0.0439516805 * ((20 - 0) ** 3) / 6 = 58.60224064283987
# Term 4: -0.0015003593 * ((20 - 0) ** 4) / 24 = -10.00239559424952
# Term 5: 0.0000301794 * ((20 - 0) ** 5) / 120 = 0.8047842046580749
# Maclaurin Series: 1868.5382788214 * ((20 - 0) ** 0) / 1 + 35.5201677705 * ((20 - 0) ** 1) / 1 + -0.0029148581 * ((20 - 0) ** 2) / 2 + 0.0439516805 * ((20 - 0) ** 3) / 6 + -0.0015003593 * ((20 - 0) ** 4) / 24 + 0.0000301794 * ((20 - 0) ** 5) / 120
# Bag Production at x=20: 2627.7632918734207
#
#
# Evaluating Maclaurin Series around a = 0 for x = 21
# Term 0: 1868.5382788214 * ((21 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((21 - 0) ** 1) / 1 = 745.9235231805245
# Term 2: -0.0029148581 * ((21 - 0) ** 2) / 2 = -0.642726201375902
# Term 3: 0.0439516805 * ((21 - 0) ** 3) / 6 = 67.8394188241675
# Term 4: -0.0015003593 * ((21 - 0) ** 4) / 24 = -12.157974359782756
# Term 5: 0.0000301794 * ((21 - 0) ** 5) / 120 = 1.0271312421963275
# Maclaurin Series: 1868.5382788214 * ((21 - 0) ** 0) / 1 + 35.5201677705 * ((21 - 0) ** 1) / 1 + -0.0029148581 * ((21 - 0) ** 2) / 2 + 0.0439516805 * ((21 - 0) ** 3) / 6 + -0.0015003593 * ((21 - 0) ** 4) / 24 + 0.0000301794 * ((21 - 0) ** 5) / 120
# Bag Production at x=21: 2670.5276515071046
#
#
# Evaluating Maclaurin Series around a = 0 for x = 22
# Term 0: 1868.5382788214 * ((22 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((22 - 0) ** 1) / 1 = 781.4436909510257
# Term 2: -0.0029148581 * ((22 - 0) ** 2) / 2 = -0.7053956495826226
# Term 3: 0.0439516805 * ((22 - 0) ** 3) / 6 = 77.99958229561986
# Term 4: -0.0015003593 * ((22 - 0) ** 4) / 24 = -14.644507389540722
# Term 5: 0.0000301794 * ((22 - 0) ** 5) / 120 = 1.296113009443876
# Maclaurin Series: 1868.5382788214 * ((22 - 0) ** 0) / 1 + 35.5201677705 * ((22 - 0) ** 1) / 1 + -0.0029148581 * ((22 - 0) ** 2) / 2 + 0.0439516805 * ((22 - 0) ** 3) / 6 + -0.0015003593 * ((22 - 0) ** 4) / 24 + 0.0000301794 * ((22 - 0) ** 5) / 120
# Bag Production at x=22: 2713.9277620383414
#
#
# Evaluating Maclaurin Series around a = 0 for x = 23
# Term 0: 1868.5382788214 * ((23 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((23 - 0) ** 1) / 1 = 816.9638587215269
# Term 2: -0.0029148581 * ((23 - 0) ** 2) / 2 = -0.7709799558454696
# Term 3: 0.0439516805 * ((23 - 0) ** 3) / 6 = 89.12668273767908
# Term 4: -0.0015003593 * ((23 - 0) ** 4) / 24 = -17.49425240931488
# Term 5: 0.0000301794 * ((23 - 0) ** 5) / 120 = 1.61870849442549
# Maclaurin Series: 1868.5382788214 * ((23 - 0) ** 0) / 1 + 35.5201677705 * ((23 - 0) ** 1) / 1 + -0.0029148581 * ((23 - 0) ** 2) / 2 + 0.0439516805 * ((23 - 0) ** 3) / 6 + -0.0015003593 * ((23 - 0) ** 4) / 24 + 0.0000301794 * ((23 - 0) ** 5) / 120
# Bag Production at x=23: 2757.9822964098457
#
#
# Evaluating Maclaurin Series around a = 0 for x = 24
# Term 0: 1868.5382788214 * ((24 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((24 - 0) ** 1) / 1 = 852.4840264920281
# Term 2: -0.0029148581 * ((24 - 0) ** 2) / 2 = -0.8394791201644434
# Term 3: 0.0439516805 * ((24 - 0) ** 3) / 6 = 101.26467183082728
# Term 4: -0.0015003593 * ((24 - 0) ** 4) / 24 = -20.740967504235808
# Term 5: 0.0000301794 * ((24 - 0) ** 5) / 120 = 2.002560632134781
# Maclaurin Series: 1868.5382788214 * ((24 - 0) ** 0) / 1 + 35.5201677705 * ((24 - 0) ** 1) / 1 + -0.0029148581 * ((24 - 0) ** 2) / 2 + 0.0439516805 * ((24 - 0) ** 3) / 6 + -0.0015003593 * ((24 - 0) ** 4) / 24 + 0.0000301794 * ((24 - 0) ** 5) / 120
# Bag Production at x=24: 2802.709091151965
#
#
# Evaluating Maclaurin Series around a = 0 for x = 25
# Term 0: 1868.5382788214 * ((25 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((25 - 0) ** 1) / 1 = 888.0041942625292
# Term 2: -0.0029148581 * ((25 - 0) ** 2) / 2 = -0.9108931425395436
# Term 3: 0.0439516805 * ((25 - 0) ** 3) / 6 = 114.45750125554662
# Term 4: -0.0015003593 * ((25 - 0) ** 4) / 24 = -24.419911118773243
# Term 5: 0.0000301794 * ((25 - 0) ** 5) / 120 = 2.4560064839418785
# Maclaurin Series: 1868.5382788214 * ((25 - 0) ** 0) / 1 + 35.5201677705 * ((25 - 0) ** 1) / 1 + -0.0029148581 * ((25 - 0) ** 2) / 2 + 0.0439516805 * ((25 - 0) ** 3) / 6 + -0.0015003593 * ((25 - 0) ** 4) / 24 + 0.0000301794 * ((25 - 0) ** 5) / 120
# Bag Production at x=25: 2848.12517656208
#
#
# Evaluating Maclaurin Series around a = 0 for x = 26
# Term 0: 1868.5382788214 * ((26 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((26 - 0) ** 1) / 1 = 923.5243620330303
# Term 2: -0.0029148581 * ((26 - 0) ** 2) / 2 = -0.9852220229707703
# Term 3: 0.0439516805 * ((26 - 0) ** 3) / 6 = 128.7491226923192
# Term 4: -0.0015003593 * ((26 - 0) ** 4) / 24 = -28.567842056736055
# Term 5: 0.0000301794 * ((26 - 0) ** 5) / 120 = 2.9881074170011055
# Maclaurin Series: 1868.5382788214 * ((26 - 0) ** 0) / 1 + 35.5201677705 * ((26 - 0) ** 1) / 1 + -0.0029148581 * ((26 - 0) ** 2) / 2 + 0.0439516805 * ((26 - 0) ** 3) / 6 + -0.0015003593 * ((26 - 0) ** 4) / 24 + 0.0000301794 * ((26 - 0) ** 5) / 120
# Bag Production at x=26: 2894.246806884019
#
#
# Evaluating Maclaurin Series around a = 0 for x = 27
# Term 0: 1868.5382788214 * ((27 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((27 - 0) ** 1) / 1 = 959.0445298035315
# Term 2: -0.0029148581 * ((27 - 0) ** 2) / 2 = -1.0624657614581237
# Term 3: 0.0439516805 * ((27 - 0) ** 3) / 6 = 144.18348782162712
# Term 4: -0.0015003593 * ((27 - 0) ** 4) / 24 = -33.223019481272246
# Term 5: 0.0000301794 * ((27 - 0) ** 5) / 120 = 3.6086792836586508
# Maclaurin Series: 1868.5382788214 * ((27 - 0) ** 0) / 1 + 35.5201677705 * ((27 - 0) ** 1) / 1 + -0.0029148581 * ((27 - 0) ** 2) / 2 + 0.0439516805 * ((27 - 0) ** 3) / 6 + -0.0015003593 * ((27 - 0) ** 4) / 24 + 0.0000301794 * ((27 - 0) ** 5) / 120
# Bag Production at x=27: 2941.089490487462
#
#
# Evaluating Maclaurin Series around a = 0 for x = 28
# Term 0: 1868.5382788214 * ((28 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((28 - 0) ** 1) / 1 = 994.5646975740327
# Term 2: -0.0029148581 * ((28 - 0) ** 2) / 2 = -1.1426243580016033
# Term 3: 0.0439516805 * ((28 - 0) ** 3) / 6 = 160.8045483239526
# Term 4: -0.0015003593 * ((28 - 0) ** 4) / 24 = -38.42520291486896
# Term 5: 0.0000301794 * ((28 - 0) ** 5) / 120 = 4.328322600860244
# Maclaurin Series: 1868.5382788214 * ((28 - 0) ** 0) / 1 + 35.5201677705 * ((28 - 0) ** 1) / 1 + -0.0029148581 * ((28 - 0) ** 2) / 2 + 0.0439516805 * ((28 - 0) ** 3) / 6 + -0.0015003593 * ((28 - 0) ** 4) / 24 + 0.0000301794 * ((28 - 0) ** 5) / 120
# Bag Production at x=28: 2988.6680200473497
#
#
# Evaluating Maclaurin Series around a = 0 for x = 29
# Term 0: 1868.5382788214 * ((29 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((29 - 0) ** 1) / 1 = 1030.084865344534
# Term 2: -0.0029148581 * ((29 - 0) ** 2) / 2 = -1.22569781260121
# Term 3: 0.0439516805 * ((29 - 0) ** 3) / 6 = 178.65625587977766
# Term 4: -0.0015003593 * ((29 - 0) ** 4) / 24 = -44.21565223935247
# Term 5: 0.0000301794 * ((29 - 0) ** 5) / 120 = 5.158452729558833
# Maclaurin Series: 1868.5382788214 * ((29 - 0) ** 0) / 1 + 35.5201677705 * ((29 - 0) ** 1) / 1 + -0.0029148581 * ((29 - 0) ** 2) / 2 + 0.0439516805 * ((29 - 0) ** 3) / 6 + -0.0015003593 * ((29 - 0) ** 4) / 24 + 0.0000301794 * ((29 - 0) ** 5) / 120
# Bag Production at x=29: 3036.996502723292
#
#
# Evaluating Maclaurin Series around a = 0 for x = 30
# Term 0: 1868.5382788214 * ((30 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((30 - 0) ** 1) / 1 = 1065.605033115035
# Term 2: -0.0029148581 * ((30 - 0) ** 2) / 2 = -1.3116861252569427
# Term 3: 0.0439516805 * ((30 - 0) ** 3) / 6 = 197.78256216958457
# Term 4: -0.0015003593 * ((30 - 0) ** 4) / 24 = -50.6371276958882
# Term 5: 0.0000301794 * ((30 - 0) ** 5) / 120 = 6.111330054122255
# Maclaurin Series: 1868.5382788214 * ((30 - 0) ** 0) / 1 + 35.5201677705 * ((30 - 0) ** 1) / 1 + -0.0029148581 * ((30 - 0) ** 2) / 2 + 0.0439516805 * ((30 - 0) ** 3) / 6 + -0.0015003593 * ((30 - 0) ** 4) / 24 + 0.0000301794 * ((30 - 0) ** 5) / 120
# Bag Production at x=30: 3086.088390338972
#
#
# Evaluating Maclaurin Series around a = 0 for x = 31
# Term 0: 1868.5382788214 * ((31 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((31 - 0) ** 1) / 1 = 1101.1252008855363
# Term 2: -0.0029148581 * ((31 - 0) ** 2) / 2 = -1.4005892959688022
# Term 3: 0.0439516805 * ((31 - 0) ** 3) / 6 = 218.2274188738553
# Term 4: -0.0015003593 * ((31 - 0) ** 4) / 24 = -57.7338898849807
# Term 5: 0.0000301794 * ((31 - 0) ** 5) / 120 = 7.200090161740915
# Maclaurin Series: 1868.5382788214 * ((31 - 0) ** 0) / 1 + 35.5201677705 * ((31 - 0) ** 1) / 1 + -0.0029148581 * ((31 - 0) ** 2) / 2 + 0.0439516805 * ((31 - 0) ** 3) / 6 + -0.0015003593 * ((31 - 0) ** 4) / 24 + 0.0000301794 * ((31 - 0) ** 5) / 120
# Bag Production at x=31: 3135.956509561557
#
#
# Evaluating Maclaurin Series around a = 0 for x = 32
# Term 0: 1868.5382788214 * ((32 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((32 - 0) ** 1) / 1 = 1136.6453686560374
# Term 2: -0.0029148581 * ((32 - 0) ** 2) / 2 = -1.4924073247367882
# Term 3: 0.0439516805 * ((32 - 0) ** 3) / 6 = 240.03477767307209
# Term 4: -0.0015003593 * ((32 - 0) ** 4) / 24 = -65.55169976647366
# Term 5: 0.0000301794 * ((32 - 0) ** 5) / 120 = 8.438774021835455
# Maclaurin Series: 1868.5382788214 * ((32 - 0) ** 0) / 1 + 35.5201677705 * ((32 - 0) ** 1) / 1 + -0.0029148581 * ((32 - 0) ** 2) / 2 + 0.0439516805 * ((32 - 0) ** 3) / 6 + -0.0015003593 * ((32 - 0) ** 4) / 24 + 0.0000301794 * ((32 - 0) ** 5) / 120
# Bag Production at x=32: 3186.6130920811092
#
#
# Evaluating Maclaurin Series around a = 0 for x = 33
# Term 0: 1868.5382788214 * ((33 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((33 - 0) ** 1) / 1 = 1172.1655364265384
# Term 2: -0.0029148581 * ((33 - 0) ** 2) / 2 = -1.5871402115609008
# Term 3: 0.0439516805 * ((33 - 0) ** 3) / 6 = 263.248590247717
# Term 4: -0.0015003593 * ((33 - 0) ** 4) / 24 = -74.13781865954992
# Term 5: 0.0000301794 * ((33 - 0) ** 5) / 120 = 9.842358165464434
# Maclaurin Series: 1868.5382788214 * ((33 - 0) ** 0) / 1 + 35.5201677705 * ((33 - 0) ** 1) / 1 + -0.0029148581 * ((33 - 0) ** 2) / 2 + 0.0439516805 * ((33 - 0) ** 3) / 6 + -0.0015003593 * ((33 - 0) ** 4) / 24 + 0.0000301794 * ((33 - 0) ** 5) / 120
# Bag Production at x=33: 3238.069804789984
#
#
# Evaluating Maclaurin Series around a = 0 for x = 34
# Term 0: 1868.5382788214 * ((34 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((34 - 0) ** 1) / 1 = 1207.6857041970397
# Term 2: -0.0029148581 * ((34 - 0) ** 2) / 2 = -1.6847879564411397
# Term 3: 0.0439516805 * ((34 - 0) ** 3) / 6 = 287.9128082782723
# Term 4: -0.0015003593 * ((34 - 0) ** 4) / 24 = -83.54100824273142
# Term 5: 0.0000301794 * ((34 - 0) ** 5) / 120 = 11.426784864732003
# Maclaurin Series: 1868.5382788214 * ((34 - 0) ** 0) / 1 + 35.5201677705 * ((34 - 0) ** 1) / 1 + -0.0029148581 * ((34 - 0) ** 2) / 2 + 0.0439516805 * ((34 - 0) ** 3) / 6 + -0.0015003593 * ((34 - 0) ** 4) / 24 + 0.0000301794 * ((34 - 0) ** 5) / 120
# Bag Production at x=34: 3290.337779962246
#
#
# Evaluating Maclaurin Series around a = 0 for x = 35
# Term 0: 1868.5382788214 * ((35 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((35 - 0) ** 1) / 1 = 1243.2058719675408
# Term 2: -0.0029148581 * ((35 - 0) ** 2) / 2 = -1.7853505593775054
# Term 3: 0.0439516805 * ((35 - 0) ** 3) / 6 = 314.0713834452199
# Term 4: -0.0015003593 * ((35 - 0) ** 4) / 24 = -93.81153055387931
# Term 5: 0.0000301794 * ((35 - 0) ** 5) / 120 = 13.20899231219557
# Maclaurin Series: 1868.5382788214 * ((35 - 0) ** 0) / 1 + 35.5201677705 * ((35 - 0) ** 1) / 1 + -0.0029148581 * ((35 - 0) ** 2) / 2 + 0.0439516805 * ((35 - 0) ** 3) / 6 + -0.0015003593 * ((35 - 0) ** 4) / 24 + 0.0000301794 * ((35 - 0) ** 5) / 120
# Bag Production at x=35: 3343.4276454330743
#
#
# Evaluating Maclaurin Series around a = 0 for x = 36
# Term 0: 1868.5382788214 * ((36 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((36 - 0) ** 1) / 1 = 1278.7260397380421
# Term 2: -0.0029148581 * ((36 - 0) ** 2) / 2 = -1.8888280203699974
# Term 3: 0.0439516805 * ((36 - 0) ** 3) / 6 = 341.76826742904206
# Term 4: -0.0015003593 * ((36 - 0) ** 4) / 24 = -105.00114799019377
# Term 5: 0.0000301794 * ((36 - 0) ** 5) / 120 = 15.206944800273492
# Maclaurin Series: 1868.5382788214 * ((36 - 0) ** 0) / 1 + 35.5201677705 * ((36 - 0) ** 1) / 1 + -0.0029148581 * ((36 - 0) ** 2) / 2 + 0.0439516805 * ((36 - 0) ** 3) / 6 + -0.0015003593 * ((36 - 0) ** 4) / 24 + 0.0000301794 * ((36 - 0) ** 5) / 120
# Bag Production at x=36: 3397.349554778169
#
#
# Evaluating Maclaurin Series around a = 0 for x = 37
# Term 0: 1868.5382788214 * ((37 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((37 - 0) ** 1) / 1 = 1314.2462075085432
# Term 2: -0.0029148581 * ((37 - 0) ** 2) / 2 = -1.9952203394186163
# Term 3: 0.0439516805 * ((37 - 0) ** 3) / 6 = 371.04741191022094
# Term 4: -0.0015003593 * ((37 - 0) ** 4) / 24 = -117.16312330821422
# Term 5: 0.0000301794 * ((37 - 0) ** 5) / 120 = 17.43966290065273
# Maclaurin Series: 1868.5382788214 * ((37 - 0) ** 0) / 1 + 35.5201677705 * ((37 - 0) ** 1) / 1 + -0.0029148581 * ((37 - 0) ** 2) / 2 + 0.0439516805 * ((37 - 0) ** 3) / 6 + -0.0015003593 * ((37 - 0) ** 4) / 24 + 0.0000301794 * ((37 - 0) ** 5) / 120
# Bag Production at x=37: 3452.1132174931586
#
#
# Evaluating Maclaurin Series around a = 0 for x = 38
# Term 0: 1868.5382788214 * ((38 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((38 - 0) ** 1) / 1 = 1349.7663752790443
# Term 2: -0.0029148581 * ((38 - 0) ** 2) / 2 = -2.1045275165233615
# Term 3: 0.0439516805 * ((38 - 0) ** 3) / 6 = 401.9527685692387
# Term 4: -0.0015003593 * ((38 - 0) ** 4) / 24 = -130.3522196238192
# Term 5: 0.0000301794 * ((38 - 0) ** 5) / 120 = 19.92725364369654
# Maclaurin Series: 1868.5382788214 * ((38 - 0) ** 0) / 1 + 35.5201677705 * ((38 - 0) ** 1) / 1 + -0.0029148581 * ((38 - 0) ** 2) / 2 + 0.0439516805 * ((38 - 0) ** 3) / 6 + -0.0015003593 * ((38 - 0) ** 4) / 24 + 0.0000301794 * ((38 - 0) ** 5) / 120
# Bag Production at x=38: 3507.727929173012
#
#
# Evaluating Maclaurin Series around a = 0 for x = 39
# Term 0: 1868.5382788214 * ((39 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((39 - 0) ** 1) / 1 = 1385.2865430495456
# Term 2: -0.0029148581 * ((39 - 0) ** 2) / 2 = -2.216749551684233
# Term 3: 0.0439516805 * ((39 - 0) ** 3) / 6 = 434.5282890865772
# Term 4: -0.0015003593 * ((39 - 0) ** 4) / 24 = -144.6247004122263
# Term 5: 0.0000301794 * ((39 - 0) ** 5) / 120 = 22.69094069785215
# Maclaurin Series: 1868.5382788214 * ((39 - 0) ** 0) / 1 + 35.5201677705 * ((39 - 0) ** 1) / 1 + -0.0029148581 * ((39 - 0) ** 2) / 2 + 0.0439516805 * ((39 - 0) ** 3) / 6 + -0.0015003593 * ((39 - 0) ** 4) / 24 + 0.0000301794 * ((39 - 0) ** 5) / 120
# Bag Production at x=39: 3564.202601691439
#
#
# Evaluating Maclaurin Series around a = 0 for x = 40
# Term 0: 1868.5382788214 * ((40 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((40 - 0) ** 1) / 1 = 1420.8067108200466
# Term 2: -0.0029148581 * ((40 - 0) ** 2) / 2 = -2.3318864449012313
# Term 3: 0.0439516805 * ((40 - 0) ** 3) / 6 = 468.81792514271893
# Term 4: -0.0015003593 * ((40 - 0) ** 4) / 24 = -160.03832950799233
# Term 5: 0.0000301794 * ((40 - 0) ** 5) / 120 = 25.753094549058396
# Maclaurin Series: 1868.5382788214 * ((40 - 0) ** 0) / 1 + 35.5201677705 * ((40 - 0) ** 1) / 1 + -0.0029148581 * ((40 - 0) ** 2) / 2 + 0.0439516805 * ((40 - 0) ** 3) / 6 + -0.0015003593 * ((40 - 0) ** 4) / 24 + 0.0000301794 * ((40 - 0) ** 5) / 120
# Bag Production at x=40: 3621.5457933803054
#
#
# Evaluating Maclaurin Series around a = 0 for x = 41
# Term 0: 1868.5382788214 * ((41 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((41 - 0) ** 1) / 1 = 1456.326878590548
# Term 2: -0.0029148581 * ((41 - 0) ** 2) / 2 = -2.4499381961743563
# Term 3: 0.0439516805 * ((41 - 0) ** 3) / 6 = 504.86562841814583
# Term 4: -0.0015003593 * ((41 - 0) ** 4) / 24 = -176.65237110501326
# Term 5: 0.0000301794 * ((41 - 0) ** 5) / 120 = 29.137262680153455
# Maclaurin Series: 1868.5382788214 * ((41 - 0) ** 0) / 1 + 35.5201677705 * ((41 - 0) ** 1) / 1 + -0.0029148581 * ((41 - 0) ** 2) / 2 + 0.0439516805 * ((41 - 0) ** 3) / 6 + -0.0015003593 * ((41 - 0) ** 4) / 24 + 0.0000301794 * ((41 - 0) ** 5) / 120
# Bag Production at x=41: 3679.7657392090346
#
#
# Evaluating Maclaurin Series around a = 0 for x = 42
# Term 0: 1868.5382788214 * ((42 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((42 - 0) ** 1) / 1 = 1491.847046361049
# Term 2: -0.0029148581 * ((42 - 0) ** 2) / 2 = -2.570904805503608
# Term 3: 0.0439516805 * ((42 - 0) ** 3) / 6 = 542.71535059334
# Term 4: -0.0015003593 * ((42 - 0) ** 4) / 24 = -194.5275897565241
# Term 5: 0.0000301794 * ((42 - 0) ** 5) / 120 = 32.86819975028248
# Maclaurin Series: 1868.5382788214 * ((42 - 0) ** 0) / 1 + 35.5201677705 * ((42 - 0) ** 1) / 1 + -0.0029148581 * ((42 - 0) ** 2) / 2 + 0.0439516805 * ((42 - 0) ** 3) / 6 + -0.0015003593 * ((42 - 0) ** 4) / 24 + 0.0000301794 * ((42 - 0) ** 5) / 120
# Bag Production at x=42: 3738.8703809640183
#
#
# Evaluating Maclaurin Series around a = 0 for x = 43
# Term 0: 1868.5382788214 * ((43 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((43 - 0) ** 1) / 1 = 1527.36721413155
# Term 2: -0.0029148581 * ((43 - 0) ** 2) / 2 = -2.6947862728889858
# Term 3: 0.0439516805 * ((43 - 0) ** 3) / 6 = 582.4110433487837
# Term 4: -0.0015003593 * ((43 - 0) ** 4) / 24 = -213.7262503750991
# Term 5: 0.0000301794 * ((43 - 0) ** 5) / 120 = 36.97189777430529
# Maclaurin Series: 1868.5382788214 * ((43 - 0) ** 0) / 1 + 35.5201677705 * ((43 - 0) ** 1) / 1 + -0.0029148581 * ((43 - 0) ** 2) / 2 + 0.0439516805 * ((43 - 0) ** 3) / 6 + -0.0015003593 * ((43 - 0) ** 4) / 24 + 0.0000301794 * ((43 - 0) ** 5) / 120
# Bag Production at x=43: 3798.867397428026
#
#
# Evaluating Maclaurin Series around a = 0 for x = 44
# Term 0: 1868.5382788214 * ((44 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((44 - 0) ** 1) / 1 = 1562.8873819020514
# Term 2: -0.0029148581 * ((44 - 0) ** 2) / 2 = -2.8215825983304903
# Term 3: 0.0439516805 * ((44 - 0) ** 3) / 6 = 623.9966583649589
# Term 4: -0.0015003593 * ((44 - 0) ** 4) / 24 = -234.31211823265156
# Term 5: 0.0000301794 * ((44 - 0) ** 5) / 120 = 41.47561630220403
# Maclaurin Series: 1868.5382788214 * ((44 - 0) ** 0) / 1 + 35.5201677705 * ((44 - 0) ** 1) / 1 + -0.0029148581 * ((44 - 0) ** 2) / 2 + 0.0439516805 * ((44 - 0) ** 3) / 6 + -0.0015003593 * ((44 - 0) ** 4) / 24 + 0.0000301794 * ((44 - 0) ** 5) / 120
# Bag Production at x=44: 3859.764234559607
#
#
# Evaluating Maclaurin Series around a = 0 for x = 45
# Term 0: 1868.5382788214 * ((45 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((45 - 0) ** 1) / 1 = 1598.4075496725525
# Term 2: -0.0029148581 * ((45 - 0) ** 2) / 2 = -2.951293781828121
# Term 3: 0.0439516805 * ((45 - 0) ** 3) / 6 = 667.5161473223478
# Term 4: -0.0015003593 * ((45 - 0) ** 4) / 24 = -256.350458960434
# Term 5: 0.0000301794 * ((45 - 0) ** 5) / 120 = 46.407912598490874
# Maclaurin Series: 1868.5382788214 * ((45 - 0) ** 0) / 1 + 35.5201677705 * ((45 - 0) ** 1) / 1 + -0.0029148581 * ((45 - 0) ** 2) / 2 + 0.0439516805 * ((45 - 0) ** 3) / 6 + -0.0015003593 * ((45 - 0) ** 4) / 24 + 0.0000301794 * ((45 - 0) ** 5) / 120
# Bag Production at x=45: 3921.568135672504
#
#
# Evaluating Maclaurin Series around a = 0 for x = 46
# Term 0: 1868.5382788214 * ((46 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((46 - 0) ** 1) / 1 = 1633.9277174430538
# Term 2: -0.0029148581 * ((46 - 0) ** 2) / 2 = -3.0839198233818785
# Term 3: 0.0439516805 * ((46 - 0) ** 3) / 6 = 713.0134619014326
# Term 4: -0.0015003593 * ((46 - 0) ** 4) / 24 = -279.90803854903805
# Term 5: 0.0000301794 * ((46 - 0) ** 5) / 120 = 51.79867182161568
# Maclaurin Series: 1868.5382788214 * ((46 - 0) ** 0) / 1 + 35.5201677705 * ((46 - 0) ** 1) / 1 + -0.0029148581 * ((46 - 0) ** 2) / 2 + 0.0439516805 * ((46 - 0) ** 3) / 6 + -0.0015003593 * ((46 - 0) ** 4) / 24 + 0.0000301794 * ((46 - 0) ** 5) / 120
# Bag Production at x=46: 3984.286171615057
#
#
# Evaluating Maclaurin Series around a = 0 for x = 47
# Term 0: 1868.5382788214 * ((47 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((47 - 0) ** 1) / 1 = 1669.4478852135549
# Term 2: -0.0029148581 * ((47 - 0) ** 2) / 2 = -3.2194607229917627
# Term 3: 0.0439516805 * ((47 - 0) ** 3) / 6 = 760.5325537826953
# Term 4: -0.0015003593 * ((47 - 0) ** 4) / 24 = -305.05312334839437
# Term 5: 0.0000301794 * ((47 - 0) ** 5) / 120 = 57.67913720337363
# Maclaurin Series: 1868.5382788214 * ((47 - 0) ** 0) / 1 + 35.5201677705 * ((47 - 0) ** 1) / 1 + -0.0029148581 * ((47 - 0) ** 2) / 2 + 0.0439516805 * ((47 - 0) ** 3) / 6 + -0.0015003593 * ((47 - 0) ** 4) / 24 + 0.0000301794 * ((47 - 0) ** 5) / 120
# Bag Production at x=47: 4047.9252709496127
#
#
# Evaluating Maclaurin Series around a = 0 for x = 48
# Term 0: 1868.5382788214 * ((48 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((48 - 0) ** 1) / 1 = 1704.9680529840562
# Term 2: -0.0029148581 * ((48 - 0) ** 2) / 2 = -3.3579164806577735
# Term 3: 0.0439516805 * ((48 - 0) ** 3) / 6 = 810.1173746466183
# Term 4: -0.0015003593 * ((48 - 0) ** 4) / 24 = -331.85548006777293
# Term 5: 0.0000301794 * ((48 - 0) ** 5) / 120 = 64.08194022831299
# Maclaurin Series: 1868.5382788214 * ((48 - 0) ** 0) / 1 + 35.5201677705 * ((48 - 0) ** 1) / 1 + -0.0029148581 * ((48 - 0) ** 2) / 2 + 0.0439516805 * ((48 - 0) ** 3) / 6 + -0.0015003593 * ((48 - 0) ** 4) / 24 + 0.0000301794 * ((48 - 0) ** 5) / 120
# Bag Production at x=48: 4112.4922501319315
#
#
# Evaluating Maclaurin Series around a = 0 for x = 49
# Term 0: 1868.5382788214 * ((49 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((49 - 0) ** 1) / 1 = 1740.4882207545572
# Term 2: -0.0029148581 * ((49 - 0) ** 2) / 2 = -3.4992870963799105
# Term 3: 0.0439516805 * ((49 - 0) ** 3) / 6 = 861.8118761736833
# Term 4: -0.0015003593 * ((49 - 0) ** 4) / 24 = -360.3863757757827
# Term 5: 0.0000301794 * ((49 - 0) ** 5) / 120 = 71.0411308131427
# Maclaurin Series: 1868.5382788214 * ((49 - 0) ** 0) / 1 + 35.5201677705 * ((49 - 0) ** 1) / 1 + -0.0029148581 * ((49 - 0) ** 2) / 2 + 0.0439516805 * ((49 - 0) ** 3) / 6 + -0.0015003593 * ((49 - 0) ** 4) / 24 + 0.0000301794 * ((49 - 0) ** 5) / 120
# Bag Production at x=49: 4177.993843690596
#
#
# Evaluating Maclaurin Series around a = 0 for x = 50
# Term 0: 1868.5382788214 * ((50 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((50 - 0) ** 1) / 1 = 1776.0083885250583
# Term 2: -0.0029148581 * ((50 - 0) ** 2) / 2 = -3.6435725701581743
# Term 3: 0.0439516805 * ((50 - 0) ** 3) / 6 = 915.6600100443729
# Term 4: -0.0015003593 * ((50 - 0) ** 4) / 24 = -390.7185779003719
# Term 5: 0.0000301794 * ((50 - 0) ** 5) / 120 = 78.59220748614011
# Maclaurin Series: 1868.5382788214 * ((50 - 0) ** 0) / 1 + 35.5201677705 * ((50 - 0) ** 1) / 1 + -0.0029148581 * ((50 - 0) ** 2) / 2 + 0.0439516805 * ((50 - 0) ** 3) / 6 + -0.0015003593 * ((50 - 0) ** 4) / 24 + 0.0000301794 * ((50 - 0) ** 5) / 120
# Bag Production at x=50: 4244.436734406417
#
#
# Evaluating Maclaurin Series around a = 0 for x = 51
# Term 0: 1868.5382788214 * ((51 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((51 - 0) ** 1) / 1 = 1811.5285562955596
# Term 2: -0.0029148581 * ((51 - 0) ** 2) / 2 = -3.7907729019925647
# Term 3: 0.0439516805 * ((51 - 0) ** 3) / 6 = 971.7057279391688
# Term 4: -0.0015003593 * ((51 - 0) ** 4) / 24 = -422.92635422882785
# Term 5: 0.0000301794 * ((51 - 0) ** 5) / 120 = 86.77214756655864
# Maclaurin Series: 1868.5382788214 * ((51 - 0) ** 0) / 1 + 35.5201677705 * ((51 - 0) ** 1) / 1 + -0.0029148581 * ((51 - 0) ** 2) / 2 + 0.0439516805 * ((51 - 0) ** 3) / 6 + -0.0015003593 * ((51 - 0) ** 4) / 24 + 0.0000301794 * ((51 - 0) ** 5) / 120
# Bag Production at x=51: 4311.82758349184
#
#
# Evaluating Maclaurin Series around a = 0 for x = 52
# Term 0: 1868.5382788214 * ((52 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((52 - 0) ** 1) / 1 = 1847.0487240660607
# Term 2: -0.0029148581 * ((52 - 0) ** 2) / 2 = -3.9408880918830813
# Term 3: 0.0439516805 * ((52 - 0) ** 3) / 6 = 1029.9929815385535
# Term 4: -0.0015003593 * ((52 - 0) ** 4) / 24 = -457.0854729077769
# Term 5: 0.0000301794 * ((52 - 0) ** 5) / 120 = 95.61943734403538
# Maclaurin Series: 1868.5382788214 * ((52 - 0) ** 0) / 1 + 35.5201677705 * ((52 - 0) ** 1) / 1 + -0.0029148581 * ((52 - 0) ** 2) / 2 + 0.0439516805 * ((52 - 0) ** 3) / 6 + -0.0015003593 * ((52 - 0) ** 4) / 24 + 0.0000301794 * ((52 - 0) ** 5) / 120
# Bag Production at x=52: 4380.173060770365
#
#
# Evaluating Maclaurin Series around a = 0 for x = 53
# Term 0: 1868.5382788214 * ((53 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((53 - 0) ** 1) / 1 = 1882.568891836562
# Term 2: -0.0029148581 * ((53 - 0) ** 2) / 2 = -4.093918139829724
# Term 3: 0.0439516805 * ((53 - 0) ** 3) / 6 = 1090.5657225230088
# Term 4: -0.0015003593 * ((53 - 0) ** 4) / 24 = -493.27320244318474
# Term 5: 0.0000301794 * ((53 - 0) ** 5) / 120 = 105.1741022579989
# Maclaurin Series: 1868.5382788214 * ((53 - 0) ** 0) / 1 + 35.5201677705 * ((53 - 0) ** 1) / 1 + -0.0029148581 * ((53 - 0) ** 2) / 2 + 0.0439516805 * ((53 - 0) ** 3) / 6 + -0.0015003593 * ((53 - 0) ** 4) / 24 + 0.0000301794 * ((53 - 0) ** 5) / 120
# Bag Production at x=53: 4449.479874855931
#
#
# Evaluating Maclaurin Series around a = 0 for x = 54
# Term 0: 1868.5382788214 * ((54 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((54 - 0) ** 1) / 1 = 1918.089059607063
# Term 2: -0.0029148581 * ((54 - 0) ** 2) / 2 = -4.249863045832495
# Term 3: 0.0439516805 * ((54 - 0) ** 3) / 6 = 1153.467902573017
# Term 4: -0.0015003593 * ((54 - 0) ** 4) / 24 = -531.5683117003559
# Term 5: 0.0000301794 * ((54 - 0) ** 5) / 120 = 115.47773707707682
# Maclaurin Series: 1868.5382788214 * ((54 - 0) ** 0) / 1 + 35.5201677705 * ((54 - 0) ** 1) / 1 + -0.0029148581 * ((54 - 0) ** 2) / 2 + 0.0439516805 * ((54 - 0) ** 3) / 6 + -0.0015003593 * ((54 - 0) ** 4) / 24 + 0.0000301794 * ((54 - 0) ** 5) / 120
# Bag Production at x=54: 4519.754803332344
#
#
# Evaluating Maclaurin Series around a = 0 for x = 55
# Term 0: 1868.5382788214 * ((55 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((55 - 0) ** 1) / 1 = 1953.6092273775641
# Term 2: -0.0029148581 * ((55 - 0) ** 2) / 2 = -4.40872280989139
# Term 3: 0.0439516805 * ((55 - 0) ** 3) / 6 = 1218.7434733690604
# Term 4: -0.0015003593 * ((55 - 0) ** 4) / 24 = -572.0510699039345
# Term 5: 0.0000301794 * ((55 - 0) ** 5) / 120 = 126.57353607850352
# Maclaurin Series: 1868.5382788214 * ((55 - 0) ** 0) / 1 + 35.5201677705 * ((55 - 0) ** 1) / 1 + -0.0029148581 * ((55 - 0) ** 2) / 2 + 0.0439516805 * ((55 - 0) ** 3) / 6 + -0.0015003593 * ((55 - 0) ** 4) / 24 + 0.0000301794 * ((55 - 0) ** 5) / 120
# Bag Production at x=55: 4591.004722932677
#
#
# Evaluating Maclaurin Series around a = 0 for x = 56
# Term 0: 1868.5382788214 * ((56 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((56 - 0) ** 1) / 1 = 1989.1293951480654
# Term 2: -0.0029148581 * ((56 - 0) ** 2) / 2 = -4.570497432006413
# Term 3: 0.0439516805 * ((56 - 0) ** 3) / 6 = 1286.4363865916207
# Term 4: -0.0015003593 * ((56 - 0) ** 4) / 24 = -614.8032466379034
# Term 5: 0.0000301794 * ((56 - 0) ** 5) / 120 = 138.50632322752782
# Maclaurin Series: 1868.5382788214 * ((56 - 0) ** 0) / 1 + 35.5201677705 * ((56 - 0) ** 1) / 1 + -0.0029148581 * ((56 - 0) ** 2) / 2 + 0.0439516805 * ((56 - 0) ** 3) / 6 + -0.0015003593 * ((56 - 0) ** 4) / 24 + 0.0000301794 * ((56 - 0) ** 5) / 120
# Bag Production at x=56: 4663.236639718679
#
#
# Evaluating Maclaurin Series around a = 0 for x = 57
# Term 0: 1868.5382788214 * ((57 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((57 - 0) ** 1) / 1 = 2024.6495629185665
# Term 2: -0.0029148581 * ((57 - 0) ** 2) / 2 = -4.735186912177563
# Term 3: 0.0439516805 * ((57 - 0) ** 3) / 6 = 1356.5905939211805
# Term 4: -0.0015003593 * ((57 - 0) ** 4) / 24 = -659.9081118455846
# Term 5: 0.0000301794 * ((57 - 0) ** 5) / 120 = 151.32258235682062
# Maclaurin Series: 1868.5382788214 * ((57 - 0) ** 0) / 1 + 35.5201677705 * ((57 - 0) ** 1) / 1 + -0.0029148581 * ((57 - 0) ** 2) / 2 + 0.0439516805 * ((57 - 0) ** 3) / 6 + -0.0015003593 * ((57 - 0) ** 4) / 24 + 0.0000301794 * ((57 - 0) ** 5) / 120
# Bag Production at x=57: 4736.457719260181
#
#
# Evaluating Maclaurin Series around a = 0 for x = 58
# Term 0: 1868.5382788214 * ((58 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((58 - 0) ** 1) / 1 = 2060.169730689068
# Term 2: -0.0029148581 * ((58 - 0) ** 2) / 2 = -4.90279125040484
# Term 3: 0.0439516805 * ((58 - 0) ** 3) / 6 = 1429.2500470382213
# Term 4: -0.0015003593 * ((58 - 0) ** 4) / 24 = -707.4504358296396
# Term 5: 0.0000301794 * ((58 - 0) ** 5) / 120 = 165.07048734588267
# Maclaurin Series: 1868.5382788214 * ((58 - 0) ** 0) / 1 + 35.5201677705 * ((58 - 0) ** 1) / 1 + -0.0029148581 * ((58 - 0) ** 2) / 2 + 0.0439516805 * ((58 - 0) ** 3) / 6 + -0.0015003593 * ((58 - 0) ** 4) / 24 + 0.0000301794 * ((58 - 0) ** 5) / 120
# Bag Production at x=58: 4810.675316814502
#
#
# Evaluating Maclaurin Series around a = 0 for x = 59
# Term 0: 1868.5382788214 * ((59 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((59 - 0) ** 1) / 1 = 2095.6898984595687
# Term 2: -0.0029148581 * ((59 - 0) ** 2) / 2 = -5.073310446688242
# Term 3: 0.0439516805 * ((59 - 0) ** 3) / 6 = 1504.458697623226
# Term 4: -0.0015003593 * ((59 - 0) ** 4) / 24 = -757.5164892520685
# Term 5: 0.0000301794 * ((59 - 0) ** 5) / 120 = 179.79993230045207
# Maclaurin Series: 1868.5382788214 * ((59 - 0) ** 0) / 1 + 35.5201677705 * ((59 - 0) ** 1) / 1 + -0.0029148581 * ((59 - 0) ** 2) / 2 + 0.0439516805 * ((59 - 0) ** 3) / 6 + -0.0015003593 * ((59 - 0) ** 4) / 24 + 0.0000301794 * ((59 - 0) ** 5) / 120
# Bag Production at x=59: 4885.897007505865
#
#
# Evaluating Maclaurin Series around a = 0 for x = 60
# Term 0: 1868.5382788214 * ((60 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((60 - 0) ** 1) / 1 = 2131.21006623007
# Term 2: -0.0029148581 * ((60 - 0) ** 2) / 2 = -5.246744501027771
# Term 3: 0.0439516805 * ((60 - 0) ** 3) / 6 = 1582.2604973566765
# Term 4: -0.0015003593 * ((60 - 0) ** 4) / 24 = -810.1940431342113
# Term 5: 0.0000301794 * ((60 - 0) ** 5) / 120 = 195.56256173191215
# Maclaurin Series: 1868.5382788214 * ((60 - 0) ** 0) / 1 + 35.5201677705 * ((60 - 0) ** 1) / 1 + -0.0029148581 * ((60 - 0) ** 2) / 2 + 0.0439516805 * ((60 - 0) ** 3) / 6 + -0.0015003593 * ((60 - 0) ** 4) / 24 + 0.0000301794 * ((60 - 0) ** 5) / 120
# Bag Production at x=60: 4962.1306165047945
#
#
# Evaluating Maclaurin Series around a = 0 for x = 61
# Term 0: 1868.5382788214 * ((61 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((61 - 0) ** 1) / 1 = 2166.7302340005713
# Term 2: -0.0029148581 * ((61 - 0) ** 2) / 2 = -5.423093413423427
# Term 3: 0.0439516805 * ((61 - 0) ** 3) / 6 = 1662.6993979190545
# Term 4: -0.0015003593 * ((61 - 0) ** 4) / 24 = -865.572368856746
# Term 5: 0.0000301794 * ((61 - 0) ** 5) / 120 = 212.41180073669906
# Maclaurin Series: 1868.5382788214 * ((61 - 0) ** 0) / 1 + 35.5201677705 * ((61 - 0) ** 1) / 1 + -0.0029148581 * ((61 - 0) ** 2) / 2 + 0.0439516805 * ((61 - 0) ** 3) / 6 + -0.0015003593 * ((61 - 0) ** 4) / 24 + 0.0000301794 * ((61 - 0) ** 5) / 120
# Bag Production at x=61: 5039.38424920753
#
#
# Evaluating Maclaurin Series around a = 0 for x = 62
# Term 0: 1868.5382788214 * ((62 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((62 - 0) ** 1) / 1 = 2202.2504017710726
# Term 2: -0.0029148581 * ((62 - 0) ** 2) / 2 = -5.602357183875209
# Term 3: 0.0439516805 * ((62 - 0) ** 3) / 6 = 1745.8193509908424
# Term 4: -0.0015003593 * ((62 - 0) ** 4) / 24 = -923.7422381596912
# Term 5: 0.0000301794 * ((62 - 0) ** 5) / 120 = 230.4028851757093
# Maclaurin Series: 1868.5382788214 * ((62 - 0) ** 0) / 1 + 35.5201677705 * ((62 - 0) ** 1) / 1 + -0.0029148581 * ((62 - 0) ** 2) / 2 + 0.0439516805 * ((62 - 0) ** 3) / 6 + -0.0015003593 * ((62 - 0) ** 4) / 24 + 0.0000301794 * ((62 - 0) ** 5) / 120
# Bag Production at x=62: 5117.666321415433
#
#
# Evaluating Maclaurin Series around a = 0 for x = 63
# Term 0: 1868.5382788214 * ((63 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((63 - 0) ** 1) / 1 = 2237.7705695415734
# Term 2: -0.0029148581 * ((63 - 0) ** 2) / 2 = -5.784535812383117
# Term 3: 0.0439516805 * ((63 - 0) ** 3) / 6 = 1831.6643082525225
# Term 4: -0.0015003593 * ((63 - 0) ** 4) / 24 = -984.7959231424034
# Term 5: 0.0000301794 * ((63 - 0) ** 5) / 120 = 249.59289185370758
# Maclaurin Series: 1868.5382788214 * ((63 - 0) ** 0) / 1 + 35.5201677705 * ((63 - 0) ** 1) / 1 + -0.0029148581 * ((63 - 0) ** 2) / 2 + 0.0439516805 * ((63 - 0) ** 3) / 6 + -0.0015003593 * ((63 - 0) ** 4) / 24 + 0.0000301794 * ((63 - 0) ** 5) / 120
# Bag Production at x=63: 5196.985589514391
#
#
# Evaluating Maclaurin Series around a = 0 for x = 64
# Term 0: 1868.5382788214 * ((64 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((64 - 0) ** 1) / 1 = 2273.2907373120747
# Term 2: -0.0029148581 * ((64 - 0) ** 2) / 2 = -5.969629298947153
# Term 3: 0.0439516805 * ((64 - 0) ** 3) / 6 = 1920.2782213845767
# Term 4: -0.0015003593 * ((64 - 0) ** 4) / 24 = -1048.8271962635786
# Term 5: 0.0000301794 * ((64 - 0) ** 5) / 120 = 270.04076869873455
# Maclaurin Series: 1868.5382788214 * ((64 - 0) ** 0) / 1 + 35.5201677705 * ((64 - 0) ** 1) / 1 + -0.0029148581 * ((64 - 0) ** 2) / 2 + 0.0439516805 * ((64 - 0) ** 3) / 6 + -0.0015003593 * ((64 - 0) ** 4) / 24 + 0.0000301794 * ((64 - 0) ** 5) / 120
# Bag Production at x=64: 5277.351180654236
#
#
# Evaluating Maclaurin Series around a = 0 for x = 65
# Term 0: 1868.5382788214 * ((65 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((65 - 0) ** 1) / 1 = 2308.810905082576
# Term 2: -0.0029148581 * ((65 - 0) ** 2) / 2 = -6.157637643567314
# Term 3: 0.0439516805 * ((65 - 0) ** 3) / 6 = 2011.705042067487
# Term 4: -0.0015003593 * ((65 - 0) ** 4) / 24 = -1115.931330341252
# Term 5: 0.0000301794 * ((65 - 0) ** 5) / 120 = 291.80736494151427
# Maclaurin Series: 1868.5382788214 * ((65 - 0) ** 0) / 1 + 35.5201677705 * ((65 - 0) ** 1) / 1 + -0.0029148581 * ((65 - 0) ** 2) / 2 + 0.0439516805 * ((65 - 0) ** 3) / 6 + -0.0015003593 * ((65 - 0) ** 4) / 24 + 0.0000301794 * ((65 - 0) ** 5) / 120
# Bag Production at x=65: 5358.772622928133
#
#
# Evaluating Maclaurin Series around a = 0 for x = 66
# Term 0: 1868.5382788214 * ((66 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((66 - 0) ** 1) / 1 = 2344.331072853077
# Term 2: -0.0029148581 * ((66 - 0) ** 2) / 2 = -6.348560846243603
# ...
# Bag Production at x=124: 12810.200976622398
#
#
# Evaluating Maclaurin Series around a = 0 for x = 125
# Term 0: 1868.5382788214 * ((125 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((125 - 0) ** 1) / 1 = 4440.020971312646
# Term 2: -0.0029148581 * ((125 - 0) ** 2) / 2 = -22.77232856348859
# Term 3: 0.0439516805 * ((125 - 0) ** 3) / 6 = 14307.187656943328
# Term 4: -0.0015003593 * ((125 - 0) ** 4) / 24 = -15262.444449233277
# Term 5: 0.0000301794 * ((125 - 0) ** 5) / 120 = 7675.020262318371
# Maclaurin Series: 1868.5382788214 * ((125 - 0) ** 0) / 1 + 35.5201677705 * ((125 - 0) ** 1) / 1 + -0.0029148581 * ((125 - 0) ** 2) / 2 + 0.0439516805 * ((125 - 0) ** 3) / 6 + -0.0015003593 * ((125 - 0) ** 4) / 24 + 0.0000301794 * ((125 - 0) ** 5) / 120
# Bag Production at x=125: 13005.550391598954
#
#
# Evaluating Maclaurin Series around a = 0 for x = 126
# Term 0: 1868.5382788214 * ((126 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((126 - 0) ** 1) / 1 = 4475.541139083147
# Term 2: -0.0029148581 * ((126 - 0) ** 2) / 2 = -23.13814324953247
# Term 3: 0.0439516805 * ((126 - 0) ** 3) / 6 = 14653.31446602018
# Term 4: -0.0015003593 * ((126 - 0) ** 4) / 24 = -15756.734770278454
# Term 5: 0.0000301794 * ((126 - 0) ** 5) / 120 = 7986.972539318643
# Maclaurin Series: 1868.5382788214 * ((126 - 0) ** 0) / 1 + 35.5201677705 * ((126 - 0) ** 1) / 1 + -0.0029148581 * ((126 - 0) ** 2) / 2 + 0.0439516805 * ((126 - 0) ** 3) / 6 + -0.0015003593 * ((126 - 0) ** 4) / 24 + 0.0000301794 * ((126 - 0) ** 5) / 120
# Bag Production at x=126: 13204.493509715358
#
#
# Evaluating Maclaurin Series around a = 0 for x = 127
# Term 0: 1868.5382788214 * ((127 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((127 - 0) ** 1) / 1 = 4511.061306853649
# Term 2: -0.0029148581 * ((127 - 0) ** 2) / 2 = -23.50687279363248
# Term 3: 0.0439516805 * ((127 - 0) ** 3) / 6 = 15004.979186837782
# Term 4: -0.0015003593 * ((127 - 0) ** 4) / 24 = -16262.935068787645
# Term 5: 0.0000301794 * ((127 - 0) ** 5) / 120 = 8308.986827003802
# Maclaurin Series: 1868.5382788214 * ((127 - 0) ** 0) / 1 + 35.5201677705 * ((127 - 0) ** 1) / 1 + -0.0029148581 * ((127 - 0) ** 2) / 2 + 0.0439516805 * ((127 - 0) ** 3) / 6 + -0.0015003593 * ((127 - 0) ** 4) / 24 + 0.0000301794 * ((127 - 0) ** 5) / 120
# Bag Production at x=127: 13407.12365793533
#
#
# Evaluating Maclaurin Series around a = 0 for x = 128
# Term 0: 1868.5382788214 * ((128 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((128 - 0) ** 1) / 1 = 4546.581474624149
# Term 2: -0.0029148581 * ((128 - 0) ** 2) / 2 = -23.87851719578861
# Term 3: 0.0439516805 * ((128 - 0) ** 3) / 6 = 15362.225771076613
# Term 4: -0.0015003593 * ((128 - 0) ** 4) / 24 = -16781.235140217257
# Term 5: 0.0000301794 * ((128 - 0) ** 5) / 120 = 8641.304598359506
# Maclaurin Series: 1868.5382788214 * ((128 - 0) ** 0) / 1 + 35.5201677705 * ((128 - 0) ** 1) / 1 + -0.0029148581 * ((128 - 0) ** 2) / 2 + 0.0439516805 * ((128 - 0) ** 3) / 6 + -0.0015003593 * ((128 - 0) ** 4) / 24 + 0.0000301794 * ((128 - 0) ** 5) / 120
# Bag Production at x=128: 13613.536465468596
#
#
# Evaluating Maclaurin Series around a = 0 for x = 129
# Term 0: 1868.5382788214 * ((129 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((129 - 0) ** 1) / 1 = 4582.10164239465
# Term 2: -0.0029148581 * ((129 - 0) ** 2) / 2 = -24.253076456000873
# Term 3: 0.0439516805 * ((129 - 0) ** 3) / 6 = 15725.098170417157
# Term 4: -0.0015003593 * ((129 - 0) ** 4) / 24 = -17311.826280383026
# Term 5: 0.0000301794 * ((129 - 0) ** 5) / 120 = 8984.171159156185
# Maclaurin Series: 1868.5382788214 * ((129 - 0) ** 0) / 1 + 35.5201677705 * ((129 - 0) ** 1) / 1 + -0.0029148581 * ((129 - 0) ** 2) / 2 + 0.0439516805 * ((129 - 0) ** 3) / 6 + -0.0015003593 * ((129 - 0) ** 4) / 24 + 0.0000301794 * ((129 - 0) ** 5) / 120
# Bag Production at x=129: 13823.829893950342
#
#
# Evaluating Maclaurin Series around a = 0 for x = 130
# Term 0: 1868.5382788214 * ((130 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((130 - 0) ** 1) / 1 = 4617.621810165152
# Term 2: -0.0029148581 * ((130 - 0) ** 2) / 2 = -24.630550574269257
# Term 3: 0.0439516805 * ((130 - 0) ** 3) / 6 = 16093.640336539896
# Term 4: -0.0015003593 * ((130 - 0) ** 4) / 24 = -17854.901285460033
# Term 5: 0.0000301794 * ((130 - 0) ** 5) / 120 = 9337.835678128456
# Maclaurin Series: 1868.5382788214 * ((130 - 0) ** 0) / 1 + 35.5201677705 * ((130 - 0) ** 1) / 1 + -0.0029148581 * ((130 - 0) ** 2) / 2 + 0.0439516805 * ((130 - 0) ** 3) / 6 + -0.0015003593 * ((130 - 0) ** 4) / 24 + 0.0000301794 * ((130 - 0) ** 5) / 120
# Bag Production at x=130: 14038.104267620576
#
#
# Evaluating Maclaurin Series around a = 0 for x = 131
# Term 0: 1868.5382788214 * ((131 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((131 - 0) ** 1) / 1 = 4653.141977935653
# Term 2: -0.0029148581 * ((131 - 0) ** 2) / 2 = -25.010939550593772
# Term 3: 0.0439516805 * ((131 - 0) ** 3) / 6 = 16467.896221125313
# Term 4: -0.0015003593 * ((131 - 0) ** 4) / 24 = -18410.6544519827
# Term 5: 0.0000301794 * ((131 - 0) ** 5) / 120 = 9702.55121715452
# Maclaurin Series: 1868.5382788214 * ((131 - 0) ** 0) / 1 + 35.5201677705 * ((131 - 0) ** 1) / 1 + -0.0029148581 * ((131 - 0) ** 2) / 2 + 0.0439516805 * ((131 - 0) ** 3) / 6 + -0.0015003593 * ((131 - 0) ** 4) / 24 + 0.0000301794 * ((131 - 0) ** 5) / 120
# Bag Production at x=131: 14256.462303503566
#
#
# Evaluating Maclaurin Series around a = 0 for x = 132
# Term 0: 1868.5382788214 * ((132 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((132 - 0) ** 1) / 1 = 4688.662145706154
# Term 2: -0.0029148581 * ((132 - 0) ** 2) / 2 = -25.394243384974413
# Term 3: 0.0439516805 * ((132 - 0) ** 3) / 6 = 16847.90977585389
# Term 4: -0.0015003593 * ((132 - 0) ** 4) / 24 = -18979.28157684478
# Term 5: 0.0000301794 * ((132 - 0) ** 5) / 120 = 10078.57476143558
# Maclaurin Series: 1868.5382788214 * ((132 - 0) ** 0) / 1 + 35.5201677705 * ((132 - 0) ** 1) / 1 + -0.0029148581 * ((132 - 0) ** 2) / 2 + 0.0439516805 * ((132 - 0) ** 3) / 6 + -0.0015003593 * ((132 - 0) ** 4) / 24 + 0.0000301794 * ((132 - 0) ** 5) / 120
# Bag Production at x=132: 14479.009141587243
#
#
# Evaluating Maclaurin Series around a = 0 for x = 133
# Term 0: 1868.5382788214 * ((133 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((133 - 0) ** 1) / 1 = 4724.1823134766555
# Term 2: -0.0029148581 * ((133 - 0) ** 2) / 2 = -25.780462077411176
# Term 3: 0.0439516805 * ((133 - 0) ** 3) / 6 = 17233.724952406108
# Term 4: -0.0015003593 * ((133 - 0) ** 4) / 24 = -19560.979957299365
# Term 5: 0.0000301794 * ((133 - 0) ** 5) / 120 = 10466.167249675245
# Maclaurin Series: 1868.5382788214 * ((133 - 0) ** 0) / 1 + 35.5201677705 * ((133 - 0) ** 1) / 1 + -0.0029148581 * ((133 - 0) ** 2) / 2 + 0.0439516805 * ((133 - 0) ** 3) / 6 + -0.0015003593 * ((133 - 0) ** 4) / 24 + 0.0000301794 * ((133 - 0) ** 5) / 120
# Bag Production at x=133: 14705.852375002609
#
#
# Evaluating Maclaurin Series around a = 0 for x = 134
# Term 0: 1868.5382788214 * ((134 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((134 - 0) ** 1) / 1 = 4759.702481247156
# Term 2: -0.0029148581 * ((134 - 0) ** 2) / 2 = -26.16959562790407
# Term 3: 0.0439516805 * ((134 - 0) ** 3) / 6 = 17625.38570246245
# Term 4: -0.0015003593 * ((134 - 0) ** 4) / 24 = -20155.9483909589
# Term 5: 0.0000301794 * ((134 - 0) ** 5) / 120 = 10865.593604258931
# Maclaurin Series: 1868.5382788214 * ((134 - 0) ** 0) / 1 + 35.5201677705 * ((134 - 0) ** 1) / 1 + -0.0029148581 * ((134 - 0) ** 2) / 2 + 0.0439516805 * ((134 - 0) ** 3) / 6 + -0.0015003593 * ((134 - 0) ** 4) / 24 + 0.0000301794 * ((134 - 0) ** 5) / 120
# Bag Production at x=134: 14937.102080203109
#
#
# Evaluating Maclaurin Series around a = 0 for x = 135
# Term 0: 1868.5382788214 * ((135 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((135 - 0) ** 1) / 1 = 4795.222649017657
# Term 2: -0.0029148581 * ((135 - 0) ** 2) / 2 = -26.56164403645309
# Term 3: 0.0439516805 * ((135 - 0) ** 3) / 6 = 18022.935977703393
# Term 4: -0.0015003593 * ((135 - 0) ** 4) / 24 = -20764.387175795153
# Term 5: 0.0000301794 * ((135 - 0) ** 5) / 120 = 11277.122761433284
# Maclaurin Series: 1868.5382788214 * ((135 - 0) ** 0) / 1 + 35.5201677705 * ((135 - 0) ** 1) / 1 + -0.0029148581 * ((135 - 0) ** 2) / 2 + 0.0439516805 * ((135 - 0) ** 3) / 6 + -0.0015003593 * ((135 - 0) ** 4) / 24 + 0.0000301794 * ((135 - 0) ** 5) / 120
# Bag Production at x=135: 15172.870847144104
#
#
# Evaluating Maclaurin Series around a = 0 for x = 136
# Term 0: 1868.5382788214 * ((136 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((136 - 0) ** 1) / 1 = 4830.742816788159
# Term 2: -0.0029148581 * ((136 - 0) ** 2) / 2 = -26.956607303058234
# Term 3: 0.0439516805 * ((136 - 0) ** 3) / 6 = 18426.419729809426
# Term 4: -0.0015003593 * ((136 - 0) ** 4) / 24 = -21386.498110139244
# Term 5: 0.0000301794 * ((136 - 0) ** 5) / 120 = 11701.027701485571
# Maclaurin Series: 1868.5382788214 * ((136 - 0) ** 0) / 1 + 35.5201677705 * ((136 - 0) ** 1) / 1 + -0.0029148581 * ((136 - 0) ** 2) / 2 + 0.0439516805 * ((136 - 0) ** 3) / 6 + -0.0015003593 * ((136 - 0) ** 4) / 24 + 0.0000301794 * ((136 - 0) ** 5) / 120
# Bag Production at x=136: 15413.27380946223
#
#
# Evaluating Maclaurin Series around a = 0 for x = 137
# Term 0: 1868.5382788214 * ((137 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((137 - 0) ** 1) / 1 = 4866.26298455866
# Term 2: -0.0029148581 * ((137 - 0) ** 2) / 2 = -27.35448542771951
# Term 3: 0.0439516805 * ((137 - 0) ** 3) / 6 = 18835.880910461026
# Term 4: -0.0015003593 * ((137 - 0) ** 4) / 24 = -22022.48449268162
# Term 5: 0.0000301794 * ((137 - 0) ** 5) / 120 = 12137.585478923096
# Maclaurin Series: 1868.5382788214 * ((137 - 0) ** 0) / 1 + 35.5201677705 * ((137 - 0) ** 1) / 1 + -0.0029148581 * ((137 - 0) ** 2) / 2 + 0.0439516805 * ((137 - 0) ** 3) / 6 + -0.0015003593 * ((137 - 0) ** 4) / 24 + 0.0000301794 * ((137 - 0) ** 5) / 120
# Bag Production at x=137: 15658.428674654819
#
#
# Evaluating Maclaurin Series around a = 0 for x = 138
# Term 0: 1868.5382788214 * ((138 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((138 - 0) ** 1) / 1 = 4901.783152329162
# Term 2: -0.0029148581 * ((138 - 0) ** 2) / 2 = -27.755278410436908
# Term 3: 0.0439516805 * ((138 - 0) ** 3) / 6 = 19251.363471338682
# Term 4: -0.0015003593 * ((138 - 0) ** 4) / 24 = -22672.55112247208
# Term 5: 0.0000301794 * ((138 - 0) ** 5) / 120 = 12587.077252652609
# Maclaurin Series: 1868.5382788214 * ((138 - 0) ** 0) / 1 + 35.5201677705 * ((138 - 0) ** 1) / 1 + -0.0029148581 * ((138 - 0) ** 2) / 2 + 0.0439516805 * ((138 - 0) ** 3) / 6 + -0.0015003593 * ((138 - 0) ** 4) / 24 + 0.0000301794 * ((138 - 0) ** 5) / 120
# Bag Production at x=138: 15908.45575425931
#
#
# Evaluating Maclaurin Series around a = 0 for x = 139
# Term 0: 1868.5382788214 * ((139 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((139 - 0) ** 1) / 1 = 4937.303320099662
# Term 2: -0.0029148581 * ((139 - 0) ** 2) / 2 = -28.158986251210433
# Term 3: 0.0439516805 * ((139 - 0) ** 3) / 6 = 19672.91136412287
# Term 4: -0.0015003593 * ((139 - 0) ** 4) / 24 = -23336.904298919748
# Term 5: 0.0000301794 * ((139 - 0) ** 5) / 120 = 13049.788316159711
# Maclaurin Series: 1868.5382788214 * ((139 - 0) ** 0) / 1 + 35.5201677705 * ((139 - 0) ** 1) / 1 + -0.0029148581 * ((139 - 0) ** 2) / 2 + 0.0439516805 * ((139 - 0) ** 3) / 6 + -0.0015003593 * ((139 - 0) ** 4) / 24 + 0.0000301794 * ((139 - 0) ** 5) / 120
# Bag Production at x=139: 16163.47799403266
#
#
# Evaluating Maclaurin Series around a = 0 for x = 140
# Term 0: 1868.5382788214 * ((140 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((140 - 0) ** 1) / 1 = 4972.823487870163
# Term 2: -0.0029148581 * ((140 - 0) ** 2) / 2 = -28.565608950040087
# Term 3: 0.0439516805 * ((140 - 0) ** 3) / 6 = 20100.568540494074
# Term 4: -0.0015003593 * ((140 - 0) ** 4) / 24 = -24015.751821793103
# Term 5: 0.0000301794 * ((140 - 0) ** 5) / 120 = 13526.008127688263
# Maclaurin Series: 1868.5382788214 * ((140 - 0) ** 0) / 1 + 35.5201677705 * ((140 - 0) ** 1) / 1 + -0.0029148581 * ((140 - 0) ** 2) / 2 + 0.0439516805 * ((140 - 0) ** 3) / 6 + -0.0015003593 * ((140 - 0) ** 4) / 24 + 0.0000301794 * ((140 - 0) ** 5) / 120
# Bag Production at x=140: 16423.62100413073
#
#
# Evaluating Maclaurin Series around a = 0 for x = 141
# Term 0: 1868.5382788214 * ((141 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((141 - 0) ** 1) / 1 = 5008.343655640665
# Term 2: -0.0029148581 * ((141 - 0) ** 2) / 2 = -28.975146506925864
# Term 3: 0.0439516805 * ((141 - 0) ** 3) / 6 = 20534.378952132774
# Term 4: -0.0015003593 * ((141 - 0) ** 4) / 24 = -24709.30299121994
# Term 5: 0.0000301794 * ((141 - 0) ** 5) / 120 = 14016.030340419791
# Maclaurin Series: 1868.5382788214 * ((141 - 0) ** 0) / 1 + 35.5201677705 * ((141 - 0) ** 1) / 1 + -0.0029148581 * ((141 - 0) ** 2) / 2 + 0.0439516805 * ((141 - 0) ** 3) / 6 + -0.0015003593 * ((141 - 0) ** 4) / 24 + 0.0000301794 * ((141 - 0) ** 5) / 120
# Bag Production at x=141: 16689.01308928774
#
#
# Evaluating Maclaurin Series around a = 0 for x = 142
# Term 0: 1868.5382788214 * ((142 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((142 - 0) ** 1) / 1 = 5043.863823411166
# Term 2: -0.0029148581 * ((142 - 0) ** 2) / 2 = -29.38759892186777
# Term 3: 0.0439516805 * ((142 - 0) ** 3) / 6 = 20974.38655071946
# Term 4: -0.0015003593 * ((142 - 0) ** 4) / 24 = -25417.768607687427
# Term 5: 0.0000301794 * ((142 - 0) ** 5) / 120 = 14520.152832652895
# Maclaurin Series: 1868.5382788214 * ((142 - 0) ** 0) / 1 + 35.5201677705 * ((142 - 0) ** 1) / 1 + -0.0029148581 * ((142 - 0) ** 2) / 2 + 0.0439516805 * ((142 - 0) ** 3) / 6 + -0.0015003593 * ((142 - 0) ** 4) / 24 + 0.0000301794 * ((142 - 0) ** 5) / 120
# Bag Production at x=142: 16959.7852789956
#
#
# Evaluating Maclaurin Series around a = 0 for x = 143
# Term 0: 1868.5382788214 * ((143 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((143 - 0) ** 1) / 1 = 5079.383991181667
# Term 2: -0.0029148581 * ((143 - 0) ** 2) / 2 = -29.802966194865803
# Term 3: 0.0439516805 * ((143 - 0) ** 3) / 6 = 21420.635287934605
# Term 4: -0.0015003593 * ((143 - 0) ** 4) / 24 = -26141.36097204204
# Term 5: 0.0000301794 * ((143 - 0) ** 5) / 120 = 15038.677737982658
# Maclaurin Series: 1868.5382788214 * ((143 - 0) ** 0) / 1 + 35.5201677705 * ((143 - 0) ** 1) / 1 + -0.0029148581 * ((143 - 0) ** 2) / 2 + 0.0439516805 * ((143 - 0) ** 3) / 6 + -0.0015003593 * ((143 - 0) ** 4) / 24 + 0.0000301794 * ((143 - 0) ** 5) / 120
# Bag Production at x=143: 17236.071357683402
#
#
# Evaluating Maclaurin Series around a = 0 for x = 144
# Term 0: 1868.5382788214 * ((144 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((144 - 0) ** 1) / 1 = 5114.9041589521685
# Term 2: -0.0029148581 * ((144 - 0) ** 2) / 2 = -30.22124832591996
# Term 3: 0.0439516805 * ((144 - 0) ** 3) / 6 = 21873.16911545869
# Term 4: -0.0015003593 * ((144 - 0) ** 4) / 24 = -26880.293885489606
# Term 5: 0.0000301794 * ((144 - 0) ** 5) / 120 = 15571.911475480056
# Maclaurin Series: 1868.5382788214 * ((144 - 0) ** 0) / 1 + 35.5201677705 * ((144 - 0) ** 1) / 1 + -0.0029148581 * ((144 - 0) ** 2) / 2 + 0.0439516805 * ((144 - 0) ** 3) / 6 + -0.0015003593 * ((144 - 0) ** 4) / 24 + 0.0000301794 * ((144 - 0) ** 5) / 120
# Bag Production at x=144: 17518.007894896764
# Mean Squared Error (maclaurin Series Approximation): 79412.21257840589
#
#
# Evaluating Maclaurin Series around a = 0 for x = 74
# Term 0: 1868.5382788214 * ((74 - 0) ** 0) / 1 = 1868.538278821375
# Term 1: 35.5201677705 * ((74 - 0) ** 1) / 1 = 2628.4924150170864
# Term 2: -0.0029148581 * ((74 - 0) ** 2) / 2 = -7.980881357674465
# Term 3: 0.0439516805 * ((74 - 0) ** 3) / 6 = 2968.3792952817676
# Term 4: -0.0015003593 * ((74 - 0) ** 4) / 24 = -1874.6099729314276
# Term 5: 0.0000301794 * ((74 - 0) ** 5) / 120 = 558.0692128208874
# Maclaurin Series at x=74: 6140.888347652014
# Terms: 1868.5382788214 * ((74 - 0) ** 0) / 1 + 35.5201677705 * ((74 - 0) ** 1) / 1 + -0.0029148581 * ((74 - 0) ** 2) / 2 + 0.0439516805 * ((74 - 0) ** 3) / 6 + -0.0015003593 * ((74 - 0) ** 4) / 24 + 0.0000301794 * ((74 - 0) ** 5) / 120

# %% [markdown]
# The final answer using Taylor Series or Macluarin Series is actually the same, the difference between that series is just in Macluarin Series we will use (a = 0).

# %% [markdown]
# ### Evaluation
#
# The graph image given in the Taylor Series Section actually already give us evaluation that the expansion of Taylor Series based on the Derivative of Polynomial Equation Model has no different with the Original Polynomial Model.
#
# ### Conclusion
#
# We will using the Taylor Series where the a value is middle point of months which is (a = 144 / 2 = 72).
#
# Taylor Series:
# 5959.1850514140 * ((x - 72) ** 0) / 1 + 89.6919106984 * ((x - 72) ** 1) / 1 + 1.1500753222 * ((x - 72) ** 2) / 2 + 0.0141508328 * ((x - 72) ** 3) / 6 + 0.0006725580 * ((x - 72) ** 4) / 24 + 0.0000301794 * ((x - 72) ** 5) / 120

# %% [markdown]
# # Assurance of Learning (Number 3)

# %% [markdown]
# ### Newton Raphson Function

# %%
# f --> f(x), g --> g(x)
# x0 --> Initial guess
# e -> error
# max_iter --> Maximum iteration

def netwon_raphson (f, g, x0, e = 0.01, max_iter = 15):
    for i in range (1, max_iter):
        x1 = x0 - (f(x0) / g (x0))

        if np.abs (f(x1) < e):
            return x1

        x0 = x1

    return None

# %% [markdown]
# ### Bisection Function

# %%
def bisection (f, a, b, e=0.0001):

    if np.sign(f(a)) == np.sign (f(b)):
        print ("Coordinate Invalid")
        return

    # find the middle value

    c = (a+b)/2

    # Recursive to find the root

    if np.abs(f(c)) < e:
        return c

    elif np.sign (f(a)) == np.sign(f(c)):
        return bisection (f, c, b, e)

    elif np.sign (f(b)) == np.sign (f(c)):
        return bisection (f, a, c, e)

# %% [markdown]
# ### Root of Equation Code (Solution for Number 3)

# %%
# Import Library

import math
import numpy as np
from scipy.optimize import newton, bisect

# Polynomial Model from question number 1

poly_coeffs = np.polyfit(months, data, 5)
poly_model = np.poly1d(poly_coeffs)

# Function to find the root of equation (P(x) - 25000)

def f(x):
    return poly_model(x) - 25000

# First Derivative from Polynomial Model

poly_derivative = np.polyder(poly_model)

# First Derivative of Polynomial Model Function

def f_prime(x):
    return poly_derivative(x)

# Newton-Raphson Method

initial_guess = 130  # Initial guess (month that maybe produce 25000 bags)

# Using direct library

newton_root = math.ceil(newton(f, initial_guess, f_prime)) # 164.96
print(f'\nNewton-Raphson Method (Direct Method from Python Library): Month-{newton_root:.2f} (Therefore, the EGIER need to build a new warehouse at Month-{newton_root - 13:.2f})')

# Using custom Newton Raphson Function (based on the written above)

newton2_root = math.ceil(netwon_raphson(f, f_prime, initial_guess)) # 164.96
print(f'\nNewton-Raphson Method (Custom Function): Month-{newton2_root:.2f} (Therefore, the EGIER need to build a new warehouse at Month-{newton2_root - 13:.2f})')

# Bisection Method

a, b = -300, 300 # Interval

# Using direct library

bisection_root = math.ceil(bisect(f, a, b)) # 164.96
print(f'\nBisection Method (Direct Method from Python Library): Month-{bisection_root:.2f} (Therefore, the EGIER need to build a new warehouse at Month-{bisection_root - 13:.2f})')

# Using custom Bisection Function (based on the written above)

bisection2_root = math.ceil(bisection(f, a, b)) # 164.96
print(f'\nBisection Method (Custom Function): Month-{bisection2_root:.2f} (Therefore, the EGIER need to build a new warehouse at Month-{bisection2_root - 13:.2f})')

# Conclusion

print (f'\nAll of the method given the same answer value which is the Root of Equation is 165 so EGIER need to build a new warehouse at Month-152')

# Proofing that at Month-165 the bags production will be 25.000+ using Polynomial Model from Question Number 1

x_value = 165
y_value = poly_model(x_value)
print(f'\nY value when X = {x_value} is {y_value:.2f}')

x_value = 164
y_value = poly_model(x_value)
print(f'\nY value when X = {x_value} is {y_value:.2f}')
# Out:
# Newton-Raphson Method (Direct Method from Python Library): Month-165.00 (Therefore, the EGIER need to build a new warehouse at Month-152.00)
#
# Newton-Raphson Method (Custom Function): Month-165.00 (Therefore, the EGIER need to build a new warehouse at Month-152.00)
#
# Bisection Method (Direct Method from Python Library): Month-165.00 (Therefore, the EGIER need to build a new warehouse at Month-152.00)
#
# Bisection Method (Custom Function): Month-165.00 (Therefore, the EGIER need to build a new warehouse at Month-152.00)
#
# All of the method given the same answer value which is the Root of Equation is 165 so EGIER need to build a new warehouse at Month-152
#
# Y value when X = 165 is 25016.99
#
# Y value when X = 164 is 24579.60

# %% [markdown]
# ### Conclusion
#
# Based on the Polynomial Model that was created previously, it has been proven that in the 165th month, the number of bag production will be 25016.99. So that this number will exceed the existing storage capacity, it is necessary to build a new warehouse, 13 months earlier, namely the 152nd month. My assumption is to use Rounded up (ceiling), because in the 164th month, the amount of production has not exceeded the limit, so there is no need to start construction in the 151st month, but construction of the new warehouse can start in the 152nd month.
#
# ##### ==> EGIER need to start build a new warehouse in the 152nd month

# %% [markdown]
# # AoL Number 4

# %% [markdown]
# ### There is no question Number 4 but only an order to write the code for Numbers 1 to Number 3, which has been completed at the top.
